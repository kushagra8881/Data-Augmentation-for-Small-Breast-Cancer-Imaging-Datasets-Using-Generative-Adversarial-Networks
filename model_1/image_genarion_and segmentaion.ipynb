# %%
import os
import torch
import cv2
import numpy as np
from torchvision.utils import save_image
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
from torchvision import transforms
import torch.nn.functional as F
from torch.nn.utils import spectral_norm
BASE_CHANNELS = 128  
IMG_SIZE = 256
BATCH_SIZE = 8
LATENT_DIM = 256
# Residual Block for Generator (StyleGAN-inspired)
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv = nn.Sequential(
            spectral_norm(nn.Conv2d(channels, channels, 3, padding=1)),
            nn.BatchNorm2d(channels),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(channels, channels, 3, padding=1)),
            nn.BatchNorm2d(channels)
        )
        
    def forward(self, x):
        return F.leaky_relu(x + self.conv(x), 0.2)

# Enhanced Generator with Residual Connections
class MedicalGenerator(nn.Module):
    def __init__(self):
        super().__init__()
        self.init_size = IMG_SIZE // 32
        self.fc = nn.Sequential(
            spectral_norm(nn.Linear(LATENT_DIM + 1, BASE_CHANNELS * 32 * self.init_size ** 2)),
            nn.BatchNorm1d(BASE_CHANNELS * 32 * self.init_size ** 2),
            nn.LeakyReLU(0.2)
        )
        
        self.blocks = nn.Sequential(
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*32, BASE_CHANNELS*16, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*16),
            nn.LeakyReLU(0.2),
            ResidualBlock(BASE_CHANNELS*16),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*16, BASE_CHANNELS*8, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*8),
            nn.LeakyReLU(0.2),
            ResidualBlock(BASE_CHANNELS*8),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*8, BASE_CHANNELS*4, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*4),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*4, BASE_CHANNELS*2, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*2),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*2, BASE_CHANNELS, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS, 1, 3, padding=1)),
            nn.Tanh()
        )

    def forward(self, z, labels):
        labels = labels.view(-1, 1)
        z = torch.cat([z, labels], 1)
        x = self.fc(z).view(-1, BASE_CHANNELS*32, self.init_size, self.init_size)
        return self.blocks(x)
# Load the trained GAN model
class GeneratorWrapper:
    def __init__(self, generator, latent_dim, device):
        self.generator = generator.to(device)
        self.generator.eval()
        self.latent_dim = latent_dim
        self.device = device
    
    def generate_images(self, label, num_images=50, save_dir="generated_images_1"):
        os.makedirs(f"{save_dir}/{label}", exist_ok=True)
        
        with torch.no_grad():
            z = torch.randn(num_images, self.latent_dim, device=self.device)
            labels = torch.full((num_images,), label, dtype=torch.float32, device=self.device)
            generated_imgs = self.generator(z, labels)
            
            for i in range(num_images):
                img = generated_imgs[i].cpu().squeeze().numpy()
                img = (img + 1) * 127.5  # Convert from [-1,1] to [0,255]
                img = img.astype(np.uint8)
                
                save_path = f"{save_dir}/{label}/generated_{i}.png"
                cv2.imwrite(save_path, img)
                print(f"Saved {save_path}")

# Load model and weightsS
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
latent_dim = 256  # Ensure this matches your model

generator = MedicalGenerator().to(device)
checkpoint = torch.load("gan_final.pth", map_location=device)
generator.load_state_dict(checkpoint['generator'])

# Generate and save images
gan_wrapper = GeneratorWrapper(generator, latent_dim, device)
for label in [0, 1]:
    gan_wrapper.generate_images(label, num_images=50)
# Out:
# Saved generated_images_8/0/generated7_0.png
# Saved generated_images_8/0/generated7_1.png
# Saved generated_images_8/0/generated7_2.png
# Saved generated_images_8/0/generated7_3.png
# Saved generated_images_8/0/generated7_4.png
# Saved generated_images_8/0/generated7_5.png
# Saved generated_images_8/0/generated7_6.png
# Saved generated_images_8/0/generated7_7.png
# Saved generated_images_8/0/generated7_8.png
# Saved generated_images_8/0/generated7_9.png
# Saved generated_images_8/0/generated7_10.png
# Saved generated_images_8/0/generated7_11.png
# Saved generated_images_8/0/generated7_12.png
# Saved generated_images_8/0/generated7_13.png
# Saved generated_images_8/0/generated7_14.png
# Saved generated_images_8/0/generated7_15.png
# Saved generated_images_8/0/generated7_16.png
# Saved generated_images_8/0/generated7_17.png
# Saved generated_images_8/0/generated7_18.png
# Saved generated_images_8/0/generated7_19.png
# Saved generated_images_8/0/generated7_20.png
# Saved generated_images_8/0/generated7_21.png
# Saved generated_images_8/0/generated7_22.png
# Saved generated_images_8/0/generated7_23.png
# Saved generated_images_8/0/generated7_24.png
# Saved generated_images_8/0/generated7_25.png
# Saved generated_images_8/0/generated7_26.png
# Saved generated_images_8/0/generated7_27.png
# Saved generated_images_8/0/generated7_28.png
# Saved generated_images_8/0/generated7_29.png
# Saved generated_images_8/0/generated7_30.png
# Saved generated_images_8/0/generated7_31.png
# Saved generated_images_8/0/generated7_32.png
# Saved generated_images_8/0/generated7_33.png
# Saved generated_images_8/0/generated7_34.png
# Saved generated_images_8/0/generated7_35.png
# Saved generated_images_8/0/generated7_36.png
# Saved generated_images_8/0/generated7_37.png
# Saved generated_images_8/0/generated7_38.png
# Saved generated_images_8/0/generated7_39.png
# Saved generated_images_8/0/generated7_40.png
# Saved generated_images_8/0/generated7_41.png
# Saved generated_images_8/0/generated7_42.png
# Saved generated_images_8/0/generated7_43.png
# Saved generated_images_8/0/generated7_44.png
# Saved generated_images_8/0/generated7_45.png
# Saved generated_images_8/0/generated7_46.png
# Saved generated_images_8/0/generated7_47.png
# Saved generated_images_8/0/generated7_48.png
# Saved generated_images_8/0/generated7_49.png
# Saved generated_images_8/1/generated7_0.png
# Saved generated_images_8/1/generated7_1.png
# Saved generated_images_8/1/generated7_2.png
# Saved generated_images_8/1/generated7_3.png
# Saved generated_images_8/1/generated7_4.png
# Saved generated_images_8/1/generated7_5.png
# Saved generated_images_8/1/generated7_6.png
# Saved generated_images_8/1/generated7_7.png
# Saved generated_images_8/1/generated7_8.png
# Saved generated_images_8/1/generated7_9.png
# Saved generated_images_8/1/generated7_10.png
# Saved generated_images_8/1/generated7_11.png
# Saved generated_images_8/1/generated7_12.png
# Saved generated_images_8/1/generated7_13.png
# Saved generated_images_8/1/generated7_14.png
# Saved generated_images_8/1/generated7_15.png
# Saved generated_images_8/1/generated7_16.png
# Saved generated_images_8/1/generated7_17.png
# Saved generated_images_8/1/generated7_18.png
# Saved generated_images_8/1/generated7_19.png
# Saved generated_images_8/1/generated7_20.png
# Saved generated_images_8/1/generated7_21.png
# Saved generated_images_8/1/generated7_22.png
# Saved generated_images_8/1/generated7_23.png
# Saved generated_images_8/1/generated7_24.png
# Saved generated_images_8/1/generated7_25.png
# Saved generated_images_8/1/generated7_26.png
# Saved generated_images_8/1/generated7_27.png
# Saved generated_images_8/1/generated7_28.png
# Saved generated_images_8/1/generated7_29.png
# Saved generated_images_8/1/generated7_30.png
# Saved generated_images_8/1/generated7_31.png
# Saved generated_images_8/1/generated7_32.png
# Saved generated_images_8/1/generated7_33.png
# Saved generated_images_8/1/generated7_34.png
# Saved generated_images_8/1/generated7_35.png
# Saved generated_images_8/1/generated7_36.png
# Saved generated_images_8/1/generated7_37.png
# Saved generated_images_8/1/generated7_38.png
# Saved generated_images_8/1/generated7_39.png
# Saved generated_images_8/1/generated7_40.png
# Saved generated_images_8/1/generated7_41.png
# Saved generated_images_8/1/generated7_42.png
# Saved generated_images_8/1/generated7_43.png
# Saved generated_images_8/1/generated7_44.png
# Saved generated_images_8/1/generated7_45.png
# Saved generated_images_8/1/generated7_46.png
# Saved generated_images_8/1/generated7_47.png
# Saved generated_images_8/1/generated7_48.png
# Saved generated_images_8/1/generated7_49.png

# %%
import os
import cv2
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torchvision import transforms
from natsort import natsorted

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ImprovedUNet(nn.Module):
    def __init__(self):
        super(ImprovedUNet, self).__init__()
        
        def conv_block(in_ch, out_ch):
            return nn.Sequential(
                nn.Conv2d(in_ch, out_ch, 3, padding=1),
                nn.BatchNorm2d(out_ch),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_ch, out_ch, 3, padding=1),
                nn.BatchNorm2d(out_ch),
                nn.ReLU(inplace=True)
            )
        
        self.enc1 = conv_block(1, 64)
        self.enc2 = conv_block(64, 128)
        self.enc3 = conv_block(128, 256)
        self.enc4 = conv_block(256, 512)
        self.pool = nn.MaxPool2d(2)
        
        self.up4 = nn.ConvTranspose2d(512, 256, 2, stride=2)
        self.dec4 = conv_block(512, 256)
        self.up3 = nn.ConvTranspose2d(256, 128, 2, stride=2)
        self.dec3 = conv_block(256, 128)
        self.up2 = nn.ConvTranspose2d(128, 64, 2, stride=2)
        self.dec2 = conv_block(128, 64)
        
        self.final = nn.Sequential(
            nn.Conv2d(64, 1, 1),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        
        d4 = self.up4(e4)
        d4 = torch.cat([d4, e3], dim=1)
        d4 = self.dec4(d4)
        
        d3 = self.up3(d4)
        d3 = torch.cat([d3, e2], dim=1)
        d3 = self.dec3(d3)
        
        d2 = self.up2(d3)
        d2 = torch.cat([d2, e1], dim=1)
        d2 = self.dec2(d2)
        
        return self.final(d2)

# Load model
model = ImprovedUNet().to(device)
model.load_state_dict(torch.load("best_model_seg.pth", map_location=device))
model.eval()

IMG_SIZE = (256, 256)
INPUT_FOLDER = "generated_images_8"
OUTPUT_FOLDER = "segmented_images_2"

def preprocess_image(img):
    img = cv2.resize(img, IMG_SIZE)
    img = img.astype(np.float32) / 255.0
    return torch.tensor(img).unsqueeze(0).unsqueeze(0).to(device)

# Main loop
for label in ["0", "1"]:
    input_dir = os.path.join(INPUT_FOLDER, label)
    raw_output_dir = os.path.join(OUTPUT_FOLDER, label, "raw")
    mask_output_dir = os.path.join(OUTPUT_FOLDER, label, "mask")
    
    os.makedirs(raw_output_dir, exist_ok=True)
    os.makedirs(mask_output_dir, exist_ok=True)

    for file in natsorted(os.listdir(input_dir)):
        input_path = os.path.join(input_dir, file)
        
        try:
            img = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                raise ValueError(f"Failed to read image: {input_path}")
            
            input_tensor = preprocess_image(img)
            with torch.no_grad():
                output = model(input_tensor)
                mask = (output.squeeze().cpu().numpy() > 0.6).astype(np.uint8) * 255

            # Skip saving if the mask is completely black
            if np.count_nonzero(mask) == 0:
                print(f"Skipped (empty mask): {input_path}")
                continue

            base_name = os.path.splitext(file)[0]
            raw_path = os.path.join(raw_output_dir, f"{base_name}_raw.png")
            mask_path = os.path.join(mask_output_dir, f"{base_name}_mask.png")
            
            cv2.imwrite(raw_path, cv2.resize(img, IMG_SIZE))
            cv2.imwrite(mask_path, mask)

            print(f"Saved: {raw_path}, {mask_path}")
        
        except Exception as e:
            print(f"Error processing {input_path}: {str(e)}")

print("Segmentation completed!")
# Out:
# Saved: segmented_images_2\0\raw\generated7_0_raw.png, segmented_images_2\0\mask\generated7_0_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_1.png
# Saved: segmented_images_2\0\raw\generated7_2_raw.png, segmented_images_2\0\mask\generated7_2_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_3.png
# Skipped (empty mask): generated_images_8\0\generated7_4.png
# Skipped (empty mask): generated_images_8\0\generated7_5.png
# Skipped (empty mask): generated_images_8\0\generated7_6.png
# Saved: segmented_images_2\0\raw\generated7_7_raw.png, segmented_images_2\0\mask\generated7_7_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_8.png
# Saved: segmented_images_2\0\raw\generated7_9_raw.png, segmented_images_2\0\mask\generated7_9_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_10.png
# Skipped (empty mask): generated_images_8\0\generated7_11.png
# Skipped (empty mask): generated_images_8\0\generated7_12.png
# Skipped (empty mask): generated_images_8\0\generated7_13.png
# Skipped (empty mask): generated_images_8\0\generated7_14.png
# Skipped (empty mask): generated_images_8\0\generated7_15.png
# Skipped (empty mask): generated_images_8\0\generated7_16.png
# Skipped (empty mask): generated_images_8\0\generated7_17.png
# Skipped (empty mask): generated_images_8\0\generated7_18.png
# Skipped (empty mask): generated_images_8\0\generated7_19.png
# Saved: segmented_images_2\0\raw\generated7_20_raw.png, segmented_images_2\0\mask\generated7_20_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_21.png
# Skipped (empty mask): generated_images_8\0\generated7_22.png
# Saved: segmented_images_2\0\raw\generated7_23_raw.png, segmented_images_2\0\mask\generated7_23_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_24.png
# Saved: segmented_images_2\0\raw\generated7_25_raw.png, segmented_images_2\0\mask\generated7_25_mask.png
# Saved: segmented_images_2\0\raw\generated7_26_raw.png, segmented_images_2\0\mask\generated7_26_mask.png
# Saved: segmented_images_2\0\raw\generated7_27_raw.png, segmented_images_2\0\mask\generated7_27_mask.png
# Saved: segmented_images_2\0\raw\generated7_28_raw.png, segmented_images_2\0\mask\generated7_28_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_29.png
# Skipped (empty mask): generated_images_8\0\generated7_30.png
# Saved: segmented_images_2\0\raw\generated7_31_raw.png, segmented_images_2\0\mask\generated7_31_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_32.png
# Skipped (empty mask): generated_images_8\0\generated7_33.png
# Skipped (empty mask): generated_images_8\0\generated7_34.png
# Skipped (empty mask): generated_images_8\0\generated7_35.png
# Skipped (empty mask): generated_images_8\0\generated7_36.png
# Saved: segmented_images_2\0\raw\generated7_37_raw.png, segmented_images_2\0\mask\generated7_37_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_38.png
# Saved: segmented_images_2\0\raw\generated7_39_raw.png, segmented_images_2\0\mask\generated7_39_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_40.png
# Saved: segmented_images_2\0\raw\generated7_41_raw.png, segmented_images_2\0\mask\generated7_41_mask.png
# Skipped (empty mask): generated_images_8\0\generated7_42.png
# Skipped (empty mask): generated_images_8\0\generated7_43.png
# Skipped (empty mask): generated_images_8\0\generated7_44.png
# Skipped (empty mask): generated_images_8\0\generated7_45.png
# Skipped (empty mask): generated_images_8\0\generated7_46.png
# Skipped (empty mask): generated_images_8\0\generated7_47.png
# Skipped (empty mask): generated_images_8\0\generated7_48.png
# Skipped (empty mask): generated_images_8\0\generated7_49.png
# Skipped (empty mask): generated_images_8\1\generated7_0.png
# Saved: segmented_images_2\1\raw\generated7_1_raw.png, segmented_images_2\1\mask\generated7_1_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_2.png
# Saved: segmented_images_2\1\raw\generated7_3_raw.png, segmented_images_2\1\mask\generated7_3_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_4.png
# Skipped (empty mask): generated_images_8\1\generated7_5.png
# Saved: segmented_images_2\1\raw\generated7_6_raw.png, segmented_images_2\1\mask\generated7_6_mask.png
# Saved: segmented_images_2\1\raw\generated7_7_raw.png, segmented_images_2\1\mask\generated7_7_mask.png
# Saved: segmented_images_2\1\raw\generated7_8_raw.png, segmented_images_2\1\mask\generated7_8_mask.png
# Saved: segmented_images_2\1\raw\generated7_9_raw.png, segmented_images_2\1\mask\generated7_9_mask.png
# Saved: segmented_images_2\1\raw\generated7_10_raw.png, segmented_images_2\1\mask\generated7_10_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_11.png
# Saved: segmented_images_2\1\raw\generated7_12_raw.png, segmented_images_2\1\mask\generated7_12_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_13.png
# Saved: segmented_images_2\1\raw\generated7_14_raw.png, segmented_images_2\1\mask\generated7_14_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_15.png
# Saved: segmented_images_2\1\raw\generated7_16_raw.png, segmented_images_2\1\mask\generated7_16_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_17.png
# Skipped (empty mask): generated_images_8\1\generated7_18.png
# Skipped (empty mask): generated_images_8\1\generated7_19.png
# Saved: segmented_images_2\1\raw\generated7_20_raw.png, segmented_images_2\1\mask\generated7_20_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_21.png
# Skipped (empty mask): generated_images_8\1\generated7_22.png
# Skipped (empty mask): generated_images_8\1\generated7_23.png
# Skipped (empty mask): generated_images_8\1\generated7_24.png
# Saved: segmented_images_2\1\raw\generated7_25_raw.png, segmented_images_2\1\mask\generated7_25_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_26.png
# Skipped (empty mask): generated_images_8\1\generated7_27.png
# Saved: segmented_images_2\1\raw\generated7_28_raw.png, segmented_images_2\1\mask\generated7_28_mask.png
# Saved: segmented_images_2\1\raw\generated7_29_raw.png, segmented_images_2\1\mask\generated7_29_mask.png
# Saved: segmented_images_2\1\raw\generated7_30_raw.png, segmented_images_2\1\mask\generated7_30_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_31.png
# Saved: segmented_images_2\1\raw\generated7_32_raw.png, segmented_images_2\1\mask\generated7_32_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_33.png
# Saved: segmented_images_2\1\raw\generated7_34_raw.png, segmented_images_2\1\mask\generated7_34_mask.png
# Saved: segmented_images_2\1\raw\generated7_35_raw.png, segmented_images_2\1\mask\generated7_35_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_36.png
# Saved: segmented_images_2\1\raw\generated7_37_raw.png, segmented_images_2\1\mask\generated7_37_mask.png
# Saved: segmented_images_2\1\raw\generated7_38_raw.png, segmented_images_2\1\mask\generated7_38_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_39.png
# Saved: segmented_images_2\1\raw\generated7_40_raw.png, segmented_images_2\1\mask\generated7_40_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_41.png
# Skipped (empty mask): generated_images_8\1\generated7_42.png
# Skipped (empty mask): generated_images_8\1\generated7_43.png
# Saved: segmented_images_2\1\raw\generated7_44_raw.png, segmented_images_2\1\mask\generated7_44_mask.png
# Skipped (empty mask): generated_images_8\1\generated7_45.png
# Skipped (empty mask): generated_images_8\1\generated7_46.png
# Skipped (empty mask): generated_images_8\1\generated7_47.png
# Skipped (empty mask): generated_images_8\1\generated7_48.png
# Skipped (empty mask): generated_images_8\1\generated7_49.png
# Segmentation completed!

# %%
import os

OUTPUT_FOLDER = "segmented_images_2"

def count_saved_images(label):
    raw_dir = os.path.join(OUTPUT_FOLDER, label, "raw")
    mask_dir = os.path.join(OUTPUT_FOLDER, label, "mask")
    
    raw_count = len([f for f in os.listdir(raw_dir) if f.endswith(".png")])
    mask_count = len([f for f in os.listdir(mask_dir) if f.endswith(".png")])
    
    return raw_count, mask_count

total_raw = 0
total_mask = 0

for label in ["0", "1"]:
    raw_count, mask_count = count_saved_images(label)
    total_raw += raw_count
    total_mask += mask_count
    print(f"Label {label} - Raw images: {raw_count}, Mask images: {mask_count}")

print(f"\nTotal Raw images: {total_raw}, Total Mask images: {total_mask}")
# Out:
# Label 0 - Raw images: 82, Mask images: 82
# Label 1 - Raw images: 145, Mask images: 145
#
# Total Raw images: 227, Total Mask images: 227

# %%
import os
import cv2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
from natsort import natsorted
import matplotlib.pyplot as plt

# Configuration
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
EPOCHS = 100
VAL_SPLIT = 0.2
# Fix typo in directory name (if needed) and use normalized path
DATA_PATH = "segmented_images_2"  # Remove trailing slash and fix spelling
LABELS = ["0", "1"]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Dataset Class
class UltrasoundDataset(Dataset):
    def __init__(self, data_path):
        self.rf_images = []
        self.roi_masks = []
        valid_extensions = ('.png', '.jpg', '.jpeg')

        for label in LABELS:
            # Updated path handling to be more robust
            rf_path = os.path.join(data_path, label, "raw")
            roi_path = os.path.join(data_path, label, "mask")
            
            # Check if directories exist
            if not os.path.exists(rf_path):
                print(f"Warning: Raw directory not found: {os.path.abspath(rf_path)}")
                continue
                
            if not os.path.exists(roi_path):
                print(f"Warning: Mask directory not found: {os.path.abspath(roi_path)}")
                continue
            
            print(f"Processing images from {rf_path}")
            
            rf_files = natsorted([f for f in os.listdir(rf_path) if f.lower().endswith(valid_extensions)])
            roi_files = natsorted([f for f in os.listdir(roi_path) if f.lower().endswith(valid_extensions)])

            if len(rf_files) == 0:
                print(f"Warning: No valid images found in {rf_path}")
                
            if len(roi_files) == 0:
                print(f"Warning: No valid masks found in {roi_path}")
                
            print(f"Found {len(rf_files)} raw images and {len(roi_files)} masks for label {label}")
            
            # Make sure we only process files that have both image and mask
            for rf_file, roi_file in zip(rf_files, roi_files):
                rf_path_full = os.path.join(rf_path, rf_file)
                roi_path_full = os.path.join(roi_path, roi_file)
                
                rf_img = cv2.imread(rf_path_full, cv2.IMREAD_GRAYSCALE)
                roi_img = cv2.imread(roi_path_full, cv2.IMREAD_GRAYSCALE)

                if rf_img is None:
                    print(f"Warning: Could not read image: {rf_path_full}")
                    continue
                    
                if roi_img is None:
                    print(f"Warning: Could not read mask: {roi_path_full}")
                    continue

                rf_img = cv2.resize(rf_img, IMG_SIZE)
                roi_img = cv2.resize(roi_img, IMG_SIZE)
                roi_img = (roi_img > 127).astype(np.float32)

                # Data augmentation
                if np.random.rand() > 0.5:
                    rf_img = cv2.flip(rf_img, 1)
                    roi_img = cv2.flip(roi_img, 1)

                if np.random.rand() > 0.5:
                    angle = np.random.randint(-15, 15)
                    M = cv2.getRotationMatrix2D((IMG_SIZE[0]//2, IMG_SIZE[1]//2), angle, 1)
                    rf_img = cv2.warpAffine(rf_img, M, IMG_SIZE)
                    roi_img = cv2.warpAffine(roi_img, M, IMG_SIZE)

                self.rf_images.append(rf_img)
                self.roi_masks.append(roi_img)

    def __len__(self):
        return len(self.rf_images)

    def __getitem__(self, idx):
        img = torch.tensor(self.rf_images[idx], dtype=torch.float32).unsqueeze(0) / 255.0
        mask = torch.tensor(self.roi_masks[idx], dtype=torch.float32).unsqueeze(0)
        return img, mask

# Improved U-Net model (unchanged)
class ImprovedUNet(nn.Module):
    def __init__(self):
        super(ImprovedUNet, self).__init__()
        
        def conv_block(in_ch, out_ch):
            return nn.Sequential(
                nn.Conv2d(in_ch, out_ch, 3, padding=1),
                nn.BatchNorm2d(out_ch),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_ch, out_ch, 3, padding=1),
                nn.BatchNorm2d(out_ch),
                nn.ReLU(inplace=True)
            )
        
        self.enc1 = conv_block(1, 64)
        self.enc2 = conv_block(64, 128)
        self.enc3 = conv_block(128, 256)
        self.enc4 = conv_block(256, 512)
        self.pool = nn.MaxPool2d(2)
        
        self.up4 = nn.ConvTranspose2d(512, 256, 2, stride=2)
        self.dec4 = conv_block(512, 256)
        self.up3 = nn.ConvTranspose2d(256, 128, 2, stride=2)
        self.dec3 = conv_block(256, 128)
        self.up2 = nn.ConvTranspose2d(128, 64, 2, stride=2)
        self.dec2 = conv_block(128, 64)
        
        self.final = nn.Sequential(
            nn.Conv2d(64, 1, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        
        d4 = self.up4(e4)
        d4 = torch.cat([d4, e3], dim=1)
        d4 = self.dec4(d4)
        
        d3 = self.up3(d4)
        d3 = torch.cat([d3, e2], dim=1)
        d3 = self.dec3(d3)
        
        d2 = self.up2(d3)
        d2 = torch.cat([d2, e1], dim=1)
        d2 = self.dec2(d2)
        
        return self.final(d2)

# Metrics (unchanged)
def calculate_metrics(TP, TN, FP, FN):
    eps = 1e-10
    return {
        'Accuracy': (TP + TN) / (TP + TN + FP + FN + eps),
        'Recall': TP / (TP + FN + eps),
        'Specificity': TN / (TN + FP + eps),
        'Precision': TP / (TP + FP + eps),
        'Dice': (2 * TP) / (2 * TP + FP + FN + eps),
        'IoU': TP / (TP + FP + FN + eps)
    }

# Count Images in Each Label - improved error handling
def count_images_per_label():
    print("Counting images per label:")
    for label in LABELS:
        raw_dir = os.path.join(DATA_PATH, label, "raw")
        mask_dir = os.path.join(DATA_PATH, label, "mask")

        if not os.path.exists(raw_dir) or not os.path.exists(mask_dir):
            print(f"Directory missing for label {label}:")
            print(f" - Raw path exists? {os.path.exists(raw_dir)} -> {os.path.abspath(raw_dir)}")
            print(f" - Mask path exists? {os.path.exists(mask_dir)} -> {os.path.abspath(mask_dir)}")
            continue

        raw_count = len([f for f in os.listdir(raw_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
        mask_count = len([f for f in os.listdir(mask_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
        
        print(f"Label {label}: {raw_count} raw images, {mask_count} masks")

# Function to verify and create directory structure
def setup_directories():
    print("Setting up directory structure...")
    for label in LABELS:
        raw_dir = os.path.join(DATA_PATH, label, "raw")
        mask_dir = os.path.join(DATA_PATH, label, "mask")
        
        # Create directories if they don't exist
        os.makedirs(raw_dir, exist_ok=True)
        os.makedirs(mask_dir, exist_ok=True)
        
        print(f"Created directories for label {label}:")
        print(f" - Raw directory: {os.path.abspath(raw_dir)}")
        print(f" - Mask directory: {os.path.abspath(mask_dir)}")
    
    print("Directory setup complete. Please add your images to these directories.")

def train_model():
    # Check if we have any data
    has_data = False
    for label in LABELS:
        raw_dir = os.path.join(DATA_PATH, label, "raw")
        if os.path.exists(raw_dir) and len(os.listdir(raw_dir)) > 0:
            has_data = True
            break
    
    if not has_data:
        print("No data found. Please add images to your dataset directories.")
        return
        
    dataset = UltrasoundDataset(DATA_PATH)
    
    if len(dataset) == 0:
        print("Dataset is empty. Please check your image directories and file formats.")
        return
        
    print(f"\nTotal dataset samples: {len(dataset)}")
    
    # Show a sample from the dataset
    sample_img, sample_mask = dataset[0]
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.imshow(sample_img.squeeze(), cmap='gray')
    plt.title('Input Image')
    plt.subplot(122)
    plt.imshow(sample_mask.squeeze(), cmap='gray')
    plt.title('Ground Truth')
    plt.show()

    # Split dataset into training and validation
    train_size = int((1 - VAL_SPLIT) * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

    # Initialize model, optimizer, scheduler, and loss function
    model = ImprovedUNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3)
    criterion = nn.BCELoss()
    best_dice = 0

    print(f"Training on device: {device}")
    print(f"Training samples: {len(train_dataset)}, Validation samples: {len(val_dataset)}")

    # Training loop
    for epoch in range(EPOCHS):
        model.train()
        train_loss = 0
        train_TP = train_TN = train_FP = train_FN = 0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

            with torch.no_grad():
                preds = (outputs > 0.5).float()
                TP = (preds * masks).sum().item()
                TN = ((1 - preds) * (1 - masks)).sum().item()
                FP = (preds * (1 - masks)).sum().item()
                FN = ((1 - preds) * masks).sum().item()
                train_TP += TP
                train_TN += TN
                train_FP += FP
                train_FN += FN

        model.eval()
        val_loss = 0
        val_TP = val_TN = val_FP = val_FN = 0

        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)
                val_loss += criterion(outputs, masks).item()

                preds = (outputs > 0.5).float()
                TP = (preds * masks).sum().item()
                TN = ((1 - preds) * (1 - masks)).sum().item()
                FP = (preds * (1 - masks)).sum().item()
                FN = ((1 - preds) * masks).sum().item()
                val_TP += TP
                val_TN += TN
                val_FP += FP
                val_FN += FN

        train_metrics = calculate_metrics(train_TP, train_TN, train_FP, train_FN)
        val_metrics = calculate_metrics(val_TP, val_TN, val_FP, val_FN)
        scheduler.step(val_loss)

        print(f"\nEpoch {epoch+1}/{EPOCHS}")
        print(f"Train Loss: {train_loss/len(train_loader):.4f} | Acc: {train_metrics['Accuracy']:.4f} | Dice: {train_metrics['Dice']:.4f} | IoU: {train_metrics['IoU']:.4f}")
        print(f"Val   Loss: {val_loss/len(val_loader):.4f} | Acc: {val_metrics['Accuracy']:.4f} | Dice: {val_metrics['Dice']:.4f} | IoU: {val_metrics['IoU']:.4f}")

        if val_metrics['Dice'] > best_dice:
            best_dice = val_metrics['Dice']
            torch.save(model.state_dict(), "best_model_seg_NEW.pth")
            print(f"Saved new best model with Dice: {best_dice:.4f}")

if __name__ == "__main__":
    # Create the directory structure if needed
    setup_directories()
    
    # Check if images are properly placed
    count_images_per_label()
    
    # Ask user if they want to proceed with training
    proceed = input("Do you want to proceed with training? (y/n): ")
    if proceed.lower() in ['y', 'yes']:
        train_model()
    else:
        print("Training cancelled. Please add images to the directories and run again.")
# Out:
# Setting up directory structure...
# Created directories for label 0:
#  - Raw directory: d:\gankushagra\new-20241107T124416Z-001\cnn\segmented_images_2\0\raw
#  - Mask directory: d:\gankushagra\new-20241107T124416Z-001\cnn\segmented_images_2\0\mask
# Created directories for label 1:
#  - Raw directory: d:\gankushagra\new-20241107T124416Z-001\cnn\segmented_images_2\1\raw
#  - Mask directory: d:\gankushagra\new-20241107T124416Z-001\cnn\segmented_images_2\1\mask
# Directory setup complete. Please add your images to these directories.
# Counting images per label:
# Label 0: 82 raw images, 82 masks
# Label 1: 145 raw images, 145 masks
# Processing images from segmented_images_2\0\raw
# Found 82 raw images and 82 masks for label 0
# Processing images from segmented_images_2\1\raw
# Found 145 raw images and 145 masks for label 1
#
# Total dataset samples: 227
# Training on device: cuda
# Training samples: 181, Validation samples: 46
#
# Epoch 1/100
# Train Loss: 0.5820 | Acc: 0.8217 | Dice: 0.0323 | IoU: 0.0164
# Val   Loss: 0.5671 | Acc: 0.9794 | Dice: 0.0001 | IoU: 0.0001
# Saved new best model with Dice: 0.0001
#
# Epoch 2/100
# Train Loss: 0.4040 | Acc: 0.9794 | Dice: 0.0003 | IoU: 0.0002
# Val   Loss: 0.3771 | Acc: 0.9810 | Dice: 0.0000 | IoU: 0.0000
#
# Epoch 3/100
# Train Loss: 0.3539 | Acc: 0.9818 | Dice: 0.0000 | IoU: 0.0000
# Val   Loss: 0.3473 | Acc: 0.9788 | Dice: 0.0000 | IoU: 0.0000
#
# Epoch 4/100
# Train Loss: 0.3236 | Acc: 0.9829 | Dice: 0.0000 | IoU: 0.0000
# Val   Loss: 0.3292 | Acc: 0.9802 | Dice: 0.0000 | IoU: 0.0000
#
# Epoch 5/100
# Train Loss: 0.3083 | Acc: 0.9831 | Dice: 0.0016 | IoU: 0.0008
# Val   Loss: 0.3240 | Acc: 0.9726 | Dice: 0.0002 | IoU: 0.0001
# Saved new best model with Dice: 0.0002
#
# Epoch 6/100
# Train Loss: 0.3012 | Acc: 0.9835 | Dice: 0.0000 | IoU: 0.0000
# Val   Loss: 0.2897 | Acc: 0.9814 | Dice: 0.0000 | IoU: 0.0000
#
# Epoch 7/100
# Train Loss: 0.2806 | Acc: 0.9842 | Dice: 0.1137 | IoU: 0.0603
# Val   Loss: 0.2834 | Acc: 0.9817 | Dice: 0.1580 | IoU: 0.0858
# Saved new best model with Dice: 0.1580
#
# Epoch 8/100
# Train Loss: 0.2666 | Acc: 0.9855 | Dice: 0.4113 | IoU: 0.2589
# Val   Loss: 0.3016 | Acc: 0.9548 | Dice: 0.3777 | IoU: 0.2328
# Saved new best model with Dice: 0.3777
#
# Epoch 9/100
# Train Loss: 0.2561 | Acc: 0.9860 | Dice: 0.5044 | IoU: 0.3373
# Val   Loss: 0.2560 | Acc: 0.9851 | Dice: 0.5169 | IoU: 0.3486
# Saved new best model with Dice: 0.5169
#
# Epoch 10/100
# Train Loss: 0.2462 | Acc: 0.9854 | Dice: 0.5222 | IoU: 0.3534
# Val   Loss: 0.2514 | Acc: 0.9845 | Dice: 0.5170 | IoU: 0.3486
# Saved new best model with Dice: 0.5170
#
# Epoch 11/100
# Train Loss: 0.2357 | Acc: 0.9864 | Dice: 0.5638 | IoU: 0.3926
# Val   Loss: 0.2399 | Acc: 0.9839 | Dice: 0.4871 | IoU: 0.3220
#
# Epoch 12/100
# Train Loss: 0.2257 | Acc: 0.9878 | Dice: 0.6160 | IoU: 0.4451
# Val   Loss: 0.2206 | Acc: 0.9862 | Dice: 0.5632 | IoU: 0.3920
# Saved new best model with Dice: 0.5632
#
# Epoch 13/100
# Train Loss: 0.2171 | Acc: 0.9881 | Dice: 0.6290 | IoU: 0.4588
# Val   Loss: 0.2295 | Acc: 0.9842 | Dice: 0.4664 | IoU: 0.3041
#
# Epoch 14/100
# Train Loss: 0.2107 | Acc: 0.9876 | Dice: 0.6049 | IoU: 0.4336
# Val   Loss: 0.2198 | Acc: 0.9820 | Dice: 0.5860 | IoU: 0.4144
# Saved new best model with Dice: 0.5860
#
# Epoch 15/100
# Train Loss: 0.2017 | Acc: 0.9881 | Dice: 0.6255 | IoU: 0.4550
# Val   Loss: 0.2284 | Acc: 0.9734 | Dice: 0.5449 | IoU: 0.3745
#
# Epoch 16/100
# Train Loss: 0.1945 | Acc: 0.9882 | Dice: 0.6403 | IoU: 0.4709
# Val   Loss: 0.1906 | Acc: 0.9857 | Dice: 0.5383 | IoU: 0.3682
#
# Epoch 17/100
# Train Loss: 0.1860 | Acc: 0.9899 | Dice: 0.6785 | IoU: 0.5134
# Val   Loss: 0.1879 | Acc: 0.9836 | Dice: 0.6167 | IoU: 0.4458
# Saved new best model with Dice: 0.6167
#
# Epoch 18/100
# Train Loss: 0.1812 | Acc: 0.9886 | Dice: 0.6400 | IoU: 0.4706
# Val   Loss: 0.1866 | Acc: 0.9829 | Dice: 0.5874 | IoU: 0.4159
#
# Epoch 19/100
# Train Loss: 0.1746 | Acc: 0.9895 | Dice: 0.6573 | IoU: 0.4895
# Val   Loss: 0.2169 | Acc: 0.9580 | Dice: 0.4575 | IoU: 0.2966
#
# Epoch 20/100
# Train Loss: 0.1682 | Acc: 0.9891 | Dice: 0.6748 | IoU: 0.5092
# Val   Loss: 0.1708 | Acc: 0.9844 | Dice: 0.3163 | IoU: 0.1879
#
# Epoch 21/100
# Train Loss: 0.1633 | Acc: 0.9898 | Dice: 0.6662 | IoU: 0.4995
# Val   Loss: 0.1696 | Acc: 0.9841 | Dice: 0.3156 | IoU: 0.1874
#
# Epoch 22/100
# Train Loss: 0.1581 | Acc: 0.9893 | Dice: 0.6599 | IoU: 0.4924
# Val   Loss: 0.1590 | Acc: 0.9833 | Dice: 0.5691 | IoU: 0.3977
#
# Epoch 23/100
# Train Loss: 0.1527 | Acc: 0.9895 | Dice: 0.6640 | IoU: 0.4970
# Val   Loss: 0.1570 | Acc: 0.9846 | Dice: 0.6269 | IoU: 0.4566
# Saved new best model with Dice: 0.6269
#
# Epoch 24/100
# Train Loss: 0.1472 | Acc: 0.9901 | Dice: 0.6791 | IoU: 0.5142
# Val   Loss: 0.1532 | Acc: 0.9852 | Dice: 0.4619 | IoU: 0.3003
#
# Epoch 25/100
# Train Loss: 0.1425 | Acc: 0.9900 | Dice: 0.6912 | IoU: 0.5281
# Val   Loss: 0.1506 | Acc: 0.9865 | Dice: 0.6317 | IoU: 0.4617
# Saved new best model with Dice: 0.6317
#
# Epoch 26/100
# Train Loss: 0.1372 | Acc: 0.9904 | Dice: 0.7012 | IoU: 0.5398
# Val   Loss: 0.1403 | Acc: 0.9866 | Dice: 0.5167 | IoU: 0.3483
#
# Epoch 27/100
# Train Loss: 0.1321 | Acc: 0.9914 | Dice: 0.7262 | IoU: 0.5701
# Val   Loss: 0.1462 | Acc: 0.9824 | Dice: 0.1293 | IoU: 0.0691
#
# Epoch 28/100
# Train Loss: 0.1298 | Acc: 0.9904 | Dice: 0.6839 | IoU: 0.5197
# Val   Loss: 0.1357 | Acc: 0.9848 | Dice: 0.6100 | IoU: 0.4389
#
# Epoch 29/100
# Train Loss: 0.1264 | Acc: 0.9896 | Dice: 0.6764 | IoU: 0.5111
# Val   Loss: 0.1336 | Acc: 0.9852 | Dice: 0.3535 | IoU: 0.2147
#
# Epoch 30/100
# Train Loss: 0.1214 | Acc: 0.9905 | Dice: 0.6922 | IoU: 0.5293
# Val   Loss: 0.1306 | Acc: 0.9847 | Dice: 0.3491 | IoU: 0.2115
#
# Epoch 31/100
# Train Loss: 0.1174 | Acc: 0.9906 | Dice: 0.7049 | IoU: 0.5443
# Val   Loss: 0.1244 | Acc: 0.9848 | Dice: 0.5094 | IoU: 0.3418
#
# Epoch 32/100
# Train Loss: 0.1161 | Acc: 0.9891 | Dice: 0.6699 | IoU: 0.5036
# Val   Loss: 0.1243 | Acc: 0.9839 | Dice: 0.2838 | IoU: 0.1654
#
# Epoch 33/100
# Train Loss: 0.1109 | Acc: 0.9912 | Dice: 0.7028 | IoU: 0.5418
# Val   Loss: 0.1142 | Acc: 0.9867 | Dice: 0.5135 | IoU: 0.3454
#
# Epoch 34/100
# Train Loss: 0.1066 | Acc: 0.9913 | Dice: 0.7310 | IoU: 0.5760
# Val   Loss: 0.1194 | Acc: 0.9842 | Dice: 0.2895 | IoU: 0.1692
#
# Epoch 35/100
# Train Loss: 0.1033 | Acc: 0.9915 | Dice: 0.7312 | IoU: 0.5763
# Val   Loss: 0.1091 | Acc: 0.9884 | Dice: 0.6836 | IoU: 0.5193
# Saved new best model with Dice: 0.6836
#
# Epoch 36/100
# Train Loss: 0.0999 | Acc: 0.9918 | Dice: 0.7407 | IoU: 0.5882
# Val   Loss: 0.1032 | Acc: 0.9880 | Dice: 0.6582 | IoU: 0.4905
#
# Epoch 37/100
# Train Loss: 0.0951 | Acc: 0.9932 | Dice: 0.7859 | IoU: 0.6473
# Val   Loss: 0.1053 | Acc: 0.9867 | Dice: 0.6432 | IoU: 0.4740
#
# Epoch 38/100
# Train Loss: 0.0935 | Acc: 0.9924 | Dice: 0.7671 | IoU: 0.6221
# Val   Loss: 0.0989 | Acc: 0.9881 | Dice: 0.6181 | IoU: 0.4473
#
# Epoch 39/100
# Train Loss: 0.0902 | Acc: 0.9930 | Dice: 0.7820 | IoU: 0.6421
# Val   Loss: 0.0970 | Acc: 0.9879 | Dice: 0.6298 | IoU: 0.4597
#
# Epoch 40/100
# Train Loss: 0.0902 | Acc: 0.9916 | Dice: 0.7327 | IoU: 0.5782
# Val   Loss: 0.1025 | Acc: 0.9858 | Dice: 0.4592 | IoU: 0.2980
#
# Epoch 41/100
# Train Loss: 0.0869 | Acc: 0.9918 | Dice: 0.7420 | IoU: 0.5898
# Val   Loss: 0.1001 | Acc: 0.9859 | Dice: 0.4328 | IoU: 0.2762
#
# Epoch 42/100
# Train Loss: 0.0829 | Acc: 0.9931 | Dice: 0.7857 | IoU: 0.6470
# Val   Loss: 0.0916 | Acc: 0.9875 | Dice: 0.6692 | IoU: 0.5028
#
# Epoch 43/100
# Train Loss: 0.0842 | Acc: 0.9914 | Dice: 0.7233 | IoU: 0.5665
# Val   Loss: 0.0879 | Acc: 0.9873 | Dice: 0.5839 | IoU: 0.4123
#
# Epoch 44/100
# Train Loss: 0.0783 | Acc: 0.9934 | Dice: 0.7977 | IoU: 0.6635
# Val   Loss: 0.0862 | Acc: 0.9879 | Dice: 0.6003 | IoU: 0.4289
#
# Epoch 45/100
# Train Loss: 0.0758 | Acc: 0.9937 | Dice: 0.7981 | IoU: 0.6640
# Val   Loss: 0.0885 | Acc: 0.9855 | Dice: 0.6371 | IoU: 0.4675
#
# Epoch 46/100
# Train Loss: 0.0760 | Acc: 0.9927 | Dice: 0.7708 | IoU: 0.6270
# Val   Loss: 0.0889 | Acc: 0.9855 | Dice: 0.4020 | IoU: 0.2516
#
# Epoch 47/100
# Train Loss: 0.0737 | Acc: 0.9928 | Dice: 0.7743 | IoU: 0.6317
# Val   Loss: 0.0872 | Acc: 0.9856 | Dice: 0.6513 | IoU: 0.4830
#
# Epoch 48/100
# Train Loss: 0.0732 | Acc: 0.9921 | Dice: 0.7507 | IoU: 0.6009
# Val   Loss: 0.0892 | Acc: 0.9851 | Dice: 0.3611 | IoU: 0.2204
#
# Epoch 49/100
# Train Loss: 0.0686 | Acc: 0.9944 | Dice: 0.8147 | IoU: 0.6873
# Val   Loss: 0.0774 | Acc: 0.9892 | Dice: 0.6725 | IoU: 0.5066
#
# Epoch 50/100
# Train Loss: 0.0672 | Acc: 0.9948 | Dice: 0.8395 | IoU: 0.7234
# Val   Loss: 0.0782 | Acc: 0.9887 | Dice: 0.6145 | IoU: 0.4435
#
# Epoch 51/100
# Train Loss: 0.0666 | Acc: 0.9949 | Dice: 0.8447 | IoU: 0.7312
# Val   Loss: 0.0796 | Acc: 0.9883 | Dice: 0.5979 | IoU: 0.4265
#
# Epoch 52/100
# Train Loss: 0.0666 | Acc: 0.9949 | Dice: 0.8422 | IoU: 0.7275
# Val   Loss: 0.0799 | Acc: 0.9882 | Dice: 0.5948 | IoU: 0.4232
#
# Epoch 53/100
# Train Loss: 0.0653 | Acc: 0.9956 | Dice: 0.8620 | IoU: 0.7575
# Val   Loss: 0.0792 | Acc: 0.9888 | Dice: 0.6355 | IoU: 0.4658
#
# Epoch 54/100
# Train Loss: 0.0650 | Acc: 0.9955 | Dice: 0.8627 | IoU: 0.7586
# Val   Loss: 0.0786 | Acc: 0.9890 | Dice: 0.6501 | IoU: 0.4816
#
# Epoch 55/100
# Train Loss: 0.0650 | Acc: 0.9955 | Dice: 0.8614 | IoU: 0.7566
# Val   Loss: 0.0784 | Acc: 0.9889 | Dice: 0.6361 | IoU: 0.4664
#
# Epoch 56/100
# Train Loss: 0.0649 | Acc: 0.9956 | Dice: 0.8635 | IoU: 0.7599
# Val   Loss: 0.0782 | Acc: 0.9889 | Dice: 0.6342 | IoU: 0.4643
#
# Epoch 57/100
# Train Loss: 0.0648 | Acc: 0.9957 | Dice: 0.8700 | IoU: 0.7699
# Val   Loss: 0.0780 | Acc: 0.9890 | Dice: 0.6452 | IoU: 0.4763
#
# Epoch 58/100
# Train Loss: 0.0653 | Acc: 0.9953 | Dice: 0.8573 | IoU: 0.7502
# Val   Loss: 0.0781 | Acc: 0.9889 | Dice: 0.6399 | IoU: 0.4705
#
# Epoch 59/100
# Train Loss: 0.0668 | Acc: 0.9945 | Dice: 0.8335 | IoU: 0.7146
# Val   Loss: 0.0794 | Acc: 0.9887 | Dice: 0.6427 | IoU: 0.4735
#
# Epoch 60/100
# Train Loss: 0.0652 | Acc: 0.9954 | Dice: 0.8582 | IoU: 0.7516
# Val   Loss: 0.0783 | Acc: 0.9889 | Dice: 0.6338 | IoU: 0.4640
#
# Epoch 61/100
# Train Loss: 0.0654 | Acc: 0.9952 | Dice: 0.8542 | IoU: 0.7455
# Val   Loss: 0.0783 | Acc: 0.9889 | Dice: 0.6488 | IoU: 0.4802
#
# Epoch 62/100
# Train Loss: 0.0645 | Acc: 0.9957 | Dice: 0.8693 | IoU: 0.7688
# Val   Loss: 0.0786 | Acc: 0.9889 | Dice: 0.6420 | IoU: 0.4728
#
# Epoch 63/100
# Train Loss: 0.0656 | Acc: 0.9952 | Dice: 0.8531 | IoU: 0.7438
# Val   Loss: 0.0784 | Acc: 0.9888 | Dice: 0.6307 | IoU: 0.4606
#
# Epoch 64/100
# Train Loss: 0.0653 | Acc: 0.9955 | Dice: 0.8607 | IoU: 0.7554
# Val   Loss: 0.0791 | Acc: 0.9888 | Dice: 0.6315 | IoU: 0.4614
#
# Epoch 65/100
# Train Loss: 0.0641 | Acc: 0.9959 | Dice: 0.8756 | IoU: 0.7787
# Val   Loss: 0.0785 | Acc: 0.9889 | Dice: 0.6342 | IoU: 0.4643
#
# Epoch 66/100
# Train Loss: 0.0653 | Acc: 0.9953 | Dice: 0.8565 | IoU: 0.7490
# Val   Loss: 0.0789 | Acc: 0.9888 | Dice: 0.6318 | IoU: 0.4618
#
# Epoch 67/100
# Train Loss: 0.0656 | Acc: 0.9952 | Dice: 0.8527 | IoU: 0.7432
# Val   Loss: 0.0785 | Acc: 0.9888 | Dice: 0.6320 | IoU: 0.4620
#
# Epoch 68/100
# Train Loss: 0.0650 | Acc: 0.9956 | Dice: 0.8648 | IoU: 0.7619
# Val   Loss: 0.0785 | Acc: 0.9888 | Dice: 0.6380 | IoU: 0.4684
#
# Epoch 69/100
# Train Loss: 0.0654 | Acc: 0.9953 | Dice: 0.8555 | IoU: 0.7475
# Val   Loss: 0.0783 | Acc: 0.9889 | Dice: 0.6500 | IoU: 0.4815
#
# Epoch 70/100
# Train Loss: 0.0653 | Acc: 0.9953 | Dice: 0.8582 | IoU: 0.7516
# Val   Loss: 0.0783 | Acc: 0.9889 | Dice: 0.6418 | IoU: 0.4726
#
# Epoch 71/100
# Train Loss: 0.0653 | Acc: 0.9954 | Dice: 0.8581 | IoU: 0.7515
# Val   Loss: 0.0786 | Acc: 0.9889 | Dice: 0.6523 | IoU: 0.4840
#
# Epoch 72/100
# Train Loss: 0.0657 | Acc: 0.9951 | Dice: 0.8506 | IoU: 0.7401
# Val   Loss: 0.0782 | Acc: 0.9889 | Dice: 0.6406 | IoU: 0.4713
#
# Epoch 73/100
# Train Loss: 0.0649 | Acc: 0.9956 | Dice: 0.8642 | IoU: 0.7608
# Val   Loss: 0.0786 | Acc: 0.9889 | Dice: 0.6377 | IoU: 0.4681
#
# Epoch 74/100
# Train Loss: 0.0648 | Acc: 0.9957 | Dice: 0.8669 | IoU: 0.7651
# Val   Loss: 0.0791 | Acc: 0.9887 | Dice: 0.6289 | IoU: 0.4587
#
# Epoch 75/100
# Train Loss: 0.0648 | Acc: 0.9956 | Dice: 0.8655 | IoU: 0.7629
# Val   Loss: 0.0789 | Acc: 0.9888 | Dice: 0.6380 | IoU: 0.4684
#
# Epoch 76/100
# Train Loss: 0.0651 | Acc: 0.9955 | Dice: 0.8622 | IoU: 0.7578
# Val   Loss: 0.0784 | Acc: 0.9889 | Dice: 0.6362 | IoU: 0.4665
#
# Epoch 77/100
# Train Loss: 0.0665 | Acc: 0.9947 | Dice: 0.8367 | IoU: 0.7192
# Val   Loss: 0.0783 | Acc: 0.9889 | Dice: 0.6347 | IoU: 0.4649
#
# Epoch 78/100
# Train Loss: 0.0650 | Acc: 0.9955 | Dice: 0.8634 | IoU: 0.7596
# Val   Loss: 0.0785 | Acc: 0.9888 | Dice: 0.6260 | IoU: 0.4556
#
# Epoch 79/100
# Train Loss: 0.0657 | Acc: 0.9952 | Dice: 0.8523 | IoU: 0.7426
# Val   Loss: 0.0780 | Acc: 0.9889 | Dice: 0.6347 | IoU: 0.4649
#
# Epoch 80/100
# Train Loss: 0.0663 | Acc: 0.9948 | Dice: 0.8427 | IoU: 0.7281
# Val   Loss: 0.0785 | Acc: 0.9889 | Dice: 0.6407 | IoU: 0.4713
#
# Epoch 81/100
# Train Loss: 0.0643 | Acc: 0.9959 | Dice: 0.8732 | IoU: 0.7750
# Val   Loss: 0.0784 | Acc: 0.9889 | Dice: 0.6325 | IoU: 0.4625
#
# Epoch 82/100
# Train Loss: 0.0656 | Acc: 0.9951 | Dice: 0.8506 | IoU: 0.7400
# Val   Loss: 0.0780 | Acc: 0.9889 | Dice: 0.6382 | IoU: 0.4686
#
# Epoch 83/100
# Train Loss: 0.0646 | Acc: 0.9957 | Dice: 0.8684 | IoU: 0.7674
# Val   Loss: 0.0778 | Acc: 0.9890 | Dice: 0.6442 | IoU: 0.4752
#
# Epoch 84/100
# Train Loss: 0.0648 | Acc: 0.9957 | Dice: 0.8674 | IoU: 0.7658
# Val   Loss: 0.0791 | Acc: 0.9887 | Dice: 0.6286 | IoU: 0.4583
#
# Epoch 85/100
# Train Loss: 0.0648 | Acc: 0.9956 | Dice: 0.8654 | IoU: 0.7628
# Val   Loss: 0.0780 | Acc: 0.9889 | Dice: 0.6575 | IoU: 0.4897
#
# Epoch 86/100
# Train Loss: 0.0664 | Acc: 0.9947 | Dice: 0.8384 | IoU: 0.7218
# Val   Loss: 0.0785 | Acc: 0.9888 | Dice: 0.6426 | IoU: 0.4734
#
# Epoch 87/100
# Train Loss: 0.0646 | Acc: 0.9958 | Dice: 0.8696 | IoU: 0.7693
# Val   Loss: 0.0786 | Acc: 0.9889 | Dice: 0.6421 | IoU: 0.4728
#
# Epoch 88/100
# Train Loss: 0.0649 | Acc: 0.9957 | Dice: 0.8671 | IoU: 0.7655
# Val   Loss: 0.0783 | Acc: 0.9889 | Dice: 0.6367 | IoU: 0.4670
#
# Epoch 89/100
# Train Loss: 0.0650 | Acc: 0.9955 | Dice: 0.8619 | IoU: 0.7573
# Val   Loss: 0.0789 | Acc: 0.9888 | Dice: 0.6438 | IoU: 0.4747
#
# Epoch 90/100
# Train Loss: 0.0652 | Acc: 0.9953 | Dice: 0.8563 | IoU: 0.7488
# Val   Loss: 0.0785 | Acc: 0.9889 | Dice: 0.6427 | IoU: 0.4735
#
# Epoch 91/100
# Train Loss: 0.0651 | Acc: 0.9954 | Dice: 0.8593 | IoU: 0.7533
# Val   Loss: 0.0782 | Acc: 0.9889 | Dice: 0.6422 | IoU: 0.4729
#
# Epoch 92/100
# Train Loss: 0.0657 | Acc: 0.9952 | Dice: 0.8527 | IoU: 0.7433
# Val   Loss: 0.0782 | Acc: 0.9889 | Dice: 0.6342 | IoU: 0.4643
#
# Epoch 93/100
# Train Loss: 0.0642 | Acc: 0.9960 | Dice: 0.8766 | IoU: 0.7802
# Val   Loss: 0.0783 | Acc: 0.9889 | Dice: 0.6433 | IoU: 0.4741
#
# Epoch 94/100
# Train Loss: 0.0653 | Acc: 0.9954 | Dice: 0.8595 | IoU: 0.7537
# Val   Loss: 0.0790 | Acc: 0.9888 | Dice: 0.6401 | IoU: 0.4707
#
# Epoch 95/100
# Train Loss: 0.0657 | Acc: 0.9951 | Dice: 0.8497 | IoU: 0.7387
# Val   Loss: 0.0786 | Acc: 0.9888 | Dice: 0.6315 | IoU: 0.4614
#
# Epoch 96/100
# Train Loss: 0.0657 | Acc: 0.9950 | Dice: 0.8491 | IoU: 0.7378
# Val   Loss: 0.0784 | Acc: 0.9888 | Dice: 0.6337 | IoU: 0.4638
#
# Epoch 97/100
# Train Loss: 0.0647 | Acc: 0.9956 | Dice: 0.8657 | IoU: 0.7632
# Val   Loss: 0.0784 | Acc: 0.9889 | Dice: 0.6386 | IoU: 0.4691
#
# Epoch 98/100
# Train Loss: 0.0653 | Acc: 0.9953 | Dice: 0.8559 | IoU: 0.7481
# Val   Loss: 0.0779 | Acc: 0.9889 | Dice: 0.6562 | IoU: 0.4883
#
# Epoch 99/100
# Train Loss: 0.0655 | Acc: 0.9952 | Dice: 0.8547 | IoU: 0.7462
# Val   Loss: 0.0778 | Acc: 0.9889 | Dice: 0.6367 | IoU: 0.4671
#
# Epoch 100/100
# Train Loss: 0.0644 | Acc: 0.9958 | Dice: 0.8716 | IoU: 0.7725
# Val   Loss: 0.0782 | Acc: 0.9888 | Dice: 0.6284 | IoU: 0.4582
