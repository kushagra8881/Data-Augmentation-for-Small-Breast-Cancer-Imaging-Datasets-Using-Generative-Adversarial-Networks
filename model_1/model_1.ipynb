# %%
import os
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
from torchvision import transforms
import torch.nn.functional as F
from torch.nn.utils import spectral_norm
from time import time
from datetime import datetime
import json
from math import sqrt

# Configuration based on paper recommendations
SEED = 60
IMG_SIZE = 256
BATCH_SIZE = 8
LATENT_DIM = 256

# Modified Configuration
LAMBDA_GP = 5.0  # Reduced from 10
LAMBDA_PIXEL = 3.0  # Reduced from 5.0
LAMBDA_PEARSON = 5.0  # Increased from 2.0
LR = 0.0001  # Reduced from 0.0002
N_CRITIC = 3  # Reduced from 5
BASE_CHANNELS = 128  # Increased capacity
BETAS = (0.5, 0.9)  # More conservative momentum
EPOCHS = 1000

# Set seed for reproducibility
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Define normalize function outside of the transform to make it picklable
def normalize_image(x):
    return 2 * x - 1  # Normalize to [-1, 1]

# Helper: compute mean and 95% CI half-width (1.96 * std / sqrt(n))
def mean_ci(data, confidence=0.95):
    arr = np.array(data, dtype=np.float64)
    n = arr.size
    if n == 0:
        return 0.0, 0.0
    mean = arr.mean()
    if n == 1:
        return float(mean), 0.0
    # Use t-based if small n? For simplicity and because n often >=3, use normal approx with z=1.96
    se = arr.std(ddof=1) / sqrt(n)
    z = 1.96  # 95% confidence
    h = z * se
    return float(mean), float(h)

# Enhanced Dataset Class
class MedicalDataset(Dataset):
    def __init__(self, root_dir, img_size=256):
        self.image_paths = []
        self.labels = []
        self.img_size = img_size
        self.transform = transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.3),
            transforms.Lambda(normalize_image)  # Using named function instead of lambda
        ])

        # Load data with binary labels (0/1)
        for label in ['0', '1']:
            folder = os.path.join(root_dir, label)
            if os.path.exists(folder):
                for fname in os.listdir(folder):
                    if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                        self.image_paths.append(os.path.join(folder, fname))
                        self.labels.append(int(label))

    def __getitem__(self, idx):
        img = cv2.imread(self.image_paths[idx], cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (self.img_size, self.img_size))
        img = img.astype(np.float32) / 255.0  # Normalize to [0, 1]
        img = torch.tensor(img).unsqueeze(0)  # Add channel dimension -> shape [1,H,W]
        img = self.transform(img)
        return img, torch.tensor(self.labels[idx], dtype=torch.float32)

    def __len__(self):
        return len(self.image_paths)

# Residual Block for Generator (StyleGAN-inspired)
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv = nn.Sequential(
            spectral_norm(nn.Conv2d(channels, channels, 3, padding=1)),
            nn.BatchNorm2d(channels),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(channels, channels, 3, padding=1)),
            nn.BatchNorm2d(channels)
        )
        
    def forward(self, x):
        return F.leaky_relu(x + self.conv(x), 0.2)

# Enhanced Generator with Residual Connections
class MedicalGenerator(nn.Module):
    def __init__(self):
        super().__init__()
        self.init_size = IMG_SIZE // 16  # Reduced from 32 to decrease computation
        
        # More efficient latent mapping
        self.style_mapping = nn.Sequential(
            spectral_norm(nn.Linear(LATENT_DIM + 1, 512)),
            nn.LeakyReLU(0.2, inplace=True),
            spectral_norm(nn.Linear(512, 512)),
            nn.LeakyReLU(0.2, inplace=True)
        )
        
        # Initial projection with reduced channels
        self.fc = spectral_norm(nn.Linear(512, BASE_CHANNELS * 16 * self.init_size ** 2))
        
        # Upsampling blocks with optimized structure
        self.blocks = nn.ModuleList([
            self._make_block(BASE_CHANNELS*16, BASE_CHANNELS*8),
            self._make_block(BASE_CHANNELS*8, BASE_CHANNELS*4),
            self._make_block(BASE_CHANNELS*4, BASE_CHANNELS*2),
            self._make_block(BASE_CHANNELS*2, BASE_CHANNELS)
        ])
        
        # Final output with fewer layers
        self.final = nn.Sequential(
            spectral_norm(nn.Conv2d(BASE_CHANNELS, BASE_CHANNELS//2, 3, padding=1)),
            nn.LeakyReLU(0.2, inplace=True),
            spectral_norm(nn.Conv2d(BASE_CHANNELS//2, 1, 3, padding=1)),
            nn.Tanh()
        )

    def _make_block(self, in_ch, out_ch):
        return nn.Sequential(
            nn.Upsample(scale_factor=2, mode='nearest'),  # Faster upsampling
            spectral_norm(nn.Conv2d(in_ch, out_ch, 3, padding=1)),
            nn.BatchNorm2d(out_ch),
            nn.LeakyReLU(0.2, inplace=True),
            ResidualBlock(out_ch)  # Kept one residual block per scale
        )

    def forward(self, z, labels):
        style = self.style_mapping(torch.cat([z, labels.view(-1, 1)], 1))
        x = self.fc(style).view(-1, BASE_CHANNELS*16, self.init_size, self.init_size)
        
        for block in self.blocks:
            x = block(x)
            
        return self.final(x)

# Optimized Discriminator with better feature extraction
class MedicalDiscriminator(nn.Module):
    def __init__(self):
        super().__init__()
        
        # More efficient initial processing
        self.initial = nn.Sequential(
            spectral_norm(nn.Conv2d(2, BASE_CHANNELS, 4, 2, 1)),
            nn.LeakyReLU(0.2, inplace=True)
        )
        
        # Main backbone
        self.main = nn.Sequential(
            spectral_norm(nn.Conv2d(BASE_CHANNELS, BASE_CHANNELS*2, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*2),
            nn.LeakyReLU(0.2, inplace=True),

            spectral_norm(nn.Conv2d(BASE_CHANNELS*2, BASE_CHANNELS*4, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*4),
            nn.LeakyReLU(0.2, inplace=True),
            
            spectral_norm(nn.Conv2d(BASE_CHANNELS*4, BASE_CHANNELS*8, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*8),
            nn.LeakyReLU(0.2, inplace=True),
            
            spectral_norm(nn.Conv2d(BASE_CHANNELS*8, 1, 4, 1, 0))
        )

    def forward(self, img, labels):
        # More efficient label processing
        labels = labels.view(-1, 1, 1, 1).expand(-1, 1, IMG_SIZE//2, IMG_SIZE//2)  # Reduced size
        x = torch.cat([F.avg_pool2d(img, 2), labels], 1)  # Downsample image to match
        
        x = self.initial(x)
        return self.main(x).view(-1)

# Classifier for evaluating generated images
class MedicalClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        # feature extractor (ends with AdaptiveAvgPool and flatten)
        self.features = nn.Sequential(
            nn.Conv2d(1, 64, 3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 128, 3, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.Conv2d(128, 256, 3, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
        )
        # classifier head
        self.classifier_head = nn.Sequential(
            nn.Dropout(0.3),
            nn.Linear(256, 64),
            nn.LeakyReLU(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        f = self.features(x)
        return self.classifier_head(f)
    
    def get_features(self, x):
        return self.features(x)

# Structural Similarity Index (SSIM) for image quality assessment
def ssim(img1, img2, window_size=11, size_average=True):
    # Value range can be different from 0 to 255. So normalize images.
    if img1.max() > 128:
        img1 = img1 / 255.0
    if img2.max() > 128:
        img2 = img2 / 255.0
    
    if not img1.shape == img2.shape:
        raise ValueError('Input images must have the same dimensions.')
    
    # Compute means
    mu1 = F.avg_pool2d(img1, window_size, stride=1, padding=window_size//2)
    mu2 = F.avg_pool2d(img2, window_size, stride=1, padding=window_size//2)
    
    # Compute squares of means
    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1 * mu2
    
    # Compute variances and covariance
    sigma1_sq = F.avg_pool2d(img1 * img1, window_size, stride=1, padding=window_size//2) - mu1_sq
    sigma2_sq = F.avg_pool2d(img2 * img2, window_size, stride=1, padding=window_size//2) - mu2_sq
    sigma12 = F.avg_pool2d(img1 * img2, window_size, stride=1, padding=window_size//2) - mu1_mu2
    
    # SSIM constants
    C1 = 0.01 ** 2
    C2 = 0.03 ** 2
    
    # Compute SSIM
    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2))
    
    if size_average:
        return ssim_map.mean()
    else:
        return ssim_map.mean(1).mean(1).mean(1)

# Pearson Correlation Loss Function
def pearson_correlation_loss(x, y):
    """
    Computes Pearson correlation coefficient loss between two batches of images
    """
    # Flatten spatial dimensions
    x_flat = x.view(x.size(0), -1)
    y_flat = y.view(y.size(0), -1)
    
    # Compute means
    x_mean = torch.mean(x_flat, dim=1, keepdim=True)
    y_mean = torch.mean(y_flat, dim=1, keepdim=True)
    
    # Compute covariance and variances
    covariance = torch.mean((x_flat - x_mean) * (y_flat - y_mean), dim=1)
    x_var = torch.var(x_flat, dim=1)
    y_var = torch.var(y_flat, dim=1)
    
    # Compute Pearson correlation
    pearson = covariance / (torch.sqrt(x_var) * torch.sqrt(y_var) + 1e-8)
    
    # Return loss as 1 - average correlation
    return 1 - torch.mean(pearson)

# Compute Frechet Inception Distance (FID) approximation
def compute_fid_proxy(real_features, fake_features):
    """
    Simplified FID calculation since we don't have Inception network.
    This uses feature embeddings from our discriminator/classifier instead.
    """
    # Calculate mean and covariance for real and fake features
    mu1 = torch.mean(real_features, dim=0)
    sigma1 = torch.from_numpy(np.cov(real_features.cpu().numpy(), rowvar=False)).to(real_features.device)
    
    mu2 = torch.mean(fake_features, dim=0)
    sigma2 = torch.from_numpy(np.cov(fake_features.cpu().numpy(), rowvar=False)).to(fake_features.device)
    
    # Calculate squared difference between means
    diff = mu1 - mu2
    mean_diff = torch.sum(diff * diff)
    
    # Calculate matrix sqrt - approximation for FID
    # This is a simplified version - true FID uses matrix sqrt
    # Use elementwise sqrt of diag covariances approximation to avoid heavy matrix ops:
    try:
        covmean = torch.sqrt(sigma1 * sigma2 + 1e-8)
    except Exception:
        covmean = torch.sqrt((sigma1 + sigma2) / 2 + 1e-8)
    
    # Calculate trace
    # pad to square if necessary
    min_dim = min(sigma1.shape[0], sigma2.shape[0])
    trace_term = torch.trace(sigma1[:min_dim, :min_dim] + sigma2[:min_dim, :min_dim] - 2 * covmean[:min_dim, :min_dim])
    
    # FID
    fid = mean_diff + trace_term
    return fid

# Complete GAN Training System
class StableGAN:
    def __init__(self, data_folder="medical_data"):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {self.device}")
        
        # Initialize networks
        self.netG = MedicalGenerator().to(self.device)
        self.netD = MedicalDiscriminator().to(self.device)
        
        # Add classifier for quality evaluation
        self.classifier = MedicalClassifier().to(self.device)
        self.classifier_optim = optim.Adam(self.classifier.parameters(), lr=LR*0.5)
        self.classifier_criterion = nn.BCELoss()
        
        # Optimizers
        self.optimG = optim.Adam(self.netG.parameters(), lr=LR, betas=BETAS)
        self.optimD = optim.Adam(self.netD.parameters(), lr=LR, betas=BETAS)
        
        # Learning rate schedulers
        self.schedulerG = optim.lr_scheduler.ReduceLROnPlateau(self.optimG, 'min', factor=0.5, patience=30, verbose=True)
        self.schedulerD = optim.lr_scheduler.ReduceLROnPlateau(self.optimD, 'min', factor=0.5, patience=30, verbose=True)
        
        # Data loading - use num_workers=0 to avoid multiprocessing issues with lambda
        self.dataset = MedicalDataset(data_folder, img_size=IMG_SIZE)
        self.loader = DataLoader(self.dataset, BATCH_SIZE, shuffle=True, num_workers=0)
        
        # Tracking: we'll store means and CI half-widths separately for plotting convenience
        self.metrics = {
            # Means
            'd_loss_mean': [], 'g_loss_mean': [], 'pearson_mean': [], 'ssim_mean': [], 
            'fid_proxy_mean': [], 'inception_score_proxy_mean': [], 'classifier_acc_mean': [], 'psnr_mean': [], 'train_time_mean': [],
            # CI half-widths
            'd_loss_ci': [], 'g_loss_ci': [], 'pearson_ci': [], 'ssim_ci': [],
            'fid_proxy_ci': [], 'inception_score_proxy_ci': [], 'classifier_acc_ci': [], 'psnr_ci': [], 'train_time_ci': []
        }
        
        # Create fixed noise for consistent sampling
        self.fixed_z = torch.randn(8, LATENT_DIM, device=self.device)  # Increased samples
        self.fixed_labels_0 = torch.zeros(4, device=self.device)
        self.fixed_labels_1 = torch.ones(4, device=self.device)
        self.fixed_labels = torch.cat([self.fixed_labels_0, self.fixed_labels_1])
        
        # Create run directory
        self.run_dir = f"gan_run_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        os.makedirs(f"{self.run_dir}/samples", exist_ok=True)
        os.makedirs(f"{self.run_dir}/checkpoints", exist_ok=True)

    def compute_gradient_penalty(self, real_samples, fake_samples, labels):
        """Calculates the gradient penalty loss for WGAN-GP"""
        alpha = torch.rand(real_samples.size(0), 1, 1, 1, device=self.device)
        interpolates = (alpha * real_samples + (1 - alpha) * fake_samples).requires_grad_(True)
        d_interpolates = self.netD(interpolates, labels)
        
        gradients = torch.autograd.grad(
            outputs=d_interpolates,
            inputs=interpolates,
            grad_outputs=torch.ones_like(d_interpolates),
            create_graph=True,
            retain_graph=True,
        )[0]
        
        gradients = gradients.view(gradients.size(0), -1)
        gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()
        return gradient_penalty

    def train_classifier(self, real_imgs, fake_imgs, labels, steps=1):
        """Train the classifier on both real and fake images"""
        for _ in range(steps):
            self.classifier_optim.zero_grad()
            
            # Create a batch with both real and fake images
            all_imgs = torch.cat([real_imgs, fake_imgs.detach()], 0)
            all_labels = torch.cat([labels, labels], 0)
            
            # Forward pass
            pred = self.classifier(all_imgs).squeeze()
            loss = self.classifier_criterion(pred, all_labels)
            
            # Backward pass
            loss.backward()
            self.classifier_optim.step()
            
            # Calculate accuracy
            pred_binary = (pred > 0.5).float()
            acc = (pred_binary == all_labels).float().mean()
            
        return acc.item()

    def compute_psnr(self, real_imgs, fake_imgs):
        """Compute Peak Signal-to-Noise Ratio"""
        mse = F.mse_loss(fake_imgs, real_imgs)
        if mse == 0:
            return 100.0
        max_pixel = 2.0  # Since images are normalized to [-1, 1]
        psnr = 20 * torch.log10(max_pixel / torch.sqrt(mse))
        return psnr.item()

    def compute_inception_score_proxy(self, fake_imgs, eps=1e-8):
        """Compute a proxy for inception score using our classifier"""
        self.classifier.eval()
        with torch.no_grad():
            preds = self.classifier(fake_imgs).squeeze()
            # preds in [0,1], compute approximate entropy / KL-like measure
            kl_div = preds * torch.log(preds + eps) + (1 - preds) * torch.log(1 - preds + eps)
            inception_score = torch.exp(torch.mean(kl_div))
        self.classifier.train()
        return inception_score.item()

    def extract_features(self, imgs):
        """Extract features from the classifier for FID calculation"""
        with torch.no_grad():
            feats = self.classifier.get_features(imgs)
        return feats.view(feats.size(0), -1)

    def train_epoch(self, epoch):
        self.netG.train()
        self.netD.train()
        self.classifier.train()
        
        epoch_metrics = {
            'd_loss': [], 'g_loss': [], 'pearson': [], 'ssim': [], 
            'psnr': [], 'classifier_acc': []
        }
        
        epoch_start_time = time()
        
        for batch_idx, (real_imgs, labels) in enumerate(self.loader):
            real_imgs = real_imgs.to(self.device)
            labels = labels.to(self.device)
            batch_size = real_imgs.size(0)
            
            # --- Discriminator Update ---
            self.optimD.zero_grad()
            
            # Generate fake images
            z = torch.randn(batch_size, LATENT_DIM, device=self.device)
            fake_imgs = self.netG(z, labels)
            
            # Compute discriminator losses
            d_real = self.netD(real_imgs, labels)
            d_fake = self.netD(fake_imgs.detach(), labels)
            
            # Gradient penalty
            gp = self.compute_gradient_penalty(real_imgs, fake_imgs, labels)
            
            # WGAN-GP loss
            d_loss = -torch.mean(d_real) + torch.mean(d_fake) + LAMBDA_GP * gp
            d_loss.backward()
            self.optimD.step()
            
            epoch_metrics['d_loss'].append(d_loss.item())
            
            # --- Generator Update ---
            if batch_idx % N_CRITIC == 0:
                self.optimG.zero_grad()
                
                # Generate new fake images
                z = torch.randn(batch_size, LATENT_DIM, device=self.device)
                fake_imgs = self.netG(z, labels)
                
                # Adversarial loss
                g_adv = -torch.mean(self.netD(fake_imgs, labels))
                
                # Pixel-wise L1 loss
                px_loss = F.l1_loss(fake_imgs, real_imgs)
                
                # Pearson correlation loss
                pearson_loss = pearson_correlation_loss(fake_imgs, real_imgs)
                
                # Total generator loss
                g_total = g_adv + LAMBDA_PIXEL*px_loss + LAMBDA_PEARSON*pearson_loss
                g_total.backward()
                self.optimG.step()
                
                # Train classifier and compute additional metrics
                with torch.no_grad():
                    # SSIM metric
                    ssim_val = ssim(fake_imgs, real_imgs).item()
                    
                    # PSNR metric
                    psnr_val = self.compute_psnr(real_imgs, fake_imgs)
                    
                    # Store metrics
                    epoch_metrics['g_loss'].append(g_total.item())
                    epoch_metrics['pearson'].append(1 - pearson_loss.item())  # store correlation measure
                    epoch_metrics['ssim'].append(ssim_val)
                    epoch_metrics['psnr'].append(psnr_val)
                
                # Train classifier on this batch
                classifier_acc = self.train_classifier(real_imgs, fake_imgs, labels)
                epoch_metrics['classifier_acc'].append(classifier_acc)
                
            # Progress reporting (less frequent)
            if batch_idx % 10 == 0:
                if batch_idx % N_CRITIC == 0:
                    g_loss_str = f"{g_total.item():.4f}"
                else:
                    g_loss_str = "N/A"
                print(f"Epoch [{epoch}/{EPOCHS}] Batch [{batch_idx}/{len(self.loader)}] "
                      f"D_loss: {d_loss.item():.4f} G_loss: {g_loss_str}")
        
        # Compute epoch-level metrics
        epoch_time = time() - epoch_start_time
        
        # For FID & IS proxies compute across multiple random real batches to estimate CI
        K = 5  # number of bootstrap batches for fid/is proxy calculation (tuneable)
        fid_vals = []
        is_vals = []
        temp_loader = DataLoader(self.dataset, batch_size=self.fixed_z.size(0), shuffle=True, num_workers=0)
        count = 0
        for real_batch, _ in temp_loader:
            real_batch = real_batch.to(self.device)
            with torch.no_grad():
                fake_samples = self.netG(self.fixed_z, self.fixed_labels)
                fake_features = self.extract_features(fake_samples)
                real_features = self.extract_features(real_batch)
                
                fid_val = compute_fid_proxy(real_features, fake_features).item()
                is_val = self.compute_inception_score_proxy(fake_samples)
                
                fid_vals.append(fid_val)
                is_vals.append(is_val)
            count += 1
            if count >= K:
                break
        # If not enough samples found, still compute mean/ci on whatever we have
        fid_mean, fid_ci = mean_ci(fid_vals)
        is_mean, is_ci = mean_ci(is_vals)
        
        # Now compute mean+CI for per-batch metrics collected during the epoch
        d_mean, d_ci = mean_ci(epoch_metrics['d_loss'])
        g_mean, g_ci = mean_ci(epoch_metrics['g_loss'])
        pearson_mean, pearson_ci = mean_ci(epoch_metrics['pearson'])
        ssim_mean, ssim_ci = mean_ci(epoch_metrics['ssim'])
        psnr_mean, psnr_ci = mean_ci(epoch_metrics['psnr'])
        acc_mean, acc_ci = mean_ci(epoch_metrics['classifier_acc'])
        train_time_mean, train_time_ci = epoch_time, 0.0  # train time per epoch: one sample -> CI not meaningful; set 0

        # Update overall metrics (store means and CI half-widths)
        self.metrics['d_loss_mean'].append(d_mean)
        self.metrics['d_loss_ci'].append(d_ci)
        self.metrics['g_loss_mean'].append(g_mean)
        self.metrics['g_loss_ci'].append(g_ci)
        self.metrics['pearson_mean'].append(pearson_mean)
        self.metrics['pearson_ci'].append(pearson_ci)
        self.metrics['ssim_mean'].append(ssim_mean)
        self.metrics['ssim_ci'].append(ssim_ci)
        self.metrics['psnr_mean'].append(psnr_mean)
        self.metrics['psnr_ci'].append(psnr_ci)
        self.metrics['classifier_acc_mean'].append(acc_mean)
        self.metrics['classifier_acc_ci'].append(acc_ci)
        self.metrics['fid_proxy_mean'].append(fid_mean)
        self.metrics['fid_proxy_ci'].append(fid_ci)
        self.metrics['inception_score_proxy_mean'].append(is_mean)
        self.metrics['inception_score_proxy_ci'].append(is_ci)
        self.metrics['train_time_mean'].append(train_time_mean)
        self.metrics['train_time_ci'].append(train_time_ci)
        
        # Update learning rate schedulers using G/D mean losses if available (fallback safe)
        if len(self.metrics['g_loss_mean']) > 0:
            try:
                self.schedulerG.step(self.metrics['g_loss_mean'][-1])
            except Exception:
                pass
        if len(self.metrics['d_loss_mean']) > 0:
            try:
                self.schedulerD.step(self.metrics['d_loss_mean'][-1])
            except Exception:
                pass
        
        # Print epoch summary including CI
        print(f"\nEpoch {epoch} completed in {epoch_time:.2f}s | "
              f"FID: {fid_mean:.4f} ± {fid_ci:.4f} | IS: {is_mean:.4f} ± {is_ci:.4f} | "
              f"SSIM: {ssim_mean:.4f} ± {ssim_ci:.4f} | "
              f"PSNR: {psnr_mean:.4f} ± {psnr_ci:.4f} | "
              f"Acc: {acc_mean:.4f} ± {acc_ci:.4f}\n")
        
        # Save metrics after each epoch (JSON serializable)
        serializable_metrics = {k: [float(x) for x in v] for k, v in self.metrics.items()}
        with open(f"{self.run_dir}/metrics.json", 'w') as f:
            json.dump(serializable_metrics, f, indent=2)
        
        # Plot training curves (means only) every 10 epochs
        if epoch % 10 == 0:
            self.plot_metrics(epoch)

    def plot_metrics(self, epoch):
        """Plot and save training metrics (means only)"""
        fig, axs = plt.subplots(4, 2, figsize=(12, 18))
        
        # Plot losses
        axs[0, 0].plot(self.metrics['d_loss_mean'], label='D Loss (mean)')
        axs[0, 0].plot(self.metrics['g_loss_mean'], label='G Loss (mean)')
        axs[0, 0].set_title('Losses (mean)')
        axs[0, 0].legend()
        
        # Plot image quality metrics (pearson and ssim)
        axs[0, 1].plot(self.metrics['pearson_mean'], label='Pearson (mean)')
        axs[0, 1].plot(self.metrics['ssim_mean'], label='SSIM (mean)')
        axs[0, 1].set_title('Image Quality (mean)')
        axs[0, 1].legend()
        
        # Plot FID and Inception Score
        axs[1, 0].plot(self.metrics['fid_proxy_mean'], label='FID Proxy (mean)')
        axs[1, 0].set_title('FID Proxy (lower is better)')
        axs[1, 1].plot(self.metrics['inception_score_proxy_mean'], label='IS Proxy (mean)')
        axs[1, 1].set_title('Inception Score Proxy (mean)')
        
        # Plot PSNR and classifier accuracy
        axs[2, 0].plot(self.metrics['psnr_mean'], label='PSNR (mean)')
        axs[2, 0].set_title('PSNR (mean)')
        axs[2, 1].plot(self.metrics['classifier_acc_mean'], label='Classifier Acc (mean)')
        axs[2, 1].set_title('Classifier Accuracy (mean)')
        
        # Plot training time (mean)
        axs[3, 0].plot(self.metrics['train_time_mean'], label='Train Time (s)')
        axs[3, 0].set_title('Epoch Training Time (s)')
        axs[3, 1].axis('off')
        
        plt.tight_layout()
        plt.savefig(f"{self.run_dir}/metrics_epoch_{epoch}.png")
        plt.close()

    def save_samples(self, epoch):
        """Saves generated samples for both labels"""
        self.netG.eval()
        
        with torch.no_grad():
            # Generate images using fixed noise
            gen_imgs = self.netG(self.fixed_z, self.fixed_labels)
            
            # Create a grid of images
            fig, axs = plt.subplots(2, 4, figsize=(16, 8))
            for i in range(8):
                row = i // 4
                col = i % 4
                img = gen_imgs[i].cpu().squeeze().numpy()
                img = (img + 1) * 0.5  # Convert from [-1,1] to [0,1]
                axs[row, col].imshow(img, cmap='gray')
                axs[row, col].set_title(f"Label: {int(self.fixed_labels[i].item())}")
                axs[row, col].axis('off')
            
            plt.tight_layout()
            plt.savefig(f"{self.run_dir}/samples/epoch_{epoch}_grid.png")
            plt.close()
            
            # Also save individual images
            for i, (img, label) in enumerate(zip(gen_imgs, self.fixed_labels)):
                img = img.cpu().squeeze().numpy()
                img = (img + 1) * 127.5  # Convert from [-1,1] to [0,255]
                img = img.astype(np.uint8)
                cv2.imwrite(f"{self.run_dir}/samples/epoch_{epoch}_label_{int(label.item())}_sample_{i}.png", img)
        
        self.netG.train()

    def save_checkpoint(self, epoch):
        """Save model checkpoint"""
        torch.save({
            'epoch': epoch,
            'generator': self.netG.state_dict(),
            'discriminator': self.netD.state_dict(),
            'classifier': self.classifier.state_dict(),
            'optimG': self.optimG.state_dict(),
            'optimD': self.optimD.state_dict(),
            'schedulerG': self.schedulerG.state_dict(),
            'schedulerD': self.schedulerD.state_dict(),
            'metrics': self.metrics
        }, f"{self.run_dir}/checkpoints/checkpoint_epoch_{epoch}.pth")

    def train(self):
        for epoch in range(1, EPOCHS + 1):
            self.train_epoch(epoch)
            
            # Save checkpoint every 50 epochs
            if epoch % 50 == 0:
                self.save_checkpoint(epoch)
                print(f"Saved checkpoint for epoch {epoch}")
            
            # Save samples every 200 epochs
            if epoch % 200 == 0:
                self.save_samples(epoch)
                print(f"Saved samples for epoch {epoch}")
        
        # Final save
        torch.save({
            'generator': self.netG.state_dict(),
            'discriminator': self.netD.state_dict(),
            'metrics': self.metrics
        }, os.path.join(self.run_dir, "gan_final_1.pth"))
        print("Training completed and final model saved.")

if __name__ == "__main__":
    gan = StableGAN()
    gan.train()
# Out:
# Using device: cuda
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/1000] Batch [0/25] D_loss: 206.4836 G_loss: 7.0467
# Epoch [1/1000] Batch [10/25] D_loss: 0.8205 G_loss: N/A
# Epoch [1/1000] Batch [20/25] D_loss: -0.4414 G_loss: N/A
#
# Epoch 1 completed in 58.63s | FID: 0.1843 | IS: 0.5008 | SSIM: 0.0422 | PSNR: 9.6806 | Acc: 0.4889
#
# Epoch [2/1000] Batch [0/25] D_loss: -0.0793 G_loss: 4.7860
# Epoch [2/1000] Batch [10/25] D_loss: 0.5249 G_loss: N/A
# Epoch [2/1000] Batch [20/25] D_loss: -0.5123 G_loss: N/A
#
# Epoch 2 completed in 60.13s | FID: 0.5937 | IS: 0.5008 | SSIM: 0.0518 | PSNR: 11.0911 | Acc: 0.4042
#
# Epoch [3/1000] Batch [0/25] D_loss: -0.1792 G_loss: 4.3594
# Epoch [3/1000] Batch [10/25] D_loss: -0.3199 G_loss: N/A
# Epoch [3/1000] Batch [20/25] D_loss: -1.1326 G_loss: N/A
#
# Epoch 3 completed in 60.56s | FID: 0.8292 | IS: 0.5034 | SSIM: 0.0633 | PSNR: 12.3194 | Acc: 0.6236
#
# Epoch [4/1000] Batch [0/25] D_loss: -0.3547 G_loss: 3.9328
# Epoch [4/1000] Batch [10/25] D_loss: -0.3309 G_loss: N/A
# Epoch [4/1000] Batch [20/25] D_loss: -0.8311 G_loss: N/A
#
# Epoch 4 completed in 58.19s | FID: 0.7256 | IS: 0.5001 | SSIM: 0.0599 | PSNR: 12.4871 | Acc: 0.5417
#
# Epoch [5/1000] Batch [0/25] D_loss: -0.2723 G_loss: 3.8169
# Epoch [5/1000] Batch [10/25] D_loss: -1.1679 G_loss: N/A
# Epoch [5/1000] Batch [20/25] D_loss: -1.8261 G_loss: N/A
#
# Epoch 5 completed in 61.08s | FID: 0.9539 | IS: 0.5076 | SSIM: 0.0560 | PSNR: 12.6750 | Acc: 0.4750
#
# Epoch [6/1000] Batch [0/25] D_loss: -1.1571 G_loss: 4.8327
# Epoch [6/1000] Batch [10/25] D_loss: -0.8774 G_loss: N/A
# Epoch [6/1000] Batch [20/25] D_loss: -1.5017 G_loss: N/A
#
# Epoch 6 completed in 63.50s | FID: 1.2691 | IS: 0.5048 | SSIM: 0.0557 | PSNR: 13.0950 | Acc: 0.5653
#
# Epoch [7/1000] Batch [0/25] D_loss: -1.1294 G_loss: 5.0164
# Epoch [7/1000] Batch [10/25] D_loss: -0.7131 G_loss: N/A
# Epoch [7/1000] Batch [20/25] D_loss: -1.6247 G_loss: N/A
#
# Epoch 7 completed in 62.48s | FID: 1.9322 | IS: 0.5001 | SSIM: 0.0608 | PSNR: 12.6940 | Acc: 0.5806
#
# Epoch [8/1000] Batch [0/25] D_loss: -1.8798 G_loss: 5.6539
# Epoch [8/1000] Batch [10/25] D_loss: -1.1454 G_loss: N/A
# Epoch [8/1000] Batch [20/25] D_loss: -2.0078 G_loss: N/A
#
# Epoch 8 completed in 63.85s | FID: 1.7887 | IS: 0.5026 | SSIM: 0.0655 | PSNR: 12.7138 | Acc: 0.5319
#
# Epoch [9/1000] Batch [0/25] D_loss: -1.7909 G_loss: 6.0939
# Epoch [9/1000] Batch [10/25] D_loss: -1.6385 G_loss: N/A
# Epoch [9/1000] Batch [20/25] D_loss: -1.6901 G_loss: N/A
#
# Epoch 9 completed in 64.50s | FID: 2.9007 | IS: 0.5002 | SSIM: 0.0549 | PSNR: 12.1861 | Acc: 0.6028
#
# Epoch [10/1000] Batch [0/25] D_loss: -0.9133 G_loss: 5.2423
# Epoch [10/1000] Batch [10/25] D_loss: -1.1351 G_loss: N/A
# Epoch [10/1000] Batch [20/25] D_loss: -1.4443 G_loss: N/A
#
# Epoch 10 completed in 58.94s | FID: 2.1356 | IS: 0.5000 | SSIM: 0.0571 | PSNR: 12.2865 | Acc: 0.5917
#
# Epoch [11/1000] Batch [0/25] D_loss: -1.2200 G_loss: 5.5084
# Epoch [11/1000] Batch [10/25] D_loss: -1.9846 G_loss: N/A
# Epoch [11/1000] Batch [20/25] D_loss: -1.5308 G_loss: N/A
#
# Epoch 11 completed in 60.92s | FID: 2.4795 | IS: 0.5005 | SSIM: 0.0546 | PSNR: 12.3271 | Acc: 0.5903
#
# Epoch [12/1000] Batch [0/25] D_loss: -1.2402 G_loss: 6.0274
# Epoch [12/1000] Batch [10/25] D_loss: -1.2613 G_loss: N/A
# Epoch [12/1000] Batch [20/25] D_loss: -1.7125 G_loss: N/A
#
# Epoch 12 completed in 65.86s | FID: 2.9470 | IS: 0.5031 | SSIM: 0.0572 | PSNR: 12.4865 | Acc: 0.5708
#
# Epoch [13/1000] Batch [0/25] D_loss: -1.2973 G_loss: 5.5082
# Epoch [13/1000] Batch [10/25] D_loss: -1.9648 G_loss: N/A
# Epoch [13/1000] Batch [20/25] D_loss: -2.4176 G_loss: N/A
#
# Epoch 13 completed in 67.41s | FID: 2.4018 | IS: 0.5015 | SSIM: 0.0635 | PSNR: 12.5805 | Acc: 0.6208
#
# Epoch [14/1000] Batch [0/25] D_loss: -1.1593 G_loss: 4.4889
# Epoch [14/1000] Batch [10/25] D_loss: -0.6312 G_loss: N/A
# Epoch [14/1000] Batch [20/25] D_loss: -1.7616 G_loss: N/A
#
# Epoch 14 completed in 63.43s | FID: 1.7732 | IS: 0.5000 | SSIM: 0.0629 | PSNR: 12.4691 | Acc: 0.5306
#
# Epoch [15/1000] Batch [0/25] D_loss: -1.2573 G_loss: 5.5023
# Epoch [15/1000] Batch [10/25] D_loss: -1.2772 G_loss: N/A
# Epoch [15/1000] Batch [20/25] D_loss: -1.8513 G_loss: N/A
#
# Epoch 15 completed in 63.92s | FID: 1.8804 | IS: 0.5010 | SSIM: 0.0579 | PSNR: 12.0974 | Acc: 0.5458
#
# Epoch [16/1000] Batch [0/25] D_loss: -1.5710 G_loss: 6.0830
# Epoch [16/1000] Batch [10/25] D_loss: -1.1940 G_loss: N/A
# Epoch [16/1000] Batch [20/25] D_loss: -2.1317 G_loss: N/A
#
# Epoch 16 completed in 69.02s | FID: 2.7922 | IS: 0.5133 | SSIM: 0.0675 | PSNR: 12.5631 | Acc: 0.6236
#
# Epoch [17/1000] Batch [0/25] D_loss: -1.4882 G_loss: 5.8989
# Epoch [17/1000] Batch [10/25] D_loss: -1.2263 G_loss: N/A
# Epoch [17/1000] Batch [20/25] D_loss: -2.0344 G_loss: N/A
#
# Epoch 17 completed in 69.39s | FID: 2.2353 | IS: 0.5020 | SSIM: 0.0543 | PSNR: 12.1759 | Acc: 0.5972
#
# Epoch [18/1000] Batch [0/25] D_loss: -1.5215 G_loss: 6.5066
# Epoch [18/1000] Batch [10/25] D_loss: -2.3786 G_loss: N/A
# Epoch [18/1000] Batch [20/25] D_loss: -2.2427 G_loss: N/A
#
# Epoch 18 completed in 68.68s | FID: 1.6455 | IS: 0.5001 | SSIM: 0.0657 | PSNR: 12.6302 | Acc: 0.6264
#
# Epoch [19/1000] Batch [0/25] D_loss: -1.7303 G_loss: 5.3075
# Epoch [19/1000] Batch [10/25] D_loss: -1.2685 G_loss: N/A
# Epoch [19/1000] Batch [20/25] D_loss: -2.2804 G_loss: N/A
#
# Epoch 19 completed in 66.62s | FID: 2.5857 | IS: 0.5022 | SSIM: 0.0639 | PSNR: 12.8046 | Acc: 0.5722
#
# Epoch [20/1000] Batch [0/25] D_loss: -1.2622 G_loss: 6.2036
# Epoch [20/1000] Batch [10/25] D_loss: -2.1633 G_loss: N/A
# Epoch [20/1000] Batch [20/25] D_loss: -2.1687 G_loss: N/A
#
# Epoch 20 completed in 69.14s | FID: 1.5692 | IS: 0.5005 | SSIM: 0.0616 | PSNR: 12.4852 | Acc: 0.5556
#
# Epoch [21/1000] Batch [0/25] D_loss: -1.9975 G_loss: 6.7216
# Epoch [21/1000] Batch [10/25] D_loss: -1.5651 G_loss: N/A
# Epoch [21/1000] Batch [20/25] D_loss: -1.5595 G_loss: N/A
#
# Epoch 21 completed in 70.15s | FID: 1.3376 | IS: 0.5007 | SSIM: 0.0597 | PSNR: 12.5259 | Acc: 0.6250
#
# Epoch [22/1000] Batch [0/25] D_loss: -1.6505 G_loss: 6.5152
# Epoch [22/1000] Batch [10/25] D_loss: -1.7063 G_loss: N/A
# Epoch [22/1000] Batch [20/25] D_loss: -2.2268 G_loss: N/A
#
# Epoch 22 completed in 69.02s | FID: 3.4366 | IS: 0.5000 | SSIM: 0.0596 | PSNR: 12.4868 | Acc: 0.5361
#
# Epoch [23/1000] Batch [0/25] D_loss: -2.4829 G_loss: 6.4835
# Epoch [23/1000] Batch [10/25] D_loss: -2.0395 G_loss: N/A
# Epoch [23/1000] Batch [20/25] D_loss: -2.0814 G_loss: N/A
#
# Epoch 23 completed in 70.08s | FID: 0.8934 | IS: 0.5000 | SSIM: 0.0636 | PSNR: 12.6648 | Acc: 0.5347
#
# Epoch [24/1000] Batch [0/25] D_loss: -1.4356 G_loss: 6.6583
# Epoch [24/1000] Batch [10/25] D_loss: -1.7792 G_loss: N/A
# Epoch [24/1000] Batch [20/25] D_loss: -2.1974 G_loss: N/A
#
# Epoch 24 completed in 64.61s | FID: 2.1345 | IS: 0.5000 | SSIM: 0.0662 | PSNR: 13.0595 | Acc: 0.5806
#
# Epoch [25/1000] Batch [0/25] D_loss: -1.5151 G_loss: 5.9890
# Epoch [25/1000] Batch [10/25] D_loss: -0.4990 G_loss: N/A
# Epoch [25/1000] Batch [20/25] D_loss: -2.7868 G_loss: N/A
#
# Epoch 25 completed in 62.50s | FID: 3.2847 | IS: 0.5001 | SSIM: 0.0615 | PSNR: 12.5087 | Acc: 0.5972
#
# Epoch [26/1000] Batch [0/25] D_loss: -1.6412 G_loss: 5.5665
# Epoch [26/1000] Batch [10/25] D_loss: -1.9473 G_loss: N/A
# Epoch [26/1000] Batch [20/25] D_loss: -2.1572 G_loss: N/A
#
# Epoch 26 completed in 64.88s | FID: 2.3883 | IS: 0.5006 | SSIM: 0.0660 | PSNR: 12.6630 | Acc: 0.6431
#
# Epoch [27/1000] Batch [0/25] D_loss: -2.1491 G_loss: 6.5009
# Epoch [27/1000] Batch [10/25] D_loss: -1.9567 G_loss: N/A
# Epoch [27/1000] Batch [20/25] D_loss: -3.0363 G_loss: N/A
#
# Epoch 27 completed in 63.09s | FID: 2.7426 | IS: 0.5000 | SSIM: 0.0687 | PSNR: 13.0120 | Acc: 0.5528
#
# Epoch [28/1000] Batch [0/25] D_loss: -1.6129 G_loss: 6.0996
# Epoch [28/1000] Batch [10/25] D_loss: -1.8441 G_loss: N/A
# Epoch [28/1000] Batch [20/25] D_loss: -2.2708 G_loss: N/A
#
# Epoch 28 completed in 63.45s | FID: 4.3621 | IS: 0.5063 | SSIM: 0.0644 | PSNR: 12.5506 | Acc: 0.5694
#
# Epoch [29/1000] Batch [0/25] D_loss: -1.1546 G_loss: 6.9767
# Epoch [29/1000] Batch [10/25] D_loss: -0.8812 G_loss: N/A
# Epoch [29/1000] Batch [20/25] D_loss: -1.9347 G_loss: N/A
#
# Epoch 29 completed in 63.74s | FID: 1.9314 | IS: 0.5017 | SSIM: 0.0579 | PSNR: 12.3072 | Acc: 0.6083
#
# Epoch [30/1000] Batch [0/25] D_loss: -1.7377 G_loss: 6.5236
# Epoch [30/1000] Batch [10/25] D_loss: -2.3117 G_loss: N/A
# Epoch [30/1000] Batch [20/25] D_loss: -2.1107 G_loss: N/A
#
# Epoch 30 completed in 63.95s | FID: 3.1028 | IS: 0.5006 | SSIM: 0.0641 | PSNR: 12.7188 | Acc: 0.5597
#
# Epoch [31/1000] Batch [0/25] D_loss: -2.0134 G_loss: 6.5794
# Epoch [31/1000] Batch [10/25] D_loss: -2.2480 G_loss: N/A
# Epoch [31/1000] Batch [20/25] D_loss: -2.0153 G_loss: N/A
#
# Epoch 31 completed in 64.13s | FID: 1.7711 | IS: 0.5001 | SSIM: 0.0677 | PSNR: 12.7191 | Acc: 0.5847
#
# Epoch [32/1000] Batch [0/25] D_loss: -2.3754 G_loss: 6.2480
# Epoch [32/1000] Batch [10/25] D_loss: -2.1464 G_loss: N/A
# Epoch [32/1000] Batch [20/25] D_loss: -2.5416 G_loss: N/A
#
# Epoch 32 completed in 63.50s | FID: 2.1161 | IS: 0.5000 | SSIM: 0.0632 | PSNR: 12.7397 | Acc: 0.5500
#
# Epoch [33/1000] Batch [0/25] D_loss: -2.3534 G_loss: 6.8437
# Epoch [33/1000] Batch [10/25] D_loss: -2.3377 G_loss: N/A
# Epoch [33/1000] Batch [20/25] D_loss: -2.1843 G_loss: N/A
#
# Epoch 33 completed in 63.13s | FID: 1.3103 | IS: 0.5044 | SSIM: 0.0633 | PSNR: 12.6934 | Acc: 0.5569
#
# Epoch [34/1000] Batch [0/25] D_loss: -2.2156 G_loss: 6.4887
# Epoch [34/1000] Batch [10/25] D_loss: -1.6364 G_loss: N/A
# Epoch [34/1000] Batch [20/25] D_loss: -1.8680 G_loss: N/A
#
# Epoch 34 completed in 65.52s | FID: 0.2895 | IS: 0.5001 | SSIM: 0.0607 | PSNR: 12.1836 | Acc: 0.5833
#
# Epoch [35/1000] Batch [0/25] D_loss: -1.8286 G_loss: 7.8196
# Epoch [35/1000] Batch [10/25] D_loss: -2.7315 G_loss: N/A
# Epoch [35/1000] Batch [20/25] D_loss: -3.3593 G_loss: N/A
#
# Epoch 35 completed in 64.73s | FID: 1.3201 | IS: 0.5001 | SSIM: 0.0659 | PSNR: 12.7579 | Acc: 0.5847
#
# Epoch [36/1000] Batch [0/25] D_loss: -2.7251 G_loss: 6.6086
# Epoch [36/1000] Batch [10/25] D_loss: -2.5725 G_loss: N/A
# Epoch [36/1000] Batch [20/25] D_loss: -3.6539 G_loss: N/A
#
# Epoch 36 completed in 63.50s | FID: 6.7348 | IS: 0.5012 | SSIM: 0.0669 | PSNR: 13.2054 | Acc: 0.6111
#
# Epoch [37/1000] Batch [0/25] D_loss: -2.7749 G_loss: 7.6529
# Epoch [37/1000] Batch [10/25] D_loss: -2.9545 G_loss: N/A
# Epoch [37/1000] Batch [20/25] D_loss: -3.3431 G_loss: N/A
#
# Epoch 37 completed in 65.56s | FID: 4.7946 | IS: 0.5004 | SSIM: 0.0628 | PSNR: 12.9356 | Acc: 0.6264
#
# Epoch [38/1000] Batch [0/25] D_loss: -2.9012 G_loss: 7.3473
# Epoch [38/1000] Batch [10/25] D_loss: -2.8937 G_loss: N/A
# Epoch [38/1000] Batch [20/25] D_loss: -2.6212 G_loss: N/A
#
# Epoch 38 completed in 65.77s | FID: 1.0661 | IS: 0.5001 | SSIM: 0.0647 | PSNR: 12.9915 | Acc: 0.5306
#
# Epoch [39/1000] Batch [0/25] D_loss: -2.7569 G_loss: 7.7843
# Epoch [39/1000] Batch [10/25] D_loss: -2.4918 G_loss: N/A
# Epoch [39/1000] Batch [20/25] D_loss: -3.1838 G_loss: N/A
#
# Epoch 39 completed in 64.28s | FID: 4.2481 | IS: 0.5000 | SSIM: 0.0657 | PSNR: 12.8191 | Acc: 0.5250
#
# Epoch [40/1000] Batch [0/25] D_loss: -2.6943 G_loss: 6.1887
# Epoch [40/1000] Batch [10/25] D_loss: -2.7382 G_loss: N/A
# Epoch [40/1000] Batch [20/25] D_loss: -2.4634 G_loss: N/A
#
# Epoch 40 completed in 63.79s | FID: 3.4408 | IS: 0.5003 | SSIM: 0.0664 | PSNR: 12.9700 | Acc: 0.6042
#
# Epoch [41/1000] Batch [0/25] D_loss: -3.0743 G_loss: 7.1214
# Epoch [41/1000] Batch [10/25] D_loss: -2.4333 G_loss: N/A
# Epoch [41/1000] Batch [20/25] D_loss: -3.0239 G_loss: N/A
#
# Epoch 41 completed in 64.64s | FID: 2.5867 | IS: 0.5001 | SSIM: 0.0681 | PSNR: 13.1318 | Acc: 0.5458
#
# Epoch [42/1000] Batch [0/25] D_loss: -2.5852 G_loss: 6.8781
# Epoch [42/1000] Batch [10/25] D_loss: -3.0751 G_loss: N/A
# Epoch [42/1000] Batch [20/25] D_loss: -2.7846 G_loss: N/A
#
# Epoch 42 completed in 64.58s | FID: 2.3395 | IS: 0.5002 | SSIM: 0.0636 | PSNR: 13.0142 | Acc: 0.6181
#
# Epoch [43/1000] Batch [0/25] D_loss: -2.1333 G_loss: 7.8791
# Epoch [43/1000] Batch [10/25] D_loss: -2.7673 G_loss: N/A
# Epoch [43/1000] Batch [20/25] D_loss: -3.7433 G_loss: N/A
#
# Epoch 43 completed in 64.17s | FID: 1.7399 | IS: 0.5001 | SSIM: 0.0649 | PSNR: 13.0024 | Acc: 0.5542
#
# Epoch [44/1000] Batch [0/25] D_loss: -2.8129 G_loss: 7.0659
# Epoch [44/1000] Batch [10/25] D_loss: -3.1496 G_loss: N/A
# Epoch [44/1000] Batch [20/25] D_loss: -2.6981 G_loss: N/A
#
# Epoch 44 completed in 65.51s | FID: 3.5747 | IS: 0.5001 | SSIM: 0.0647 | PSNR: 12.7829 | Acc: 0.6069
#
# Epoch [45/1000] Batch [0/25] D_loss: -2.2716 G_loss: 7.1535
# Epoch [45/1000] Batch [10/25] D_loss: -2.7234 G_loss: N/A
# Epoch [45/1000] Batch [20/25] D_loss: -2.7143 G_loss: N/A
#
# Epoch 45 completed in 65.68s | FID: 6.3195 | IS: 0.5004 | SSIM: 0.0624 | PSNR: 12.9966 | Acc: 0.5556
#
# Epoch [46/1000] Batch [0/25] D_loss: -2.7758 G_loss: 7.9981
# Epoch [46/1000] Batch [10/25] D_loss: -2.9008 G_loss: N/A
# Epoch [46/1000] Batch [20/25] D_loss: -2.4859 G_loss: N/A
#
# Epoch 46 completed in 64.65s | FID: 5.3639 | IS: 0.5000 | SSIM: 0.0616 | PSNR: 12.7226 | Acc: 0.6181
#
# Epoch [47/1000] Batch [0/25] D_loss: -3.0946 G_loss: 7.7223
# Epoch [47/1000] Batch [10/25] D_loss: -2.5204 G_loss: N/A
# Epoch [47/1000] Batch [20/25] D_loss: -3.0262 G_loss: N/A
#
# Epoch 47 completed in 64.91s | FID: 2.4020 | IS: 0.5001 | SSIM: 0.0585 | PSNR: 12.6039 | Acc: 0.5556
#
# Epoch [48/1000] Batch [0/25] D_loss: -3.1411 G_loss: 8.1745
# Epoch [48/1000] Batch [10/25] D_loss: -2.2135 G_loss: N/A
# Epoch [48/1000] Batch [20/25] D_loss: -2.6965 G_loss: N/A
#
# Epoch 48 completed in 64.98s | FID: 2.2949 | IS: 0.5000 | SSIM: 0.0628 | PSNR: 12.8529 | Acc: 0.5917
#
# Epoch [49/1000] Batch [0/25] D_loss: -2.6404 G_loss: 7.9951
# Epoch [49/1000] Batch [10/25] D_loss: -1.8781 G_loss: N/A
# Epoch [49/1000] Batch [20/25] D_loss: -2.5182 G_loss: N/A
#
# Epoch 49 completed in 65.28s | FID: 1.6984 | IS: 0.5001 | SSIM: 0.0632 | PSNR: 12.6720 | Acc: 0.5764
#
# Epoch [50/1000] Batch [0/25] D_loss: -2.6527 G_loss: 8.2609
# Epoch [50/1000] Batch [10/25] D_loss: -2.7877 G_loss: N/A
# Epoch [50/1000] Batch [20/25] D_loss: -2.7307 G_loss: N/A
#
# Epoch 50 completed in 62.93s | FID: 5.1569 | IS: 0.5003 | SSIM: 0.0657 | PSNR: 12.9833 | Acc: 0.5847
#
# Epoch [51/1000] Batch [0/25] D_loss: -2.8518 G_loss: 7.8758
# Epoch [51/1000] Batch [10/25] D_loss: -2.8240 G_loss: N/A
# Epoch [51/1000] Batch [20/25] D_loss: -2.9101 G_loss: N/A
#
# Epoch 51 completed in 62.24s | FID: 2.8128 | IS: 0.5001 | SSIM: 0.0644 | PSNR: 12.9832 | Acc: 0.6514
#
# Epoch [52/1000] Batch [0/25] D_loss: -3.1417 G_loss: 8.2890
# Epoch [52/1000] Batch [10/25] D_loss: -2.6178 G_loss: N/A
# Epoch [52/1000] Batch [20/25] D_loss: -2.9503 G_loss: N/A
#
# Epoch 52 completed in 63.49s | FID: 0.7922 | IS: 0.5001 | SSIM: 0.0659 | PSNR: 12.9524 | Acc: 0.5819
#
# Epoch [53/1000] Batch [0/25] D_loss: -2.7784 G_loss: 7.4712
# Epoch [53/1000] Batch [10/25] D_loss: -3.0985 G_loss: N/A
# Epoch [53/1000] Batch [20/25] D_loss: -3.2262 G_loss: N/A
#
# Epoch 53 completed in 64.78s | FID: 3.2235 | IS: 0.5010 | SSIM: 0.0665 | PSNR: 12.9816 | Acc: 0.6542
#
# Epoch [54/1000] Batch [0/25] D_loss: -2.2441 G_loss: 8.5603
# Epoch [54/1000] Batch [10/25] D_loss: -2.3827 G_loss: N/A
# Epoch [54/1000] Batch [20/25] D_loss: -2.9362 G_loss: N/A
#
# Epoch 54 completed in 64.65s | FID: 1.2151 | IS: 0.5003 | SSIM: 0.0547 | PSNR: 12.8567 | Acc: 0.6361
#
# Epoch [55/1000] Batch [0/25] D_loss: -2.8309 G_loss: 8.1811
# Epoch [55/1000] Batch [10/25] D_loss: -2.5599 G_loss: N/A
# Epoch [55/1000] Batch [20/25] D_loss: -2.4869 G_loss: N/A
#
# Epoch 55 completed in 66.45s | FID: 5.7387 | IS: 0.5001 | SSIM: 0.0613 | PSNR: 12.8336 | Acc: 0.6292
#
# Epoch [56/1000] Batch [0/25] D_loss: -1.8389 G_loss: 7.6877
# Epoch [56/1000] Batch [10/25] D_loss: -2.2596 G_loss: N/A
# Epoch [56/1000] Batch [20/25] D_loss: -2.6774 G_loss: N/A
#
# Epoch 56 completed in 66.29s | FID: 5.5666 | IS: 0.5007 | SSIM: 0.0690 | PSNR: 12.8367 | Acc: 0.5833
#
# Epoch [57/1000] Batch [0/25] D_loss: -2.5208 G_loss: 8.2370
# Epoch [57/1000] Batch [10/25] D_loss: -3.1403 G_loss: N/A
# Epoch [57/1000] Batch [20/25] D_loss: -2.9093 G_loss: N/A
#
# Epoch 57 completed in 66.20s | FID: 1.5566 | IS: 0.5005 | SSIM: 0.0619 | PSNR: 12.7770 | Acc: 0.6083
#
# Epoch [58/1000] Batch [0/25] D_loss: -2.3204 G_loss: 7.6058
# Epoch [58/1000] Batch [10/25] D_loss: -2.7211 G_loss: N/A
# Epoch [58/1000] Batch [20/25] D_loss: -3.2255 G_loss: N/A
#
# Epoch 58 completed in 65.79s | FID: 5.5553 | IS: 0.5006 | SSIM: 0.0622 | PSNR: 13.1300 | Acc: 0.5972
#
# Epoch [59/1000] Batch [0/25] D_loss: -2.4559 G_loss: 8.2193
# Epoch [59/1000] Batch [10/25] D_loss: -2.3426 G_loss: N/A
# Epoch [59/1000] Batch [20/25] D_loss: -2.4588 G_loss: N/A
#
# Epoch 59 completed in 63.95s | FID: 2.7802 | IS: 0.5003 | SSIM: 0.0608 | PSNR: 12.7183 | Acc: 0.6292
#
# Epoch [60/1000] Batch [0/25] D_loss: -2.3235 G_loss: 7.9851
# Epoch [60/1000] Batch [10/25] D_loss: -3.0544 G_loss: N/A
# Epoch [60/1000] Batch [20/25] D_loss: -2.2982 G_loss: N/A
#
# Epoch 60 completed in 66.95s | FID: 6.7905 | IS: 0.5009 | SSIM: 0.0614 | PSNR: 12.8980 | Acc: 0.6403
#
# Epoch [61/1000] Batch [0/25] D_loss: -2.5494 G_loss: 7.8051
# Epoch [61/1000] Batch [10/25] D_loss: -3.0557 G_loss: N/A
# Epoch [61/1000] Batch [20/25] D_loss: -3.1887 G_loss: N/A
#
# Epoch 61 completed in 63.86s | FID: 3.4633 | IS: 0.5011 | SSIM: 0.0690 | PSNR: 13.1586 | Acc: 0.5875
#
# Epoch [62/1000] Batch [0/25] D_loss: -2.9857 G_loss: 7.8602
# Epoch [62/1000] Batch [10/25] D_loss: -3.2693 G_loss: N/A
# Epoch [62/1000] Batch [20/25] D_loss: -2.8520 G_loss: N/A
#
# Epoch 62 completed in 65.31s | FID: 2.9688 | IS: 0.5003 | SSIM: 0.0665 | PSNR: 12.9664 | Acc: 0.5597
#
# Epoch [63/1000] Batch [0/25] D_loss: -3.1706 G_loss: 8.0568
# Epoch [63/1000] Batch [10/25] D_loss: -2.4222 G_loss: N/A
# Epoch [63/1000] Batch [20/25] D_loss: -2.9832 G_loss: N/A
#
# Epoch 63 completed in 66.57s | FID: 3.3941 | IS: 0.5002 | SSIM: 0.0643 | PSNR: 12.9533 | Acc: 0.6194
#
# Epoch [64/1000] Batch [0/25] D_loss: -1.9363 G_loss: 7.8581
# Epoch [64/1000] Batch [10/25] D_loss: -1.7857 G_loss: N/A
# Epoch [64/1000] Batch [20/25] D_loss: -2.5642 G_loss: N/A
#
# Epoch 64 completed in 66.27s | FID: 4.3503 | IS: 0.5002 | SSIM: 0.0577 | PSNR: 12.2728 | Acc: 0.6417
#
# Epoch [65/1000] Batch [0/25] D_loss: -3.1552 G_loss: 8.4748
# Epoch [65/1000] Batch [10/25] D_loss: -2.7364 G_loss: N/A
# Epoch [65/1000] Batch [20/25] D_loss: -3.2320 G_loss: N/A
#
# Epoch 65 completed in 64.48s | FID: 1.3022 | IS: 0.5008 | SSIM: 0.0614 | PSNR: 12.8450 | Acc: 0.6125
#
# Epoch [66/1000] Batch [0/25] D_loss: -3.1550 G_loss: 8.1467
# Epoch [66/1000] Batch [10/25] D_loss: -3.0531 G_loss: N/A
# Epoch [66/1000] Batch [20/25] D_loss: -3.2496 G_loss: N/A
#
# Epoch 66 completed in 66.28s | FID: 1.0190 | IS: 0.5004 | SSIM: 0.0627 | PSNR: 12.9724 | Acc: 0.6028
#
# Epoch [67/1000] Batch [0/25] D_loss: -3.2579 G_loss: 8.0441
# Epoch [67/1000] Batch [10/25] D_loss: -3.0110 G_loss: N/A
# Epoch [67/1000] Batch [20/25] D_loss: -3.2158 G_loss: N/A
#
# Epoch 67 completed in 67.17s | FID: 3.0314 | IS: 0.5005 | SSIM: 0.0648 | PSNR: 13.2305 | Acc: 0.6500
#
# Epoch [68/1000] Batch [0/25] D_loss: -2.5395 G_loss: 6.8539
# Epoch [68/1000] Batch [10/25] D_loss: -3.5770 G_loss: N/A
# Epoch [68/1000] Batch [20/25] D_loss: -3.3333 G_loss: N/A
#
# Epoch 68 completed in 68.59s | FID: 1.0761 | IS: 0.5007 | SSIM: 0.0667 | PSNR: 13.1030 | Acc: 0.5861
#
# Epoch [69/1000] Batch [0/25] D_loss: -3.2709 G_loss: 7.5803
# Epoch [69/1000] Batch [10/25] D_loss: -2.6534 G_loss: N/A
# Epoch [69/1000] Batch [20/25] D_loss: -3.4528 G_loss: N/A
#
# Epoch 69 completed in 65.75s | FID: 2.8374 | IS: 0.5007 | SSIM: 0.0677 | PSNR: 13.1684 | Acc: 0.5889
#
# Epoch [70/1000] Batch [0/25] D_loss: -3.2848 G_loss: 7.1893
# Epoch [70/1000] Batch [10/25] D_loss: -2.3518 G_loss: N/A
# Epoch [70/1000] Batch [20/25] D_loss: -3.2609 G_loss: N/A
#
# Epoch 70 completed in 63.24s | FID: 1.0155 | IS: 0.5010 | SSIM: 0.0680 | PSNR: 13.3060 | Acc: 0.6167
#
# Epoch [71/1000] Batch [0/25] D_loss: -3.3770 G_loss: 7.6235
# Epoch [71/1000] Batch [10/25] D_loss: -3.6165 G_loss: N/A
# Epoch [71/1000] Batch [20/25] D_loss: -3.1382 G_loss: N/A
#
# Epoch 71 completed in 64.40s | FID: 2.1129 | IS: 0.5010 | SSIM: 0.0704 | PSNR: 13.3417 | Acc: 0.5625
#
# Epoch [72/1000] Batch [0/25] D_loss: -2.7714 G_loss: 7.4419
# Epoch [72/1000] Batch [10/25] D_loss: -3.0514 G_loss: N/A
# Epoch [72/1000] Batch [20/25] D_loss: -2.8106 G_loss: N/A
#
# Epoch 72 completed in 63.96s | FID: 2.2086 | IS: 0.5011 | SSIM: 0.0694 | PSNR: 13.2595 | Acc: 0.5931
#
# Epoch [73/1000] Batch [0/25] D_loss: -2.7681 G_loss: 7.2300
# Epoch [73/1000] Batch [10/25] D_loss: -3.0801 G_loss: N/A
# Epoch [73/1000] Batch [20/25] D_loss: -3.1040 G_loss: N/A
#
# Epoch 73 completed in 63.66s | FID: 0.8042 | IS: 0.5011 | SSIM: 0.0668 | PSNR: 13.2354 | Acc: 0.6542
#
# Epoch [74/1000] Batch [0/25] D_loss: -2.8086 G_loss: 7.5921
# Epoch [74/1000] Batch [10/25] D_loss: -1.8586 G_loss: N/A
# Epoch [74/1000] Batch [20/25] D_loss: -2.8784 G_loss: N/A
#
# Epoch 74 completed in 64.00s | FID: 3.3242 | IS: 0.5007 | SSIM: 0.0623 | PSNR: 12.8208 | Acc: 0.6153
#
# Epoch [75/1000] Batch [0/25] D_loss: -2.9604 G_loss: 8.4284
# Epoch [75/1000] Batch [10/25] D_loss: -2.8561 G_loss: N/A
# Epoch [75/1000] Batch [20/25] D_loss: -2.5716 G_loss: N/A
#
# Epoch 75 completed in 63.97s | FID: 1.3078 | IS: 0.5008 | SSIM: 0.0678 | PSNR: 13.0399 | Acc: 0.6167
#
# Epoch [76/1000] Batch [0/25] D_loss: -3.1431 G_loss: 7.9256
# Epoch [76/1000] Batch [10/25] D_loss: -3.3274 G_loss: N/A
# Epoch [76/1000] Batch [20/25] D_loss: -2.6557 G_loss: N/A
#
# Epoch 76 completed in 64.07s | FID: 5.5763 | IS: 0.5005 | SSIM: 0.0676 | PSNR: 13.0972 | Acc: 0.6083
#
# Epoch [77/1000] Batch [0/25] D_loss: -3.5642 G_loss: 8.4403
# Epoch [77/1000] Batch [10/25] D_loss: -2.9051 G_loss: N/A
# Epoch [77/1000] Batch [20/25] D_loss: -3.4770 G_loss: N/A
#
# Epoch 77 completed in 65.35s | FID: 2.0286 | IS: 0.5006 | SSIM: 0.0678 | PSNR: 13.2186 | Acc: 0.6236
#
# Epoch [78/1000] Batch [0/25] D_loss: -2.8379 G_loss: 8.3729
# Epoch [78/1000] Batch [10/25] D_loss: -3.1914 G_loss: N/A
# Epoch [78/1000] Batch [20/25] D_loss: -3.0809 G_loss: N/A
#
# Epoch 78 completed in 64.58s | FID: 6.3279 | IS: 0.5006 | SSIM: 0.0698 | PSNR: 13.3068 | Acc: 0.5986
#
# Epoch [79/1000] Batch [0/25] D_loss: -2.5283 G_loss: 7.5298
# Epoch [79/1000] Batch [10/25] D_loss: -2.6122 G_loss: N/A
# Epoch [79/1000] Batch [20/25] D_loss: -3.7862 G_loss: N/A
#
# Epoch 79 completed in 65.66s | FID: 4.6834 | IS: 0.5015 | SSIM: 0.0670 | PSNR: 13.1013 | Acc: 0.5958
#
# Epoch [80/1000] Batch [0/25] D_loss: -3.1120 G_loss: 8.0028
# Epoch [80/1000] Batch [10/25] D_loss: -3.3063 G_loss: N/A
# Epoch [80/1000] Batch [20/25] D_loss: -3.3414 G_loss: N/A
#
# Epoch 80 completed in 64.71s | FID: 4.2156 | IS: 0.5013 | SSIM: 0.0662 | PSNR: 13.0716 | Acc: 0.6500
#
# Epoch [81/1000] Batch [0/25] D_loss: -2.6719 G_loss: 8.2776
# Epoch [81/1000] Batch [10/25] D_loss: -3.3111 G_loss: N/A
# Epoch [81/1000] Batch [20/25] D_loss: -3.1973 G_loss: N/A
#
# Epoch 81 completed in 65.89s | FID: 1.2344 | IS: 0.5008 | SSIM: 0.0698 | PSNR: 13.3489 | Acc: 0.6111
#
# Epoch [82/1000] Batch [0/25] D_loss: -2.9125 G_loss: 8.6427
# Epoch [82/1000] Batch [10/25] D_loss: -3.2550 G_loss: N/A
# Epoch [82/1000] Batch [20/25] D_loss: -3.0832 G_loss: N/A
#
# Epoch 82 completed in 65.60s | FID: 5.3144 | IS: 0.5006 | SSIM: 0.0640 | PSNR: 13.0274 | Acc: 0.6125
#
# Epoch [83/1000] Batch [0/25] D_loss: -3.5003 G_loss: 8.1811
# Epoch [83/1000] Batch [10/25] D_loss: -3.0398 G_loss: N/A
# Epoch [83/1000] Batch [20/25] D_loss: -3.6655 G_loss: N/A
#
# Epoch 83 completed in 64.60s | FID: 3.9227 | IS: 0.5003 | SSIM: 0.0718 | PSNR: 13.2926 | Acc: 0.6444
#
# Epoch [84/1000] Batch [0/25] D_loss: -2.4898 G_loss: 8.4910
# Epoch [84/1000] Batch [10/25] D_loss: -2.3171 G_loss: N/A
# Epoch [84/1000] Batch [20/25] D_loss: -3.2515 G_loss: N/A
#
# Epoch 84 completed in 64.49s | FID: 2.1600 | IS: 0.5003 | SSIM: 0.0655 | PSNR: 12.9881 | Acc: 0.5528
#
# Epoch [85/1000] Batch [0/25] D_loss: -2.2683 G_loss: 7.5565
# Epoch [85/1000] Batch [10/25] D_loss: -3.1392 G_loss: N/A
# Epoch [85/1000] Batch [20/25] D_loss: -3.2933 G_loss: N/A
#
# Epoch 85 completed in 65.68s | FID: 0.4598 | IS: 0.5002 | SSIM: 0.0703 | PSNR: 13.1488 | Acc: 0.5944
#
# Epoch [86/1000] Batch [0/25] D_loss: -2.9797 G_loss: 8.2725
# Epoch [86/1000] Batch [10/25] D_loss: -2.7462 G_loss: N/A
# Epoch [86/1000] Batch [20/25] D_loss: -3.0681 G_loss: N/A
#
# Epoch 86 completed in 65.54s | FID: 3.4680 | IS: 0.5001 | SSIM: 0.0648 | PSNR: 13.0188 | Acc: 0.5931
#
# Epoch [87/1000] Batch [0/25] D_loss: -2.5895 G_loss: 7.5778
# Epoch [87/1000] Batch [10/25] D_loss: -3.0913 G_loss: N/A
# Epoch [87/1000] Batch [20/25] D_loss: -3.3073 G_loss: N/A
#
# Epoch 87 completed in 65.31s | FID: 3.3721 | IS: 0.5004 | SSIM: 0.0668 | PSNR: 12.9613 | Acc: 0.5986
#
# Epoch [88/1000] Batch [0/25] D_loss: -3.4353 G_loss: 8.6314
# Epoch [88/1000] Batch [10/25] D_loss: -3.1125 G_loss: N/A
# Epoch [88/1000] Batch [20/25] D_loss: -2.8148 G_loss: N/A
#
# Epoch 88 completed in 65.63s | FID: 0.8584 | IS: 0.5003 | SSIM: 0.0636 | PSNR: 12.7595 | Acc: 0.5972
#
# Epoch [89/1000] Batch [0/25] D_loss: -3.4982 G_loss: 8.6946
# Epoch [89/1000] Batch [10/25] D_loss: -3.1187 G_loss: N/A
# Epoch [89/1000] Batch [20/25] D_loss: -2.8152 G_loss: N/A
#
# Epoch 89 completed in 65.56s | FID: 2.1168 | IS: 0.5005 | SSIM: 0.0639 | PSNR: 13.0231 | Acc: 0.5597
#
# Epoch [90/1000] Batch [0/25] D_loss: -2.6471 G_loss: 8.8543
# Epoch [90/1000] Batch [10/25] D_loss: -2.6937 G_loss: N/A
# Epoch [90/1000] Batch [20/25] D_loss: -3.0374 G_loss: N/A
#
# Epoch 90 completed in 66.18s | FID: 3.0400 | IS: 0.5010 | SSIM: 0.0696 | PSNR: 13.0174 | Acc: 0.6569
#
# Epoch [91/1000] Batch [0/25] D_loss: -2.8990 G_loss: 8.0621
# Epoch [91/1000] Batch [10/25] D_loss: -2.4835 G_loss: N/A
# Epoch [91/1000] Batch [20/25] D_loss: -2.9109 G_loss: N/A
#
# Epoch 91 completed in 65.49s | FID: 0.5108 | IS: 0.5009 | SSIM: 0.0602 | PSNR: 12.8024 | Acc: 0.6208
#
# Epoch [92/1000] Batch [0/25] D_loss: -2.2615 G_loss: 7.9490
# Epoch [92/1000] Batch [10/25] D_loss: -2.8512 G_loss: N/A
# Epoch [92/1000] Batch [20/25] D_loss: -3.3384 G_loss: N/A
#
# Epoch 92 completed in 64.65s | FID: 1.7318 | IS: 0.5007 | SSIM: 0.0703 | PSNR: 13.2143 | Acc: 0.6153
#
# Epoch [93/1000] Batch [0/25] D_loss: -2.7004 G_loss: 7.3837
# Epoch [93/1000] Batch [10/25] D_loss: -2.7335 G_loss: N/A
# Epoch [93/1000] Batch [20/25] D_loss: -2.5093 G_loss: N/A
#
# Epoch 93 completed in 65.15s | FID: 3.3350 | IS: 0.5016 | SSIM: 0.0662 | PSNR: 12.8220 | Acc: 0.6597
#
# Epoch [94/1000] Batch [0/25] D_loss: -2.6853 G_loss: 8.3461
# Epoch [94/1000] Batch [10/25] D_loss: -2.1930 G_loss: N/A
# Epoch [94/1000] Batch [20/25] D_loss: -2.9546 G_loss: N/A
#
# Epoch 94 completed in 66.37s | FID: 2.4930 | IS: 0.5030 | SSIM: 0.0632 | PSNR: 12.7111 | Acc: 0.6806
#
# Epoch [95/1000] Batch [0/25] D_loss: -2.8701 G_loss: 8.2706
# Epoch [95/1000] Batch [10/25] D_loss: -2.7050 G_loss: N/A
# Epoch [95/1000] Batch [20/25] D_loss: -3.0958 G_loss: N/A
#
# Epoch 95 completed in 65.08s | FID: 3.4793 | IS: 0.5019 | SSIM: 0.0680 | PSNR: 12.9227 | Acc: 0.6458
#
# Epoch [96/1000] Batch [0/25] D_loss: -3.6136 G_loss: 8.3846
# Epoch [96/1000] Batch [10/25] D_loss: -3.0059 G_loss: N/A
# Epoch [96/1000] Batch [20/25] D_loss: -2.1311 G_loss: N/A
#
# Epoch 96 completed in 64.91s | FID: 1.5267 | IS: 0.5099 | SSIM: 0.0619 | PSNR: 12.5334 | Acc: 0.6944
#
# Epoch [97/1000] Batch [0/25] D_loss: -2.9423 G_loss: 8.2050
# Epoch [97/1000] Batch [10/25] D_loss: -2.2984 G_loss: N/A
# Epoch [97/1000] Batch [20/25] D_loss: -2.6628 G_loss: N/A
#
# Epoch 97 completed in 65.27s | FID: 1.9720 | IS: 0.5106 | SSIM: 0.0616 | PSNR: 12.5873 | Acc: 0.6319
#
# Epoch [98/1000] Batch [0/25] D_loss: -2.2795 G_loss: 8.2603
# Epoch [98/1000] Batch [10/25] D_loss: -3.1380 G_loss: N/A
# Epoch [98/1000] Batch [20/25] D_loss: -3.1540 G_loss: N/A
#
# Epoch 98 completed in 64.91s | FID: 0.5122 | IS: 0.5054 | SSIM: 0.0653 | PSNR: 12.6821 | Acc: 0.6486
#
# Epoch [99/1000] Batch [0/25] D_loss: -2.5602 G_loss: 7.9037
# Epoch [99/1000] Batch [10/25] D_loss: -2.3995 G_loss: N/A
# Epoch [99/1000] Batch [20/25] D_loss: -2.9354 G_loss: N/A
#
# Epoch 99 completed in 64.99s | FID: 0.6877 | IS: 0.5052 | SSIM: 0.0692 | PSNR: 13.1280 | Acc: 0.7125
#
# Epoch [100/1000] Batch [0/25] D_loss: -2.7784 G_loss: 7.6226
# Epoch [100/1000] Batch [10/25] D_loss: -2.7006 G_loss: N/A
# Epoch [100/1000] Batch [20/25] D_loss: -2.9027 G_loss: N/A
#
# Epoch 100 completed in 65.96s | FID: 0.9328 | IS: 0.5107 | SSIM: 0.0654 | PSNR: 12.8573 | Acc: 0.6639
#
# Epoch [101/1000] Batch [0/25] D_loss: -2.6538 G_loss: 8.1292
# Epoch [101/1000] Batch [10/25] D_loss: -2.7252 G_loss: N/A
# Epoch [101/1000] Batch [20/25] D_loss: -2.9084 G_loss: N/A
#
# Epoch 101 completed in 64.48s | FID: 0.6926 | IS: 0.5034 | SSIM: 0.0643 | PSNR: 12.7282 | Acc: 0.6014
#
# Epoch [102/1000] Batch [0/25] D_loss: -2.3985 G_loss: 7.7233
# Epoch [102/1000] Batch [10/25] D_loss: -2.2471 G_loss: N/A
# Epoch [102/1000] Batch [20/25] D_loss: -2.9019 G_loss: N/A
#
# Epoch 102 completed in 64.86s | FID: 0.9317 | IS: 0.5072 | SSIM: 0.0720 | PSNR: 12.9820 | Acc: 0.6806
#
# Epoch [103/1000] Batch [0/25] D_loss: -3.0380 G_loss: 8.9334
# Epoch [103/1000] Batch [10/25] D_loss: -2.6387 G_loss: N/A
# Epoch [103/1000] Batch [20/25] D_loss: -2.7608 G_loss: N/A
#
# Epoch 103 completed in 64.60s | FID: 0.7884 | IS: 0.5088 | SSIM: 0.0670 | PSNR: 12.9170 | Acc: 0.6653
#
# Epoch [104/1000] Batch [0/25] D_loss: -2.7225 G_loss: 7.8642
# Epoch [104/1000] Batch [10/25] D_loss: -3.1260 G_loss: N/A
# Epoch [104/1000] Batch [20/25] D_loss: -2.5675 G_loss: N/A
#
# Epoch 104 completed in 65.10s | FID: 0.6983 | IS: 0.5086 | SSIM: 0.0652 | PSNR: 12.8795 | Acc: 0.6653
#
# Epoch [105/1000] Batch [0/25] D_loss: -2.9781 G_loss: 8.2994
# Epoch [105/1000] Batch [10/25] D_loss: -2.9484 G_loss: N/A
# Epoch [105/1000] Batch [20/25] D_loss: -2.6738 G_loss: N/A
#
# Epoch 105 completed in 64.74s | FID: 0.4170 | IS: 0.5106 | SSIM: 0.0651 | PSNR: 12.7807 | Acc: 0.7444
#
# Epoch [106/1000] Batch [0/25] D_loss: -2.4734 G_loss: 7.7502
# Epoch [106/1000] Batch [10/25] D_loss: -2.8257 G_loss: N/A
# Epoch [106/1000] Batch [20/25] D_loss: -2.7570 G_loss: N/A
#
# Epoch 106 completed in 64.52s | FID: 0.5043 | IS: 0.5131 | SSIM: 0.0721 | PSNR: 13.0439 | Acc: 0.6653
#
# Epoch [107/1000] Batch [0/25] D_loss: -2.6179 G_loss: 8.1877
# Epoch [107/1000] Batch [10/25] D_loss: -2.4577 G_loss: N/A
# Epoch [107/1000] Batch [20/25] D_loss: -2.9724 G_loss: N/A
#
# Epoch 107 completed in 65.26s | FID: 1.1055 | IS: 0.5232 | SSIM: 0.0667 | PSNR: 12.6102 | Acc: 0.6847
#
# Epoch [108/1000] Batch [0/25] D_loss: -2.4931 G_loss: 8.6519
# Epoch [108/1000] Batch [10/25] D_loss: -2.7084 G_loss: N/A
# Epoch [108/1000] Batch [20/25] D_loss: -2.8033 G_loss: N/A
#
# Epoch 108 completed in 64.66s | FID: 0.4535 | IS: 0.5103 | SSIM: 0.0671 | PSNR: 12.5659 | Acc: 0.6181
#
# Epoch [109/1000] Batch [0/25] D_loss: -2.6802 G_loss: 8.0658
# Epoch [109/1000] Batch [10/25] D_loss: -3.0682 G_loss: N/A
# Epoch [109/1000] Batch [20/25] D_loss: -2.3950 G_loss: N/A
#
# Epoch 109 completed in 65.17s | FID: 0.8724 | IS: 0.5200 | SSIM: 0.0582 | PSNR: 12.4808 | Acc: 0.6667
#
# Epoch [110/1000] Batch [0/25] D_loss: -2.4798 G_loss: 8.5690
# Epoch [110/1000] Batch [10/25] D_loss: -2.3992 G_loss: N/A
# Epoch [110/1000] Batch [20/25] D_loss: -2.9907 G_loss: N/A
#
# Epoch 110 completed in 65.28s | FID: 1.3942 | IS: 0.5114 | SSIM: 0.0583 | PSNR: 12.4334 | Acc: 0.6528
#
# Epoch [111/1000] Batch [0/25] D_loss: -3.1435 G_loss: 9.2291
# Epoch [111/1000] Batch [10/25] D_loss: -2.7249 G_loss: N/A
# Epoch [111/1000] Batch [20/25] D_loss: -2.5697 G_loss: N/A
#
# Epoch 111 completed in 64.80s | FID: 1.5348 | IS: 0.5083 | SSIM: 0.0658 | PSNR: 12.7408 | Acc: 0.6181
#
# Epoch [112/1000] Batch [0/25] D_loss: -2.5741 G_loss: 7.9052
# Epoch [112/1000] Batch [10/25] D_loss: -2.5166 G_loss: N/A
# Epoch [112/1000] Batch [20/25] D_loss: -2.4474 G_loss: N/A
#
# Epoch 112 completed in 65.40s | FID: 1.3541 | IS: 0.5083 | SSIM: 0.0604 | PSNR: 12.5016 | Acc: 0.6361
#
# Epoch [113/1000] Batch [0/25] D_loss: -2.4971 G_loss: 8.4604
# Epoch [113/1000] Batch [10/25] D_loss: -2.4228 G_loss: N/A
# Epoch [113/1000] Batch [20/25] D_loss: -2.8492 G_loss: N/A
#
# Epoch 113 completed in 65.63s | FID: 1.8302 | IS: 0.5102 | SSIM: 0.0622 | PSNR: 12.6041 | Acc: 0.6681
#
# Epoch [114/1000] Batch [0/25] D_loss: -2.4324 G_loss: 8.1031
# Epoch [114/1000] Batch [10/25] D_loss: -2.3930 G_loss: N/A
# Epoch [114/1000] Batch [20/25] D_loss: -2.1442 G_loss: N/A
#
# Epoch 114 completed in 65.46s | FID: 0.9196 | IS: 0.5145 | SSIM: 0.0673 | PSNR: 12.7279 | Acc: 0.7153
#
# Epoch [115/1000] Batch [0/25] D_loss: -2.7906 G_loss: 8.7591
# Epoch [115/1000] Batch [10/25] D_loss: -2.5164 G_loss: N/A
# Epoch [115/1000] Batch [20/25] D_loss: -2.2142 G_loss: N/A
#
# Epoch 115 completed in 65.02s | FID: 0.4898 | IS: 0.5119 | SSIM: 0.0615 | PSNR: 12.4587 | Acc: 0.6958
#
# Epoch [116/1000] Batch [0/25] D_loss: -2.6167 G_loss: 8.0257
# Epoch [116/1000] Batch [10/25] D_loss: -2.4168 G_loss: N/A
# Epoch [116/1000] Batch [20/25] D_loss: -2.0027 G_loss: N/A
#
# Epoch 116 completed in 65.17s | FID: 0.6685 | IS: 0.5154 | SSIM: 0.0652 | PSNR: 12.5707 | Acc: 0.6403
#
# Epoch [117/1000] Batch [0/25] D_loss: -2.2800 G_loss: 7.9103
# Epoch [117/1000] Batch [10/25] D_loss: -2.4067 G_loss: N/A
# Epoch [117/1000] Batch [20/25] D_loss: -2.1914 G_loss: N/A
#
# Epoch 117 completed in 65.69s | FID: 0.6396 | IS: 0.5254 | SSIM: 0.0665 | PSNR: 12.5158 | Acc: 0.7347
#
# Epoch [118/1000] Batch [0/25] D_loss: -2.1511 G_loss: 8.2313
# Epoch [118/1000] Batch [10/25] D_loss: -3.0080 G_loss: N/A
# Epoch [118/1000] Batch [20/25] D_loss: -2.9484 G_loss: N/A
#
# Epoch 118 completed in 66.11s | FID: 0.4927 | IS: 0.5190 | SSIM: 0.0678 | PSNR: 12.7690 | Acc: 0.6597
#
# Epoch [119/1000] Batch [0/25] D_loss: -2.6801 G_loss: 8.3619
# Epoch [119/1000] Batch [10/25] D_loss: -2.6228 G_loss: N/A
# Epoch [119/1000] Batch [20/25] D_loss: -2.3893 G_loss: N/A
#
# Epoch 119 completed in 65.77s | FID: 2.7766 | IS: 0.5193 | SSIM: 0.0645 | PSNR: 12.7113 | Acc: 0.6611
#
# Epoch [120/1000] Batch [0/25] D_loss: -1.9579 G_loss: 8.0225
# Epoch [120/1000] Batch [10/25] D_loss: -2.4549 G_loss: N/A
# Epoch [120/1000] Batch [20/25] D_loss: -2.3451 G_loss: N/A
#
# Epoch 120 completed in 65.57s | FID: 0.6389 | IS: 0.5342 | SSIM: 0.0654 | PSNR: 12.6054 | Acc: 0.6986
#
# Epoch [121/1000] Batch [0/25] D_loss: -2.6902 G_loss: 8.5216
# Epoch [121/1000] Batch [10/25] D_loss: -1.9896 G_loss: N/A
# Epoch [121/1000] Batch [20/25] D_loss: -2.2815 G_loss: N/A
#
# Epoch 121 completed in 65.20s | FID: 1.2753 | IS: 0.5182 | SSIM: 0.0638 | PSNR: 12.3566 | Acc: 0.6431
#
# Epoch [122/1000] Batch [0/25] D_loss: -2.1199 G_loss: 8.1768
# Epoch [122/1000] Batch [10/25] D_loss: -2.3150 G_loss: N/A
# Epoch [122/1000] Batch [20/25] D_loss: -2.6123 G_loss: N/A
#
# Epoch 122 completed in 65.08s | FID: 1.1038 | IS: 0.5030 | SSIM: 0.0605 | PSNR: 12.3794 | Acc: 0.6222
#
# Epoch [123/1000] Batch [0/25] D_loss: -2.1596 G_loss: 7.8899
# Epoch [123/1000] Batch [10/25] D_loss: -2.2171 G_loss: N/A
# Epoch [123/1000] Batch [20/25] D_loss: -2.8200 G_loss: N/A
#
# Epoch 123 completed in 65.18s | FID: 0.5948 | IS: 0.5279 | SSIM: 0.0637 | PSNR: 12.8179 | Acc: 0.7028
#
# Epoch [124/1000] Batch [0/25] D_loss: -2.0203 G_loss: 8.4805
# Epoch [124/1000] Batch [10/25] D_loss: -2.2041 G_loss: N/A
# Epoch [124/1000] Batch [20/25] D_loss: -2.1789 G_loss: N/A
#
# Epoch 124 completed in 64.62s | FID: 0.6643 | IS: 0.5432 | SSIM: 0.0629 | PSNR: 12.4825 | Acc: 0.7028
#
# Epoch [125/1000] Batch [0/25] D_loss: -2.3677 G_loss: 7.8428
# Epoch [125/1000] Batch [10/25] D_loss: -2.3752 G_loss: N/A
# Epoch [125/1000] Batch [20/25] D_loss: -2.7156 G_loss: N/A
#
# Epoch 125 completed in 64.85s | FID: 0.6986 | IS: 0.5390 | SSIM: 0.0594 | PSNR: 12.5271 | Acc: 0.7069
#
# Epoch [126/1000] Batch [0/25] D_loss: -2.2665 G_loss: 7.9035
# Epoch [126/1000] Batch [10/25] D_loss: -2.2989 G_loss: N/A
# Epoch [126/1000] Batch [20/25] D_loss: -2.2771 G_loss: N/A
#
# Epoch 126 completed in 64.89s | FID: 0.6842 | IS: 0.5226 | SSIM: 0.0628 | PSNR: 12.5028 | Acc: 0.6417
#
# Epoch [127/1000] Batch [0/25] D_loss: -2.5263 G_loss: 7.9873
# Epoch [127/1000] Batch [10/25] D_loss: -1.9090 G_loss: N/A
# Epoch [127/1000] Batch [20/25] D_loss: -2.7114 G_loss: N/A
#
# Epoch 127 completed in 64.58s | FID: 1.6669 | IS: 0.5270 | SSIM: 0.0608 | PSNR: 12.5676 | Acc: 0.7097
#
# Epoch [128/1000] Batch [0/25] D_loss: -2.0080 G_loss: 7.6804
# Epoch [128/1000] Batch [10/25] D_loss: -2.3966 G_loss: N/A
# Epoch [128/1000] Batch [20/25] D_loss: -2.6319 G_loss: N/A
#
# Epoch 128 completed in 64.78s | FID: 0.7365 | IS: 0.5323 | SSIM: 0.0612 | PSNR: 12.5506 | Acc: 0.6667
#
# Epoch [129/1000] Batch [0/25] D_loss: -2.6494 G_loss: 8.3354
# Epoch [129/1000] Batch [10/25] D_loss: -2.3327 G_loss: N/A
# Epoch [129/1000] Batch [20/25] D_loss: -2.6957 G_loss: N/A
#
# Epoch 129 completed in 65.06s | FID: 0.3443 | IS: 0.5263 | SSIM: 0.0652 | PSNR: 12.4964 | Acc: 0.6819
#
# Epoch [130/1000] Batch [0/25] D_loss: -2.4097 G_loss: 8.1670
# Epoch [130/1000] Batch [10/25] D_loss: -2.4432 G_loss: N/A
# Epoch [130/1000] Batch [20/25] D_loss: -2.5124 G_loss: N/A
#
# Epoch 130 completed in 65.44s | FID: 0.5173 | IS: 0.5193 | SSIM: 0.0644 | PSNR: 12.8341 | Acc: 0.7319
#
# Epoch [131/1000] Batch [0/25] D_loss: -2.7326 G_loss: 8.5256
# Epoch [131/1000] Batch [10/25] D_loss: -2.8336 G_loss: N/A
# Epoch [131/1000] Batch [20/25] D_loss: -2.1988 G_loss: N/A
#
# Epoch 131 completed in 64.60s | FID: 1.4085 | IS: 0.5356 | SSIM: 0.0623 | PSNR: 12.7981 | Acc: 0.6806
#
# Epoch [132/1000] Batch [0/25] D_loss: -2.5585 G_loss: 8.2564
# Epoch [132/1000] Batch [10/25] D_loss: -2.4186 G_loss: N/A
# Epoch [132/1000] Batch [20/25] D_loss: -2.4846 G_loss: N/A
#
# Epoch 132 completed in 64.91s | FID: 0.5007 | IS: 0.5538 | SSIM: 0.0628 | PSNR: 12.5722 | Acc: 0.7000
#
# Epoch [133/1000] Batch [0/25] D_loss: -2.6289 G_loss: 8.3607
# Epoch [133/1000] Batch [10/25] D_loss: -2.8672 G_loss: N/A
# Epoch [133/1000] Batch [20/25] D_loss: -2.1121 G_loss: N/A
#
# Epoch 133 completed in 64.99s | FID: 0.3433 | IS: 0.5250 | SSIM: 0.0646 | PSNR: 12.4254 | Acc: 0.6181
#
# Epoch [134/1000] Batch [0/25] D_loss: -2.2312 G_loss: 7.7202
# Epoch [134/1000] Batch [10/25] D_loss: -2.7783 G_loss: N/A
# Epoch [134/1000] Batch [20/25] D_loss: -2.1920 G_loss: N/A
#
# Epoch 134 completed in 65.14s | FID: 0.5431 | IS: 0.5399 | SSIM: 0.0654 | PSNR: 12.5377 | Acc: 0.7028
#
# Epoch [135/1000] Batch [0/25] D_loss: -2.5302 G_loss: 8.1475
# Epoch [135/1000] Batch [10/25] D_loss: -2.1617 G_loss: N/A
# Epoch [135/1000] Batch [20/25] D_loss: -2.1647 G_loss: N/A
#
# Epoch 135 completed in 65.68s | FID: 1.8057 | IS: 0.5712 | SSIM: 0.0641 | PSNR: 12.3606 | Acc: 0.6764
#
# Epoch [136/1000] Batch [0/25] D_loss: -1.9683 G_loss: 7.9701
# Epoch [136/1000] Batch [10/25] D_loss: -2.0761 G_loss: N/A
# Epoch [136/1000] Batch [20/25] D_loss: -2.2449 G_loss: N/A
#
# Epoch 136 completed in 65.96s | FID: 1.4771 | IS: 0.5653 | SSIM: 0.0629 | PSNR: 12.2613 | Acc: 0.6472
#
# Epoch [137/1000] Batch [0/25] D_loss: -2.1622 G_loss: 7.9442
# Epoch [137/1000] Batch [10/25] D_loss: -1.4855 G_loss: N/A
# Epoch [137/1000] Batch [20/25] D_loss: -2.1648 G_loss: N/A
#
# Epoch 137 completed in 65.84s | FID: 0.7596 | IS: 0.5391 | SSIM: 0.0579 | PSNR: 12.2173 | Acc: 0.6292
#
# Epoch [138/1000] Batch [0/25] D_loss: -2.1953 G_loss: 7.8523
# Epoch [138/1000] Batch [10/25] D_loss: -1.3222 G_loss: N/A
# Epoch [138/1000] Batch [20/25] D_loss: -1.9473 G_loss: N/A
#
# Epoch 138 completed in 65.21s | FID: 0.9685 | IS: 0.5196 | SSIM: 0.0591 | PSNR: 12.4081 | Acc: 0.6986
#
# Epoch [139/1000] Batch [0/25] D_loss: -1.3773 G_loss: 7.4954
# Epoch [139/1000] Batch [10/25] D_loss: -2.0328 G_loss: N/A
# Epoch [139/1000] Batch [20/25] D_loss: -1.9399 G_loss: N/A
#
# Epoch 139 completed in 64.66s | FID: 2.2760 | IS: 0.5505 | SSIM: 0.0623 | PSNR: 12.4315 | Acc: 0.7014
#
# Epoch [140/1000] Batch [0/25] D_loss: -2.2342 G_loss: 8.2660
# Epoch [140/1000] Batch [10/25] D_loss: -2.2903 G_loss: N/A
# Epoch [140/1000] Batch [20/25] D_loss: -2.1100 G_loss: N/A
#
# Epoch 140 completed in 64.50s | FID: 1.3900 | IS: 0.5906 | SSIM: 0.0597 | PSNR: 12.3772 | Acc: 0.6958
#
# Epoch [141/1000] Batch [0/25] D_loss: -1.7553 G_loss: 8.6169
# Epoch [141/1000] Batch [10/25] D_loss: -2.3033 G_loss: N/A
# Epoch [141/1000] Batch [20/25] D_loss: -2.0468 G_loss: N/A
#
# Epoch 141 completed in 66.03s | FID: 3.3889 | IS: 0.5655 | SSIM: 0.0593 | PSNR: 11.9817 | Acc: 0.7056
#
# Epoch [142/1000] Batch [0/25] D_loss: -2.8824 G_loss: 8.6239
# Epoch [142/1000] Batch [10/25] D_loss: -1.6120 G_loss: N/A
# Epoch [142/1000] Batch [20/25] D_loss: -1.8728 G_loss: N/A
#
# Epoch 142 completed in 65.10s | FID: 0.6984 | IS: 0.5446 | SSIM: 0.0567 | PSNR: 12.3680 | Acc: 0.6778
#
# Epoch [143/1000] Batch [0/25] D_loss: -2.6181 G_loss: 8.2779
# Epoch [143/1000] Batch [10/25] D_loss: -1.7905 G_loss: N/A
# Epoch [143/1000] Batch [20/25] D_loss: -2.2000 G_loss: N/A
#
# Epoch 143 completed in 65.01s | FID: 1.1218 | IS: 0.5516 | SSIM: 0.0596 | PSNR: 12.2996 | Acc: 0.7000
#
# Epoch [144/1000] Batch [0/25] D_loss: -1.9693 G_loss: 7.6963
# Epoch [144/1000] Batch [10/25] D_loss: -2.3201 G_loss: N/A
# Epoch [144/1000] Batch [20/25] D_loss: -2.0304 G_loss: N/A
#
# Epoch 144 completed in 64.71s | FID: 1.2742 | IS: 0.5491 | SSIM: 0.0604 | PSNR: 12.2400 | Acc: 0.6292
#
# Epoch [145/1000] Batch [0/25] D_loss: -2.3085 G_loss: 7.9213
# Epoch [145/1000] Batch [10/25] D_loss: -2.6623 G_loss: N/A
# Epoch [145/1000] Batch [20/25] D_loss: -2.0334 G_loss: N/A
#
# Epoch 145 completed in 64.85s | FID: 1.4630 | IS: 0.5588 | SSIM: 0.0590 | PSNR: 12.3924 | Acc: 0.7208
#
# Epoch [146/1000] Batch [0/25] D_loss: -1.8680 G_loss: 7.7897
# Epoch [146/1000] Batch [10/25] D_loss: -1.6805 G_loss: N/A
# Epoch [146/1000] Batch [20/25] D_loss: -1.8124 G_loss: N/A
#
# Epoch 146 completed in 64.90s | FID: 0.8787 | IS: 0.5351 | SSIM: 0.0645 | PSNR: 12.3505 | Acc: 0.6472
#
# Epoch [147/1000] Batch [0/25] D_loss: -2.0068 G_loss: 7.8249
# Epoch [147/1000] Batch [10/25] D_loss: -1.9155 G_loss: N/A
# Epoch [147/1000] Batch [20/25] D_loss: -1.9938 G_loss: N/A
#
# Epoch 147 completed in 64.44s | FID: 0.9137 | IS: 0.5241 | SSIM: 0.0610 | PSNR: 12.2011 | Acc: 0.6583
#
# Epoch [148/1000] Batch [0/25] D_loss: -2.1026 G_loss: 7.9503
# Epoch [148/1000] Batch [10/25] D_loss: -2.2805 G_loss: N/A
# Epoch [148/1000] Batch [20/25] D_loss: -1.4478 G_loss: N/A
#
# Epoch 148 completed in 67.57s | FID: 2.9622 | IS: 0.5726 | SSIM: 0.0615 | PSNR: 12.1817 | Acc: 0.7042
#
# Epoch [149/1000] Batch [0/25] D_loss: -1.9796 G_loss: 7.9558
# Epoch [149/1000] Batch [10/25] D_loss: -1.8783 G_loss: N/A
# Epoch [149/1000] Batch [20/25] D_loss: -1.4022 G_loss: N/A
#
# Epoch 149 completed in 65.72s | FID: 2.0722 | IS: 0.5566 | SSIM: 0.0543 | PSNR: 12.1593 | Acc: 0.6819
#
# Epoch [150/1000] Batch [0/25] D_loss: -2.4005 G_loss: 7.5852
# Epoch [150/1000] Batch [10/25] D_loss: -2.0245 G_loss: N/A
# Epoch [150/1000] Batch [20/25] D_loss: -2.2750 G_loss: N/A
#
# Epoch 150 completed in 64.89s | FID: 0.7742 | IS: 0.5461 | SSIM: 0.0606 | PSNR: 12.0176 | Acc: 0.6819
#
# Epoch [151/1000] Batch [0/25] D_loss: -1.8452 G_loss: 7.9414
# Epoch [151/1000] Batch [10/25] D_loss: -1.5692 G_loss: N/A
# Epoch [151/1000] Batch [20/25] D_loss: -1.7912 G_loss: N/A
#
# Epoch 151 completed in 64.66s | FID: 0.8472 | IS: 0.5194 | SSIM: 0.0605 | PSNR: 12.3701 | Acc: 0.6417
#
# Epoch [152/1000] Batch [0/25] D_loss: -2.2660 G_loss: 7.8989
# Epoch [152/1000] Batch [10/25] D_loss: -1.8567 G_loss: N/A
# Epoch [152/1000] Batch [20/25] D_loss: -2.0710 G_loss: N/A
#
# Epoch 152 completed in 64.70s | FID: 4.9559 | IS: 0.5406 | SSIM: 0.0592 | PSNR: 12.3873 | Acc: 0.7056
#
# Epoch [153/1000] Batch [0/25] D_loss: -1.9941 G_loss: 7.8100
# Epoch [153/1000] Batch [10/25] D_loss: -2.0057 G_loss: N/A
# Epoch [153/1000] Batch [20/25] D_loss: -2.0891 G_loss: N/A
#
# Epoch 153 completed in 65.16s | FID: 0.9196 | IS: 0.5443 | SSIM: 0.0607 | PSNR: 12.4818 | Acc: 0.6986
#
# Epoch [154/1000] Batch [0/25] D_loss: -1.8621 G_loss: 7.7529
# Epoch [154/1000] Batch [10/25] D_loss: -1.7597 G_loss: N/A
# Epoch [154/1000] Batch [20/25] D_loss: -1.8453 G_loss: N/A
#
# Epoch 154 completed in 64.69s | FID: 0.7134 | IS: 0.5426 | SSIM: 0.0595 | PSNR: 12.3520 | Acc: 0.7389
#
# Epoch [155/1000] Batch [0/25] D_loss: -1.5618 G_loss: 8.0325
# Epoch [155/1000] Batch [10/25] D_loss: -1.5785 G_loss: N/A
# Epoch [155/1000] Batch [20/25] D_loss: -1.5405 G_loss: N/A
#
# Epoch 155 completed in 66.04s | FID: 2.7423 | IS: 0.5493 | SSIM: 0.0525 | PSNR: 12.0730 | Acc: 0.6875
#
# Epoch [156/1000] Batch [0/25] D_loss: -1.8068 G_loss: 8.1383
# Epoch [156/1000] Batch [10/25] D_loss: -1.6706 G_loss: N/A
# Epoch [156/1000] Batch [20/25] D_loss: -2.0373 G_loss: N/A
#
# Epoch 156 completed in 65.09s | FID: 2.3168 | IS: 0.5245 | SSIM: 0.0561 | PSNR: 11.9376 | Acc: 0.6528
#
# Epoch [157/1000] Batch [0/25] D_loss: -2.1151 G_loss: 7.6189
# Epoch [157/1000] Batch [10/25] D_loss: -1.3827 G_loss: N/A
# Epoch [157/1000] Batch [20/25] D_loss: -2.0143 G_loss: N/A
#
# Epoch 157 completed in 64.85s | FID: 0.5568 | IS: 0.5227 | SSIM: 0.0578 | PSNR: 12.3132 | Acc: 0.7181
#
# Epoch [158/1000] Batch [0/25] D_loss: -2.0405 G_loss: 7.7691
# Epoch [158/1000] Batch [10/25] D_loss: -1.3452 G_loss: N/A
# Epoch [158/1000] Batch [20/25] D_loss: -1.7837 G_loss: N/A
#
# Epoch 158 completed in 65.93s | FID: 4.0155 | IS: 0.5660 | SSIM: 0.0633 | PSNR: 12.4622 | Acc: 0.6806
#
# Epoch [159/1000] Batch [0/25] D_loss: -1.7013 G_loss: 7.4449
# Epoch [159/1000] Batch [10/25] D_loss: -1.5011 G_loss: N/A
# Epoch [159/1000] Batch [20/25] D_loss: -1.5428 G_loss: N/A
#
# Epoch 159 completed in 65.64s | FID: 1.1427 | IS: 0.5546 | SSIM: 0.0606 | PSNR: 12.2686 | Acc: 0.6861
#
# Epoch [160/1000] Batch [0/25] D_loss: -1.9787 G_loss: 7.9877
# Epoch [160/1000] Batch [10/25] D_loss: -1.7851 G_loss: N/A
# Epoch [160/1000] Batch [20/25] D_loss: -2.2775 G_loss: N/A
#
# Epoch 160 completed in 65.20s | FID: 3.7330 | IS: 0.5458 | SSIM: 0.0590 | PSNR: 12.0769 | Acc: 0.7111
#
# Epoch [161/1000] Batch [0/25] D_loss: -1.7541 G_loss: 7.6193
# Epoch [161/1000] Batch [10/25] D_loss: -2.1875 G_loss: N/A
# Epoch [161/1000] Batch [20/25] D_loss: -2.0757 G_loss: N/A
#
# Epoch 161 completed in 65.83s | FID: 4.2696 | IS: 0.5510 | SSIM: 0.0585 | PSNR: 12.2147 | Acc: 0.7208
#
# Epoch [162/1000] Batch [0/25] D_loss: -1.5220 G_loss: 7.5640
# Epoch [162/1000] Batch [10/25] D_loss: -2.0893 G_loss: N/A
# Epoch [162/1000] Batch [20/25] D_loss: -2.2690 G_loss: N/A
#
# Epoch 162 completed in 65.17s | FID: 1.3645 | IS: 0.5533 | SSIM: 0.0587 | PSNR: 12.1601 | Acc: 0.6889
#
# Epoch [163/1000] Batch [0/25] D_loss: -1.8168 G_loss: 7.8709
# Epoch [163/1000] Batch [10/25] D_loss: -2.0333 G_loss: N/A
# Epoch [163/1000] Batch [20/25] D_loss: -1.9166 G_loss: N/A
#
# Epoch 163 completed in 64.88s | FID: 0.9126 | IS: 0.5497 | SSIM: 0.0536 | PSNR: 11.8022 | Acc: 0.6431
#
# Epoch [164/1000] Batch [0/25] D_loss: -2.0596 G_loss: 7.9027
# Epoch [164/1000] Batch [10/25] D_loss: -1.9280 G_loss: N/A
# Epoch [164/1000] Batch [20/25] D_loss: -2.2735 G_loss: N/A
#
# Epoch 164 completed in 64.51s | FID: 4.2234 | IS: 0.5301 | SSIM: 0.0592 | PSNR: 12.1851 | Acc: 0.6542
#
# Epoch [165/1000] Batch [0/25] D_loss: -1.8382 G_loss: 7.6309
# Epoch [165/1000] Batch [10/25] D_loss: -1.5323 G_loss: N/A
# Epoch [165/1000] Batch [20/25] D_loss: -1.7425 G_loss: N/A
#
# Epoch 165 completed in 65.42s | FID: 1.9118 | IS: 0.5221 | SSIM: 0.0606 | PSNR: 11.7778 | Acc: 0.6819
#
# Epoch [166/1000] Batch [0/25] D_loss: -1.7502 G_loss: 7.3782
# Epoch [166/1000] Batch [10/25] D_loss: -1.8851 G_loss: N/A
# Epoch [166/1000] Batch [20/25] D_loss: -2.0385 G_loss: N/A
#
# Epoch 166 completed in 65.18s | FID: 1.9457 | IS: 0.5410 | SSIM: 0.0610 | PSNR: 12.3268 | Acc: 0.7236
#
# Epoch [167/1000] Batch [0/25] D_loss: -2.4114 G_loss: 8.3483
# Epoch [167/1000] Batch [10/25] D_loss: -1.6769 G_loss: N/A
# Epoch [167/1000] Batch [20/25] D_loss: -1.7442 G_loss: N/A
#
# Epoch 167 completed in 65.33s | FID: 2.2699 | IS: 0.5418 | SSIM: 0.0533 | PSNR: 12.1866 | Acc: 0.6806
#
# Epoch [168/1000] Batch [0/25] D_loss: -1.7625 G_loss: 7.6260
# Epoch [168/1000] Batch [10/25] D_loss: -2.2519 G_loss: N/A
# Epoch [168/1000] Batch [20/25] D_loss: -2.2068 G_loss: N/A
#
# Epoch 168 completed in 64.50s | FID: 1.3503 | IS: 0.5581 | SSIM: 0.0596 | PSNR: 12.2431 | Acc: 0.6889
#
# Epoch [169/1000] Batch [0/25] D_loss: -2.0754 G_loss: 8.1356
# Epoch [169/1000] Batch [10/25] D_loss: -1.4873 G_loss: N/A
# Epoch [169/1000] Batch [20/25] D_loss: -1.8624 G_loss: N/A
#
# Epoch 169 completed in 64.90s | FID: 1.5372 | IS: 0.5333 | SSIM: 0.0603 | PSNR: 12.1657 | Acc: 0.6542
#
# Epoch [170/1000] Batch [0/25] D_loss: -1.9390 G_loss: 7.6426
# Epoch [170/1000] Batch [10/25] D_loss: -1.9300 G_loss: N/A
# Epoch [170/1000] Batch [20/25] D_loss: -1.9630 G_loss: N/A
#
# Epoch 170 completed in 66.08s | FID: 2.3436 | IS: 0.5362 | SSIM: 0.0626 | PSNR: 12.4820 | Acc: 0.7319
#
# Epoch [171/1000] Batch [0/25] D_loss: -1.7019 G_loss: 7.4569
# ...
#
# Epoch 944 completed in 64.50s | FID: 3.3367 | IS: 0.6029 | SSIM: 0.0616 | PSNR: 12.4133 | Acc: 0.8556
#
# Epoch [945/1000] Batch [0/25] D_loss: -1.6582 G_loss: 7.8711
# Epoch [945/1000] Batch [10/25] D_loss: -1.9303 G_loss: N/A
# Epoch [945/1000] Batch [20/25] D_loss: -1.6232 G_loss: N/A
#
# Epoch 945 completed in 65.13s | FID: 2.2997 | IS: 0.5648 | SSIM: 0.0578 | PSNR: 12.1228 | Acc: 0.8250
#
# Epoch [946/1000] Batch [0/25] D_loss: -1.8699 G_loss: 7.8808
# Epoch [946/1000] Batch [10/25] D_loss: -1.9049 G_loss: N/A
# Epoch [946/1000] Batch [20/25] D_loss: -1.7196 G_loss: N/A
#
# Epoch 946 completed in 64.85s | FID: 3.8358 | IS: 0.5701 | SSIM: 0.0615 | PSNR: 12.2456 | Acc: 0.7931
#
# Epoch [947/1000] Batch [0/25] D_loss: -1.7816 G_loss: 7.7158
# Epoch [947/1000] Batch [10/25] D_loss: -1.4830 G_loss: N/A
# Epoch [947/1000] Batch [20/25] D_loss: -1.9444 G_loss: N/A
#
# Epoch 947 completed in 64.85s | FID: 7.5895 | IS: 0.6035 | SSIM: 0.0632 | PSNR: 12.4350 | Acc: 0.7833
#
# Epoch [948/1000] Batch [0/25] D_loss: -1.7037 G_loss: 7.9261
# Epoch [948/1000] Batch [10/25] D_loss: -2.0533 G_loss: N/A
# Epoch [948/1000] Batch [20/25] D_loss: -1.7620 G_loss: N/A
#
# Epoch 948 completed in 65.08s | FID: 4.0671 | IS: 0.5695 | SSIM: 0.0593 | PSNR: 12.1679 | Acc: 0.8111
#
# Epoch [949/1000] Batch [0/25] D_loss: -2.0638 G_loss: 8.0841
# Epoch [949/1000] Batch [10/25] D_loss: -2.0540 G_loss: N/A
# Epoch [949/1000] Batch [20/25] D_loss: -1.9961 G_loss: N/A
#
# Epoch 949 completed in 64.07s | FID: 8.3565 | IS: 0.6314 | SSIM: 0.0594 | PSNR: 12.3067 | Acc: 0.8694
#
# Epoch [950/1000] Batch [0/25] D_loss: -1.9555 G_loss: 8.2325
# Epoch [950/1000] Batch [10/25] D_loss: -1.7790 G_loss: N/A
# Epoch [950/1000] Batch [20/25] D_loss: -1.8083 G_loss: N/A
#
# Epoch 950 completed in 65.46s | FID: 9.3473 | IS: 0.5459 | SSIM: 0.0532 | PSNR: 12.1034 | Acc: 0.7667
#
# Epoch [951/1000] Batch [0/25] D_loss: -1.8213 G_loss: 8.0047
# Epoch [951/1000] Batch [10/25] D_loss: -1.6866 G_loss: N/A
# Epoch [951/1000] Batch [20/25] D_loss: -2.0322 G_loss: N/A
#
# Epoch 951 completed in 65.51s | FID: 13.4248 | IS: 0.6558 | SSIM: 0.0566 | PSNR: 12.2532 | Acc: 0.7764
#
# Epoch [952/1000] Batch [0/25] D_loss: -1.7934 G_loss: 7.6980
# Epoch [952/1000] Batch [10/25] D_loss: -2.0347 G_loss: N/A
# Epoch [952/1000] Batch [20/25] D_loss: -1.5286 G_loss: N/A
#
# Epoch 952 completed in 66.01s | FID: 8.1561 | IS: 0.5783 | SSIM: 0.0601 | PSNR: 12.2450 | Acc: 0.7764
#
# Epoch [953/1000] Batch [0/25] D_loss: -1.6414 G_loss: 7.4893
# Epoch [953/1000] Batch [10/25] D_loss: -1.8005 G_loss: N/A
# Epoch [953/1000] Batch [20/25] D_loss: -1.8148 G_loss: N/A
#
# Epoch 953 completed in 65.19s | FID: 13.3189 | IS: 0.5783 | SSIM: 0.0612 | PSNR: 12.4086 | Acc: 0.8542
#
# Epoch [954/1000] Batch [0/25] D_loss: -2.0363 G_loss: 7.5686
# Epoch [954/1000] Batch [10/25] D_loss: -2.0390 G_loss: N/A
# Epoch [954/1000] Batch [20/25] D_loss: -1.7958 G_loss: N/A
#
# Epoch 954 completed in 64.92s | FID: 12.5345 | IS: 0.5969 | SSIM: 0.0588 | PSNR: 12.2562 | Acc: 0.7625
#
# Epoch [955/1000] Batch [0/25] D_loss: -1.6117 G_loss: 7.9943
# Epoch [955/1000] Batch [10/25] D_loss: -1.4143 G_loss: N/A
# Epoch [955/1000] Batch [20/25] D_loss: -1.8795 G_loss: N/A
#
# Epoch 955 completed in 64.79s | FID: 3.7379 | IS: 0.5609 | SSIM: 0.0573 | PSNR: 12.1511 | Acc: 0.8319
#
# Epoch [956/1000] Batch [0/25] D_loss: -1.8115 G_loss: 7.7013
# Epoch [956/1000] Batch [10/25] D_loss: -1.7874 G_loss: N/A
# Epoch [956/1000] Batch [20/25] D_loss: -1.9492 G_loss: N/A
#
# Epoch 956 completed in 64.21s | FID: 3.1056 | IS: 0.5617 | SSIM: 0.0617 | PSNR: 12.2185 | Acc: 0.8111
#
# Epoch [957/1000] Batch [0/25] D_loss: -1.6680 G_loss: 7.5092
# Epoch [957/1000] Batch [10/25] D_loss: -1.8923 G_loss: N/A
# Epoch [957/1000] Batch [20/25] D_loss: -1.5584 G_loss: N/A
#
# Epoch 957 completed in 64.32s | FID: 2.7134 | IS: 0.5402 | SSIM: 0.0612 | PSNR: 12.3785 | Acc: 0.8000
#
# Epoch [958/1000] Batch [0/25] D_loss: -1.5433 G_loss: 7.5014
# Epoch [958/1000] Batch [10/25] D_loss: -1.8067 G_loss: N/A
# Epoch [958/1000] Batch [20/25] D_loss: -2.4452 G_loss: N/A
#
# Epoch 958 completed in 65.63s | FID: 9.3041 | IS: 0.6162 | SSIM: 0.0580 | PSNR: 12.1615 | Acc: 0.8389
#
# Epoch [959/1000] Batch [0/25] D_loss: -1.6767 G_loss: 7.6542
# Epoch [959/1000] Batch [10/25] D_loss: -1.6580 G_loss: N/A
# Epoch [959/1000] Batch [20/25] D_loss: -2.1018 G_loss: N/A
#
# Epoch 959 completed in 64.75s | FID: 1.2680 | IS: 0.5348 | SSIM: 0.0552 | PSNR: 12.0281 | Acc: 0.7514
#
# Epoch [960/1000] Batch [0/25] D_loss: -1.8073 G_loss: 7.7506
# Epoch [960/1000] Batch [10/25] D_loss: -2.0135 G_loss: N/A
# Epoch [960/1000] Batch [20/25] D_loss: -1.5259 G_loss: N/A
#
# Epoch 960 completed in 65.58s | FID: 4.0056 | IS: 0.5662 | SSIM: 0.0568 | PSNR: 12.2452 | Acc: 0.7944
#
# Epoch [961/1000] Batch [0/25] D_loss: -1.4867 G_loss: 7.3390
# Epoch [961/1000] Batch [10/25] D_loss: -1.3377 G_loss: N/A
# Epoch [961/1000] Batch [20/25] D_loss: -1.9539 G_loss: N/A
#
# Epoch 961 completed in 64.62s | FID: 3.9752 | IS: 0.5750 | SSIM: 0.0608 | PSNR: 12.3675 | Acc: 0.8208
#
# Epoch [962/1000] Batch [0/25] D_loss: -2.0536 G_loss: 7.7536
# Epoch [962/1000] Batch [10/25] D_loss: -1.5121 G_loss: N/A
# Epoch [962/1000] Batch [20/25] D_loss: -2.0130 G_loss: N/A
#
# Epoch 962 completed in 65.16s | FID: 2.1096 | IS: 0.5489 | SSIM: 0.0567 | PSNR: 12.1430 | Acc: 0.8181
#
# Epoch [963/1000] Batch [0/25] D_loss: -2.1467 G_loss: 7.4785
# Epoch [963/1000] Batch [10/25] D_loss: -1.6920 G_loss: N/A
# Epoch [963/1000] Batch [20/25] D_loss: -1.8122 G_loss: N/A
#
# Epoch 963 completed in 65.79s | FID: 4.3385 | IS: 0.5722 | SSIM: 0.0558 | PSNR: 12.0945 | Acc: 0.8500
#
# Epoch [964/1000] Batch [0/25] D_loss: -1.9874 G_loss: 7.9821
# Epoch [964/1000] Batch [10/25] D_loss: -2.4376 G_loss: N/A
# Epoch [964/1000] Batch [20/25] D_loss: -1.6039 G_loss: N/A
#
# Epoch 964 completed in 65.31s | FID: 4.8531 | IS: 0.5452 | SSIM: 0.0574 | PSNR: 12.1478 | Acc: 0.7472
#
# Epoch [965/1000] Batch [0/25] D_loss: -1.7990 G_loss: 7.6951
# Epoch [965/1000] Batch [10/25] D_loss: -1.4397 G_loss: N/A
# Epoch [965/1000] Batch [20/25] D_loss: -1.8646 G_loss: N/A
#
# Epoch 965 completed in 64.44s | FID: 3.8944 | IS: 0.5448 | SSIM: 0.0561 | PSNR: 12.0240 | Acc: 0.8319
#
# Epoch [966/1000] Batch [0/25] D_loss: -1.5636 G_loss: 7.5987
# Epoch [966/1000] Batch [10/25] D_loss: -1.8505 G_loss: N/A
# Epoch [966/1000] Batch [20/25] D_loss: -1.7151 G_loss: N/A
#
# Epoch 966 completed in 65.66s | FID: 7.5599 | IS: 0.5790 | SSIM: 0.0600 | PSNR: 12.4020 | Acc: 0.8153
#
# Epoch [967/1000] Batch [0/25] D_loss: -1.7028 G_loss: 7.7984
# Epoch [967/1000] Batch [10/25] D_loss: -1.7457 G_loss: N/A
# Epoch [967/1000] Batch [20/25] D_loss: -1.5477 G_loss: N/A
#
# Epoch 967 completed in 64.72s | FID: 3.5911 | IS: 0.5570 | SSIM: 0.0544 | PSNR: 12.1820 | Acc: 0.7958
#
# Epoch [968/1000] Batch [0/25] D_loss: -1.5121 G_loss: 7.5031
# Epoch [968/1000] Batch [10/25] D_loss: -1.3478 G_loss: N/A
# Epoch [968/1000] Batch [20/25] D_loss: -1.9508 G_loss: N/A
#
# Epoch 968 completed in 64.75s | FID: 5.5716 | IS: 0.5745 | SSIM: 0.0632 | PSNR: 12.3177 | Acc: 0.8361
#
# Epoch [969/1000] Batch [0/25] D_loss: -1.9083 G_loss: 7.8484
# Epoch [969/1000] Batch [10/25] D_loss: -1.7115 G_loss: N/A
# Epoch [969/1000] Batch [20/25] D_loss: -1.8279 G_loss: N/A
#
# Epoch 969 completed in 64.51s | FID: 2.0137 | IS: 0.5478 | SSIM: 0.0592 | PSNR: 12.1957 | Acc: 0.8111
#
# Epoch [970/1000] Batch [0/25] D_loss: -1.8835 G_loss: 7.8825
# Epoch [970/1000] Batch [10/25] D_loss: -1.8938 G_loss: N/A
# Epoch [970/1000] Batch [20/25] D_loss: -1.9973 G_loss: N/A
#
# Epoch 970 completed in 64.30s | FID: 5.0301 | IS: 0.5815 | SSIM: 0.0545 | PSNR: 12.3161 | Acc: 0.7861
#
# Epoch [971/1000] Batch [0/25] D_loss: -1.5762 G_loss: 7.6771
# Epoch [971/1000] Batch [10/25] D_loss: -1.8915 G_loss: N/A
# Epoch [971/1000] Batch [20/25] D_loss: -1.5039 G_loss: N/A
#
# Epoch 971 completed in 64.91s | FID: 5.2697 | IS: 0.5792 | SSIM: 0.0609 | PSNR: 12.4583 | Acc: 0.7972
#
# Epoch [972/1000] Batch [0/25] D_loss: -1.5677 G_loss: 7.8325
# Epoch [972/1000] Batch [10/25] D_loss: -1.6579 G_loss: N/A
# Epoch [972/1000] Batch [20/25] D_loss: -1.5722 G_loss: N/A
#
# Epoch 972 completed in 65.41s | FID: 7.4438 | IS: 0.5683 | SSIM: 0.0575 | PSNR: 12.1919 | Acc: 0.8042
#
# Epoch [973/1000] Batch [0/25] D_loss: -1.4342 G_loss: 7.4671
# Epoch [973/1000] Batch [10/25] D_loss: -1.9369 G_loss: N/A
# Epoch [973/1000] Batch [20/25] D_loss: -2.0145 G_loss: N/A
#
# Epoch 973 completed in 64.79s | FID: 6.1152 | IS: 0.5595 | SSIM: 0.0599 | PSNR: 12.2772 | Acc: 0.8111
#
# Epoch [974/1000] Batch [0/25] D_loss: -1.8997 G_loss: 7.5900
# Epoch [974/1000] Batch [10/25] D_loss: -1.6522 G_loss: N/A
# Epoch [974/1000] Batch [20/25] D_loss: -2.0398 G_loss: N/A
#
# Epoch 974 completed in 66.28s | FID: 7.3978 | IS: 0.5694 | SSIM: 0.0610 | PSNR: 12.2352 | Acc: 0.8389
#
# Epoch [975/1000] Batch [0/25] D_loss: -1.9111 G_loss: 7.8566
# Epoch [975/1000] Batch [10/25] D_loss: -2.1421 G_loss: N/A
# Epoch [975/1000] Batch [20/25] D_loss: -1.5328 G_loss: N/A
#
# Epoch 975 completed in 65.42s | FID: 1.9986 | IS: 0.5465 | SSIM: 0.0610 | PSNR: 12.2146 | Acc: 0.7861
#
# Epoch [976/1000] Batch [0/25] D_loss: -1.9425 G_loss: 8.0663
# Epoch [976/1000] Batch [10/25] D_loss: -1.8525 G_loss: N/A
# Epoch [976/1000] Batch [20/25] D_loss: -1.6153 G_loss: N/A
#
# Epoch 976 completed in 64.81s | FID: 5.0630 | IS: 0.5830 | SSIM: 0.0537 | PSNR: 11.9577 | Acc: 0.8319
#
# Epoch [977/1000] Batch [0/25] D_loss: -1.8291 G_loss: 7.4372
# Epoch [977/1000] Batch [10/25] D_loss: -1.7044 G_loss: N/A
# Epoch [977/1000] Batch [20/25] D_loss: -2.0505 G_loss: N/A
#
# Epoch 977 completed in 64.92s | FID: 6.2303 | IS: 0.5678 | SSIM: 0.0615 | PSNR: 12.2610 | Acc: 0.8292
#
# Epoch [978/1000] Batch [0/25] D_loss: -2.2100 G_loss: 7.8242
# Epoch [978/1000] Batch [10/25] D_loss: -1.3719 G_loss: N/A
# Epoch [978/1000] Batch [20/25] D_loss: -1.8523 G_loss: N/A
#
# Epoch 978 completed in 65.09s | FID: 2.3573 | IS: 0.5478 | SSIM: 0.0599 | PSNR: 12.2176 | Acc: 0.8236
#
# Epoch [979/1000] Batch [0/25] D_loss: -1.4083 G_loss: 7.2321
# Epoch [979/1000] Batch [10/25] D_loss: -1.7623 G_loss: N/A
# Epoch [979/1000] Batch [20/25] D_loss: -1.8846 G_loss: N/A
#
# Epoch 979 completed in 64.60s | FID: 3.9178 | IS: 0.5678 | SSIM: 0.0632 | PSNR: 12.2893 | Acc: 0.8417
#
# Epoch [980/1000] Batch [0/25] D_loss: -1.8269 G_loss: 7.5465
# Epoch [980/1000] Batch [10/25] D_loss: -1.6987 G_loss: N/A
# Epoch [980/1000] Batch [20/25] D_loss: -2.2303 G_loss: N/A
#
# Epoch 980 completed in 64.49s | FID: 10.3498 | IS: 0.6545 | SSIM: 0.0630 | PSNR: 12.4196 | Acc: 0.8194
#
# Epoch [981/1000] Batch [0/25] D_loss: -1.4356 G_loss: 7.5966
# Epoch [981/1000] Batch [10/25] D_loss: -1.7054 G_loss: N/A
# Epoch [981/1000] Batch [20/25] D_loss: -2.0112 G_loss: N/A
#
# Epoch 981 completed in 64.83s | FID: 3.7916 | IS: 0.5444 | SSIM: 0.0612 | PSNR: 12.2425 | Acc: 0.8014
#
# Epoch [982/1000] Batch [0/25] D_loss: -2.0267 G_loss: 7.8874
# Epoch [982/1000] Batch [10/25] D_loss: -1.6235 G_loss: N/A
# Epoch [982/1000] Batch [20/25] D_loss: -1.6535 G_loss: N/A
#
# Epoch 982 completed in 65.53s | FID: 3.2193 | IS: 0.5587 | SSIM: 0.0584 | PSNR: 12.3053 | Acc: 0.8056
#
# Epoch [983/1000] Batch [0/25] D_loss: -1.6323 G_loss: 7.7783
# Epoch [983/1000] Batch [10/25] D_loss: -2.1979 G_loss: N/A
# Epoch [983/1000] Batch [20/25] D_loss: -1.8401 G_loss: N/A
#
# Epoch 983 completed in 65.23s | FID: 2.7918 | IS: 0.6196 | SSIM: 0.0611 | PSNR: 12.1688 | Acc: 0.8208
#
# Epoch [984/1000] Batch [0/25] D_loss: -1.6221 G_loss: 7.3773
# Epoch [984/1000] Batch [10/25] D_loss: -1.7400 G_loss: N/A
# Epoch [984/1000] Batch [20/25] D_loss: -2.2158 G_loss: N/A
#
# Epoch 984 completed in 64.47s | FID: 2.2452 | IS: 0.5443 | SSIM: 0.0546 | PSNR: 11.9861 | Acc: 0.8000
#
# Epoch [985/1000] Batch [0/25] D_loss: -2.0051 G_loss: 8.0304
# Epoch [985/1000] Batch [10/25] D_loss: -1.5163 G_loss: N/A
# Epoch [985/1000] Batch [20/25] D_loss: -1.6937 G_loss: N/A
#
# Epoch 985 completed in 64.41s | FID: 3.3874 | IS: 0.5752 | SSIM: 0.0572 | PSNR: 12.0620 | Acc: 0.7861
#
# Epoch [986/1000] Batch [0/25] D_loss: -1.5739 G_loss: 7.9156
# Epoch [986/1000] Batch [10/25] D_loss: -1.9536 G_loss: N/A
# Epoch [986/1000] Batch [20/25] D_loss: -1.9649 G_loss: N/A
#
# Epoch 986 completed in 64.97s | FID: 5.3973 | IS: 0.6694 | SSIM: 0.0616 | PSNR: 12.3389 | Acc: 0.8417
#
# Epoch [987/1000] Batch [0/25] D_loss: -1.7789 G_loss: 7.7994
# Epoch [987/1000] Batch [10/25] D_loss: -1.5825 G_loss: N/A
# Epoch [987/1000] Batch [20/25] D_loss: -1.9722 G_loss: N/A
#
# Epoch 987 completed in 65.31s | FID: 2.6903 | IS: 0.5302 | SSIM: 0.0575 | PSNR: 12.0757 | Acc: 0.8222
#
# Epoch [988/1000] Batch [0/25] D_loss: -1.6340 G_loss: 7.6134
# Epoch [988/1000] Batch [10/25] D_loss: -2.1669 G_loss: N/A
# Epoch [988/1000] Batch [20/25] D_loss: -1.5393 G_loss: N/A
#
# Epoch 988 completed in 65.02s | FID: 3.4878 | IS: 0.5905 | SSIM: 0.0587 | PSNR: 12.2032 | Acc: 0.8361
#
# Epoch [989/1000] Batch [0/25] D_loss: -2.1018 G_loss: 7.8161
# Epoch [989/1000] Batch [10/25] D_loss: -1.9903 G_loss: N/A
# Epoch [989/1000] Batch [20/25] D_loss: -1.5414 G_loss: N/A
#
# Epoch 989 completed in 65.07s | FID: 5.6595 | IS: 0.5665 | SSIM: 0.0549 | PSNR: 12.0348 | Acc: 0.7528
#
# Epoch [990/1000] Batch [0/25] D_loss: -1.6715 G_loss: 7.8151
# Epoch [990/1000] Batch [10/25] D_loss: -1.7542 G_loss: N/A
# Epoch [990/1000] Batch [20/25] D_loss: -1.6196 G_loss: N/A
#
# Epoch 990 completed in 64.28s | FID: 0.5916 | IS: 0.5245 | SSIM: 0.0593 | PSNR: 12.1783 | Acc: 0.8222
#
# Epoch [991/1000] Batch [0/25] D_loss: -1.4629 G_loss: 7.7828
# Epoch [991/1000] Batch [10/25] D_loss: -1.7930 G_loss: N/A
# Epoch [991/1000] Batch [20/25] D_loss: -1.3783 G_loss: N/A
#
# Epoch 991 completed in 64.94s | FID: 8.8104 | IS: 0.5988 | SSIM: 0.0544 | PSNR: 12.0366 | Acc: 0.7569
#
# Epoch [992/1000] Batch [0/25] D_loss: -1.5542 G_loss: 7.6023
# Epoch [992/1000] Batch [10/25] D_loss: -2.2914 G_loss: N/A
# Epoch [992/1000] Batch [20/25] D_loss: -1.8266 G_loss: N/A
#
# Epoch 992 completed in 65.25s | FID: 13.4116 | IS: 0.5848 | SSIM: 0.0612 | PSNR: 12.4068 | Acc: 0.8569
#
# Epoch [993/1000] Batch [0/25] D_loss: -1.9647 G_loss: 7.7850
# Epoch [993/1000] Batch [10/25] D_loss: -1.9494 G_loss: N/A
# Epoch [993/1000] Batch [20/25] D_loss: -2.3489 G_loss: N/A
#
# Epoch 993 completed in 65.01s | FID: 3.5933 | IS: 0.5331 | SSIM: 0.0577 | PSNR: 12.0887 | Acc: 0.8014
#
# Epoch [994/1000] Batch [0/25] D_loss: -2.4181 G_loss: 8.0636
# Epoch [994/1000] Batch [10/25] D_loss: -1.8931 G_loss: N/A
# Epoch [994/1000] Batch [20/25] D_loss: -1.6352 G_loss: N/A
#
# Epoch 994 completed in 66.19s | FID: 3.0047 | IS: 0.5645 | SSIM: 0.0558 | PSNR: 12.0433 | Acc: 0.8403
#
# Epoch [995/1000] Batch [0/25] D_loss: -1.5358 G_loss: 7.7552
# Epoch [995/1000] Batch [10/25] D_loss: -1.7319 G_loss: N/A
# Epoch [995/1000] Batch [20/25] D_loss: -1.8769 G_loss: N/A
#
# Epoch 995 completed in 65.48s | FID: 13.3185 | IS: 0.5877 | SSIM: 0.0605 | PSNR: 12.1485 | Acc: 0.8069
#
# Epoch [996/1000] Batch [0/25] D_loss: -1.9433 G_loss: 8.0364
# Epoch [996/1000] Batch [10/25] D_loss: -2.2286 G_loss: N/A
# Epoch [996/1000] Batch [20/25] D_loss: -2.2118 G_loss: N/A
#
# Epoch 996 completed in 63.91s | FID: 6.6083 | IS: 0.5540 | SSIM: 0.0609 | PSNR: 12.2779 | Acc: 0.8750
#
# Epoch [997/1000] Batch [0/25] D_loss: -1.8000 G_loss: 7.7097
# Epoch [997/1000] Batch [10/25] D_loss: -1.9679 G_loss: N/A
# Epoch [997/1000] Batch [20/25] D_loss: -1.9166 G_loss: N/A
#
# Epoch 997 completed in 65.40s | FID: 5.7517 | IS: 0.5985 | SSIM: 0.0610 | PSNR: 12.3559 | Acc: 0.8139
#
# Epoch [998/1000] Batch [0/25] D_loss: -1.6981 G_loss: 7.5885
# Epoch [998/1000] Batch [10/25] D_loss: -2.1796 G_loss: N/A
# Epoch [998/1000] Batch [20/25] D_loss: -1.8912 G_loss: N/A
#
# Epoch 998 completed in 65.18s | FID: 6.6611 | IS: 0.5812 | SSIM: 0.0598 | PSNR: 12.2974 | Acc: 0.8319
#
# Epoch [999/1000] Batch [0/25] D_loss: -2.1849 G_loss: 7.8105
# Epoch [999/1000] Batch [10/25] D_loss: -1.7191 G_loss: N/A
# Epoch [999/1000] Batch [20/25] D_loss: -1.8756 G_loss: N/A
#
# Epoch 999 completed in 64.47s | FID: 1.9989 | IS: 0.5475 | SSIM: 0.0617 | PSNR: 12.2373 | Acc: 0.7806
#
# Epoch [1000/1000] Batch [0/25] D_loss: -1.8553 G_loss: 7.8607
# Epoch [1000/1000] Batch [10/25] D_loss: -2.1060 G_loss: N/A
# Epoch [1000/1000] Batch [20/25] D_loss: -1.6064 G_loss: N/A
#
# Epoch 1000 completed in 65.13s | FID: 5.0430 | IS: 0.5851 | SSIM: 0.0591 | PSNR: 12.1349 | Acc: 0.8250
#
# Saved samples for epoch 1000
