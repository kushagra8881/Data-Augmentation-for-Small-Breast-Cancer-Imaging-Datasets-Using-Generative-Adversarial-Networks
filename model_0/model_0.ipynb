# %%
import os
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
from torchvision import transforms
import torch.nn.functional as F
from torch.nn.utils import spectral_norm

# Configuration based on paper recommendations
SEED = 60
IMG_SIZE = 256
BATCH_SIZE = 8
LATENT_DIM = 256

# Modified Configuration
LAMBDA_GP = 5.0  # Reduced from 10
LAMBDA_PIXEL = 3.0  # Reduced from 5.0
LAMBDA_PEARSON = 5.0  # Increased from 2.0
LR = 0.0001  # Reduced from 0.0002
N_CRITIC = 3  # Reduced from 5
BASE_CHANNELS = 128  # Increased capacity
BETAS = (0.5, 0.9)  # More conservative momentum
EPOCHS = 1000

# Set seed for reproducibility
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Enhanced Dataset Class
class MedicalDataset(Dataset):
    def __init__(self, root_dir, img_size=256):
        self.image_paths = []
        self.labels = []
        self.img_size = img_size
        self.transform = transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.3),
            transforms.Lambda(lambda x: 2 * x - 1)  # Normalize to [-1, 1]
        ])

        # Load data with binary labels (0/1)
        for label in ['0', '1']:
            folder = os.path.join(root_dir, label)
            if os.path.exists(folder):
                for fname in os.listdir(folder):
                    if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                        self.image_paths.append(os.path.join(folder, fname))
                        self.labels.append(int(label))

    def __getitem__(self, idx):
        img = cv2.imread(self.image_paths[idx], cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (self.img_size, self.img_size))
        img = img.astype(np.float32) / 255.0  # Normalize to [0, 1]
        img = torch.tensor(img).unsqueeze(0)  # Add channel dimension
        img = self.transform(img)
        return img, torch.tensor(self.labels[idx], dtype=torch.float32)

    def __len__(self):
        return len(self.image_paths)

# Residual Block for Generator (StyleGAN-inspired)
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv = nn.Sequential(
            spectral_norm(nn.Conv2d(channels, channels, 3, padding=1)),
            nn.BatchNorm2d(channels),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(channels, channels, 3, padding=1)),
            nn.BatchNorm2d(channels)
        )
        
    def forward(self, x):
        return F.leaky_relu(x + self.conv(x), 0.2)

# Enhanced Generator with Residual Connections
class MedicalGenerator(nn.Module):
    def __init__(self):
        super().__init__()
        self.init_size = IMG_SIZE // 32
        self.fc = nn.Sequential(
            spectral_norm(nn.Linear(LATENT_DIM + 1, BASE_CHANNELS * 32 * self.init_size ** 2)),
            nn.BatchNorm1d(BASE_CHANNELS * 32 * self.init_size ** 2),
            nn.LeakyReLU(0.2)
        )
        
        self.blocks = nn.Sequential(
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*32, BASE_CHANNELS*16, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*16),
            nn.LeakyReLU(0.2),
            ResidualBlock(BASE_CHANNELS*16),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*16, BASE_CHANNELS*8, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*8),
            nn.LeakyReLU(0.2),
            ResidualBlock(BASE_CHANNELS*8),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*8, BASE_CHANNELS*4, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*4),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*4, BASE_CHANNELS*2, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*2),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*2, BASE_CHANNELS, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS, 1, 3, padding=1)),
            nn.Tanh()
        )

    def forward(self, z, labels):
        labels = labels.view(-1, 1)
        z = torch.cat([z, labels], 1)
        x = self.fc(z).view(-1, BASE_CHANNELS*32, self.init_size, self.init_size)
        return self.blocks(x)

# Enhanced Discriminator with Spectral Norm
class MedicalDiscriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            spectral_norm(nn.Conv2d(2, BASE_CHANNELS, 4, 2, 1)),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS, BASE_CHANNELS*2, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*2),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*2, BASE_CHANNELS*4, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*4),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*4, BASE_CHANNELS*8, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*8),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*8, BASE_CHANNELS*16, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*16),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*16, 1, 4, 1, 0))
        )

    def forward(self, img, labels):
        labels = labels.view(-1, 1, 1, 1).expand(-1, 1, IMG_SIZE, IMG_SIZE)
        x = torch.cat([img, labels], 1)
        return self.model(x).view(-1)

# Pearson Correlation Loss Function
def pearson_correlation_loss(x, y):
    """
    Computes Pearson correlation coefficient loss between two batches of images
    """
    # Flatten spatial dimensions
    x_flat = x.view(x.size(0), -1)
    y_flat = y.view(y.size(0), -1)
    
    # Compute means
    x_mean = torch.mean(x_flat, dim=1, keepdim=True)
    y_mean = torch.mean(y_flat, dim=1, keepdim=True)
    
    # Compute covariance and variances
    covariance = torch.mean((x_flat - x_mean) * (y_flat - y_mean), dim=1)
    x_var = torch.var(x_flat, dim=1)
    y_var = torch.var(y_flat, dim=1)
    
    # Compute Pearson correlation
    pearson = covariance / (torch.sqrt(x_var) * torch.sqrt(y_var) + 1e-8)
    
    # Return loss as 1 - average correlation
    return 1 - torch.mean(pearson)

# Complete GAN Training System
class StableGAN:
    def __init__(self):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        # Initialize networks
        self.netG = MedicalGenerator().to(self.device)
        self.netD = MedicalDiscriminator().to(self.device)
        
        # Optimizers
        self.optimG = optim.Adam(self.netG.parameters(), lr=LR, betas=BETAS)
        self.optimD = optim.Adam(self.netD.parameters(), lr=LR, betas=BETAS)
        
        # Data loading
        self.dataset = MedicalDataset("medical_data")
        self.loader = DataLoader(self.dataset, BATCH_SIZE, shuffle=True, num_workers=4)
        
        # Tracking
        self.metrics = {'d_loss': [], 'g_loss': [], 'pearson': []}
        self.fixed_z = torch.randn(2, LATENT_DIM, device=self.device)  # For consistent sampling

    def compute_gradient_penalty(self, real_samples, fake_samples, labels):
        """Calculates the gradient penalty loss for WGAN-GP"""
        alpha = torch.rand(real_samples.size(0), 1, 1, 1, device=self.device)
        interpolates = (alpha * real_samples + (1 - alpha) * fake_samples).requires_grad_(True)
        d_interpolates = self.netD(interpolates, labels)
        
        gradients = torch.autograd.grad(
            outputs=d_interpolates,
            inputs=interpolates,
            grad_outputs=torch.ones_like(d_interpolates),
            create_graph=True,
            retain_graph=True,
        )[0]
        
        gradients = gradients.view(gradients.size(0), -1)
        gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()
        return gradient_penalty

    def train_epoch(self, epoch):
        self.netG.train()
        self.netD.train()
        
        for batch_idx, (real_imgs, labels) in enumerate(self.loader):
            real_imgs = real_imgs.to(self.device)
            labels = labels.to(self.device)
            batch_size = real_imgs.size(0)
            
            # --- Discriminator Update ---
            self.optimD.zero_grad()
            
            # Generate fake images
            z = torch.randn(batch_size, LATENT_DIM, device=self.device)
            fake_imgs = self.netG(z, labels)
            
            # Compute discriminator losses
            d_real = self.netD(real_imgs, labels)
            d_fake = self.netD(fake_imgs.detach(), labels)
            
            # Gradient penalty
            gp = self.compute_gradient_penalty(real_imgs, fake_imgs, labels)
            
            # WGAN-GP loss
            d_loss = -torch.mean(d_real) + torch.mean(d_fake) + LAMBDA_GP * gp
            d_loss.backward()
            self.optimD.step()
            
            # --- Generator Update ---
            if batch_idx % N_CRITIC == 0:
                self.optimG.zero_grad()
                
                # Generate new fake images
                z = torch.randn(batch_size, LATENT_DIM, device=self.device)
                fake_imgs = self.netG(z, labels)
                
                # Adversarial loss
                g_adv = -torch.mean(self.netD(fake_imgs, labels))
                
                # Pixel-wise L1 loss
                px_loss = F.l1_loss(fake_imgs, real_imgs)
                
                # Pearson correlation loss
                pearson_loss = pearson_correlation_loss(fake_imgs, real_imgs)
                
                # Total generator loss
                g_total = g_adv + LAMBDA_PIXEL*px_loss + LAMBDA_PEARSON*pearson_loss
                g_total.backward()
                self.optimG.step()
                
                # Update metrics
                with torch.no_grad():
                    self.metrics['g_loss'].append(g_total.item())
                    self.metrics['pearson'].append(1 - pearson_loss.item())  # Store actual correlation
                    
            # Progress reporting
            if batch_idx % 25 == 0:
                print(f"Epoch [{epoch}/{EPOCHS}] Batch [{batch_idx}/{len(self.loader)}] "
                      f"D_loss: {d_loss.item():.4f} G_loss: {g_total.item():.4f} "
                      f"Pearson: {1 - pearson_loss.item():.4f}")

    def save_samples(self, epoch):
        """Saves generated samples for both labels"""
        self.netG.eval()
        os.makedirs("samples", exist_ok=True)
        
        with torch.no_grad():
            for label in [0, 1]:
                # Generate images for current label
                labels = torch.full((2,), label, device=self.device, dtype=torch.float32)
                gen_imgs = self.netG(self.fixed_z, labels)
                
                # Process and save images
                for i in range(2):
                    img = gen_imgs[i].cpu().squeeze().numpy()
                    img = (img + 1) * 127.5  # Convert from [-1,1] to [0,255]
                    img = img.astype(np.uint8)
                    cv2.imwrite(f"samples/epoch_{epoch}_label_{label}_sample_{i}.png", img)
        
        self.netG.train()

    def train(self):
        """Main training loop"""
        for epoch in range(1, EPOCHS + 1):
            self.train_epoch(epoch)
            
            # Save checkpoints
            
            # Save samples
            if epoch % 200 == 0:
                self.save_samples(epoch)
                print(f"Saved samples for epoch {epoch}")
                
        # Final save
        torch.save({
            'generator': self.netG.state_dict(),
            'discriminator': self.netD.state_dict(),
            'metrics': self.metrics
        }, "gan_final.pth")

if __name__ == "__main__":
    gan = StableGAN()
    gan.train()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 317
#     315 if __name__ == "__main__":
#     316     gan = StableGAN()
# --> 317     gan.train()
#
# Cell In[1], line 299, in StableGAN.train(self)
#     297 """Main training loop"""
#     298 for epoch in range(1, EPOCHS + 1):
# --> 299     self.train_epoch(epoch)
#     301     # Save checkpoints
#     302
#     303     # Save samples
#     304     if epoch % 200 == 0:
#
# Cell In[1], line 219, in StableGAN.train_epoch(self, epoch)
#     216 self.netG.train()
#     217 self.netD.train()
# --> 219 for batch_idx, (real_imgs, labels) in enumerate(self.loader):
#     220     real_imgs = real_imgs.to(self.device)
#     221     labels = labels.to(self.device)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\data\dataloader.py:491, in DataLoader.__iter__(self)
#     489     return self._iterator
#     490 else:
# --> 491     return self._get_iterator()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\data\dataloader.py:422, in DataLoader._get_iterator(self)
#     420 else:
#     421     self.check_worker_number_rationality()
# --> 422     return _MultiProcessingDataLoaderIter(self)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\data\dataloader.py:1146, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1139 w.daemon = True
#    1140 # NB: Process.start() actually take some time as it needs to
#    1141 #     start a process and pass the arguments over via a pipe.
#    1142 #     Therefore, we only add a worker to self._workers list after
#    1143 #     it started, so that we do not call .join() if program dies
#    1144 #     before it starts, and __del__ tries to join but will get:
#    1145 #     AssertionError: can only join a started process.
# -> 1146 w.start()
#    1147 self._index_queues.append(index_queue)
#    1148 self._workers.append(w)
#
# File c:\Program Files\Python311\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File c:\Program Files\Python311\Lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File c:\Program Files\Python311\Lib\multiprocessing\context.py:336, in SpawnProcess._Popen(process_obj)
#     333 @staticmethod
#     334 def _Popen(process_obj):
#     335     from .popen_spawn_win32 import Popen
# --> 336     return Popen(process_obj)
#
# File c:\Program Files\Python311\Lib\multiprocessing\popen_spawn_win32.py:94, in Popen.__init__(self, process_obj)
#      92 try:
#      93     reduction.dump(prep_data, to_child)
# ---> 94     reduction.dump(process_obj, to_child)
#      95 finally:
#      96     set_spawning_popen(None)
#
# File c:\Program Files\Python311\Lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# AttributeError: Can't pickle local object 'MedicalDataset.__init__.<locals>.<lambda>'

# %%
import os
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
from torchvision import transforms
import torch.nn.functional as F
from torch.nn.utils import spectral_norm
from time import time
from datetime import datetime
from sklearn.metrics import confusion_matrix
import json

# Configuration based on paper recommendations
SEED = 60
IMG_SIZE = 256
BATCH_SIZE = 8
LATENT_DIM = 256

# Modified Configuration
LAMBDA_GP = 5.0  # Reduced from 10
LAMBDA_PIXEL = 3.0  # Reduced from 5.0
LAMBDA_PEARSON = 5.0  # Increased from 2.0
LR = 0.0001  # Reduced from 0.0002
N_CRITIC = 3  # Reduced from 5
BASE_CHANNELS = 128  # Increased capacity
BETAS = (0.5, 0.9)  # More conservative momentum
EPOCHS = 1000

# Set seed for reproducibility
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Define normalize function outside of the transform to make it picklable
def normalize_image(x):
    return 2 * x - 1  # Normalize to [-1, 1]

# Enhanced Dataset Class
class MedicalDataset(Dataset):
    def __init__(self, root_dir, img_size=256):
        self.image_paths = []
        self.labels = []
        self.img_size = img_size
        self.transform = transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.3),
            transforms.Lambda(normalize_image)  # Using named function instead of lambda
        ])

        # Load data with binary labels (0/1)
        for label in ['0', '1']:
            folder = os.path.join(root_dir, label)
            if os.path.exists(folder):
                for fname in os.listdir(folder):
                    if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                        self.image_paths.append(os.path.join(folder, fname))
                        self.labels.append(int(label))

    def __getitem__(self, idx):
        img = cv2.imread(self.image_paths[idx], cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (self.img_size, self.img_size))
        img = img.astype(np.float32) / 255.0  # Normalize to [0, 1]
        img = torch.tensor(img).unsqueeze(0)  # Add channel dimension
        img = self.transform(img)
        return img, torch.tensor(self.labels[idx], dtype=torch.float32)

    def __len__(self):
        return len(self.image_paths)

# Residual Block for Generator (StyleGAN-inspired)
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv = nn.Sequential(
            spectral_norm(nn.Conv2d(channels, channels, 3, padding=1)),
            nn.BatchNorm2d(channels),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(channels, channels, 3, padding=1)),
            nn.BatchNorm2d(channels)
        )
        
    def forward(self, x):
        return F.leaky_relu(x + self.conv(x), 0.2)

# Enhanced Generator with Residual Connections
class MedicalGenerator(nn.Module):
    def __init__(self):
        super().__init__()
        self.init_size = IMG_SIZE // 32
        self.fc = nn.Sequential(
            spectral_norm(nn.Linear(LATENT_DIM + 1, BASE_CHANNELS * 32 * self.init_size ** 2)),
            nn.BatchNorm1d(BASE_CHANNELS * 32 * self.init_size ** 2),
            nn.LeakyReLU(0.2)
        )
        
        self.blocks = nn.Sequential(
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*32, BASE_CHANNELS*16, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*16),
            nn.LeakyReLU(0.2),
            ResidualBlock(BASE_CHANNELS*16),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*16, BASE_CHANNELS*8, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*8),
            nn.LeakyReLU(0.2),
            ResidualBlock(BASE_CHANNELS*8),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*8, BASE_CHANNELS*4, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*4),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*4, BASE_CHANNELS*2, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS*2),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*2, BASE_CHANNELS, 3, padding=1)),
            nn.BatchNorm2d(BASE_CHANNELS),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS, 1, 3, padding=1)),
            nn.Tanh()
        )

    def forward(self, z, labels):
        labels = labels.view(-1, 1)
        z = torch.cat([z, labels], 1)
        x = self.fc(z).view(-1, BASE_CHANNELS*32, self.init_size, self.init_size)
        return self.blocks(x)

# Enhanced Discriminator with Spectral Norm
class MedicalDiscriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            spectral_norm(nn.Conv2d(2, BASE_CHANNELS, 4, 2, 1)),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS, BASE_CHANNELS*2, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*2),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*2, BASE_CHANNELS*4, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*4),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*4, BASE_CHANNELS*8, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*8),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*8, BASE_CHANNELS*16, 4, 2, 1)),
            nn.InstanceNorm2d(BASE_CHANNELS*16),
            nn.LeakyReLU(0.2),
            spectral_norm(nn.Conv2d(BASE_CHANNELS*16, 1, 4, 1, 0))
        )

    def forward(self, img, labels):
        labels = labels.view(-1, 1, 1, 1).expand(-1, 1, IMG_SIZE, IMG_SIZE)
        x = torch.cat([img, labels], 1)
        return self.model(x).view(-1)

# Classifier for evaluating generated images
class MedicalClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 64, 3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 128, 3, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.Conv2d(128, 256, 3, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Dropout(0.3),
            nn.Linear(256, 64),
            nn.LeakyReLU(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        return self.model(x)

# Structural Similarity Index (SSIM) for image quality assessment
def ssim(img1, img2, window_size=11, size_average=True):
    # Value range can be different from 0 to 255. So normalize images.
    if img1.max() > 128:
        img1 = img1 / 255.0
    if img2.max() > 128:
        img2 = img2 / 255.0
    
    if not img1.shape == img2.shape:
        raise ValueError('Input images must have the same dimensions.')
    
    # Compute means
    mu1 = F.avg_pool2d(img1, window_size, stride=1, padding=window_size//2)
    mu2 = F.avg_pool2d(img2, window_size, stride=1, padding=window_size//2)
    
    # Compute squares of means
    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1 * mu2
    
    # Compute variances and covariance
    sigma1_sq = F.avg_pool2d(img1 * img1, window_size, stride=1, padding=window_size//2) - mu1_sq
    sigma2_sq = F.avg_pool2d(img2 * img2, window_size, stride=1, padding=window_size//2) - mu2_sq
    sigma12 = F.avg_pool2d(img1 * img2, window_size, stride=1, padding=window_size//2) - mu1_mu2
    
    # SSIM constants
    C1 = 0.01 ** 2
    C2 = 0.03 ** 2
    
    # Compute SSIM
    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2))
    
    if size_average:
        return ssim_map.mean()
    else:
        return ssim_map.mean(1).mean(1).mean(1)

# Pearson Correlation Loss Function
def pearson_correlation_loss(x, y):
    """
    Computes Pearson correlation coefficient loss between two batches of images
    """
    # Flatten spatial dimensions
    x_flat = x.view(x.size(0), -1)
    y_flat = y.view(y.size(0), -1)
    
    # Compute means
    x_mean = torch.mean(x_flat, dim=1, keepdim=True)
    y_mean = torch.mean(y_flat, dim=1, keepdim=True)
    
    # Compute covariance and variances
    covariance = torch.mean((x_flat - x_mean) * (y_flat - y_mean), dim=1)
    x_var = torch.var(x_flat, dim=1)
    y_var = torch.var(y_flat, dim=1)
    
    # Compute Pearson correlation
    pearson = covariance / (torch.sqrt(x_var) * torch.sqrt(y_var) + 1e-8)
    
    # Return loss as 1 - average correlation
    return 1 - torch.mean(pearson)

# Compute Frechet Inception Distance (FID) approximation
def compute_fid_proxy(real_features, fake_features):
    """
    Simplified FID calculation since we don't have Inception network.
    This uses feature embeddings from our discriminator/classifier instead.
    """
    # Calculate mean and covariance for real and fake features
    mu1 = torch.mean(real_features, dim=0)
    sigma1 = torch.cov(real_features.T)
    
    mu2 = torch.mean(fake_features, dim=0)
    sigma2 = torch.cov(fake_features.T)
    
    # Calculate squared difference between means
    diff = mu1 - mu2
    mean_diff = torch.sum(diff * diff)
    
    # Calculate matrix sqrt - approximation for FID
    # This is a simplified version - true FID uses matrix sqrt
    covmean = torch.sqrt(sigma1 * sigma2 + 1e-8)
    
    # Calculate trace
    trace_term = torch.trace(sigma1 + sigma2 - 2 * covmean)
    
    # FID
    fid = mean_diff + trace_term
    return fid

# Complete GAN Training System
class StableGAN:
    def __init__(self, data_folder="medical_data"):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {self.device}")
        
        # Initialize networks
        self.netG = MedicalGenerator().to(self.device)
        self.netD = MedicalDiscriminator().to(self.device)
        
        # Add classifier for quality evaluation
        self.classifier = MedicalClassifier().to(self.device)
        self.classifier_optim = optim.Adam(self.classifier.parameters(), lr=LR*0.5)
        self.classifier_criterion = nn.BCELoss()
        
        # Optimizers
        self.optimG = optim.Adam(self.netG.parameters(), lr=LR, betas=BETAS)
        self.optimD = optim.Adam(self.netD.parameters(), lr=LR, betas=BETAS)
        
        # Learning rate schedulers
        self.schedulerG = optim.lr_scheduler.ReduceLROnPlateau(self.optimG, 'min', factor=0.5, patience=30, verbose=True)
        self.schedulerD = optim.lr_scheduler.ReduceLROnPlateau(self.optimD, 'min', factor=0.5, patience=30, verbose=True)
        
        # Data loading - use num_workers=0 to avoid multiprocessing issues with lambda
        self.dataset = MedicalDataset(data_folder, img_size=IMG_SIZE)
        self.loader = DataLoader(self.dataset, BATCH_SIZE, shuffle=True, num_workers=0)
        
        # Tracking
        self.metrics = {
            'd_loss': [], 'g_loss': [], 'pearson': [], 'ssim': [], 
            'fid_proxy': [], 'classifier_acc': [], 'train_time': [],
            'inception_score_proxy': [], 'psnr': []
        }
        
        # Create fixed noise for consistent sampling
        self.fixed_z = torch.randn(8, LATENT_DIM, device=self.device)  # Increased samples
        self.fixed_labels_0 = torch.zeros(4, device=self.device)
        self.fixed_labels_1 = torch.ones(4, device=self.device)
        self.fixed_labels = torch.cat([self.fixed_labels_0, self.fixed_labels_1])
        
        # Create run directory
        self.run_dir = f"gan_run_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        os.makedirs(f"{self.run_dir}/samples", exist_ok=True)
        os.makedirs(f"{self.run_dir}/checkpoints", exist_ok=True)

    def compute_gradient_penalty(self, real_samples, fake_samples, labels):
        """Calculates the gradient penalty loss for WGAN-GP"""
        alpha = torch.rand(real_samples.size(0), 1, 1, 1, device=self.device)
        interpolates = (alpha * real_samples + (1 - alpha) * fake_samples).requires_grad_(True)
        d_interpolates = self.netD(interpolates, labels)
        
        gradients = torch.autograd.grad(
            outputs=d_interpolates,
            inputs=interpolates,
            grad_outputs=torch.ones_like(d_interpolates),
            create_graph=True,
            retain_graph=True,
        )[0]
        
        gradients = gradients.view(gradients.size(0), -1)
        gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()
        return gradient_penalty

    def train_classifier(self, real_imgs, fake_imgs, labels, steps=1):
        """Train the classifier on both real and fake images"""
        for _ in range(steps):
            self.classifier_optim.zero_grad()
            
            # Create a batch with both real and fake images
            all_imgs = torch.cat([real_imgs, fake_imgs.detach()], 0)
            all_labels = torch.cat([labels, labels], 0)
            
            # Forward pass
            pred = self.classifier(all_imgs).squeeze()
            loss = self.classifier_criterion(pred, all_labels)
            
            # Backward pass
            loss.backward()
            self.classifier_optim.step()
            
            # Calculate accuracy
            pred_binary = (pred > 0.5).float()
            acc = (pred_binary == all_labels).float().mean()
            
        return acc.item()

    def compute_psnr(self, real_imgs, fake_imgs):
        """Compute Peak Signal-to-Noise Ratio"""
        mse = F.mse_loss(fake_imgs, real_imgs)
        if mse == 0:
            return 100
        max_pixel = 2.0  # Since images are normalized to [-1, 1]
        psnr = 20 * torch.log10(max_pixel / torch.sqrt(mse))
        return psnr.item()

    def compute_inception_score_proxy(self, fake_imgs, eps=1e-8):
        """Compute a proxy for inception score using our classifier"""
        self.classifier.eval()
        with torch.no_grad():
            preds = self.classifier(fake_imgs).squeeze()
            # Calculate proxy for inception score
            kl_div = preds * torch.log(preds + eps) + (1 - preds) * torch.log(1 - preds + eps)
            inception_score = torch.exp(torch.mean(kl_div))
        self.classifier.train()
        return inception_score.item()

    def extract_features(self, imgs):
        """Extract features from the classifier for FID calculation"""
        # Use the second-to-last layer of the classifier as features
        x = self.classifier.model[0](imgs)
        x = self.classifier.model[1](x)
        x = self.classifier.model[2](x)
        x = self.classifier.model[3](x)
        x = self.classifier.model[4](x)
        x = self.classifier.model[5](x)
        x = self.classifier.model[6](x)
        x = self.classifier.model[7](x)
        x = self.classifier.model[8](x)
        x = self.classifier.model[9](x)
        x = self.classifier.model[10](x)
        x = self.classifier.model[11](x)
        x = self.classifier.model[12](x)
        x = self.classifier.model[13](x)
        # Return flattened features
        return x.view(x.size(0), -1)

    def train_epoch(self, epoch):
        self.netG.train()
        self.netD.train()
        self.classifier.train()
        
        epoch_metrics = {
            'd_loss': [], 'g_loss': [], 'pearson': [], 'ssim': [], 
            'psnr': [], 'classifier_acc': []
        }
        
        epoch_start_time = time()
        
        for batch_idx, (real_imgs, labels) in enumerate(self.loader):
            real_imgs = real_imgs.to(self.device)
            labels = labels.to(self.device)
            batch_size = real_imgs.size(0)
            
            # --- Discriminator Update ---
            self.optimD.zero_grad()
            
            # Generate fake images
            z = torch.randn(batch_size, LATENT_DIM, device=self.device)
            fake_imgs = self.netG(z, labels)
            
            # Compute discriminator losses
            d_real = self.netD(real_imgs, labels)
            d_fake = self.netD(fake_imgs.detach(), labels)
            
            # Gradient penalty
            gp = self.compute_gradient_penalty(real_imgs, fake_imgs, labels)
            
            # WGAN-GP loss
            d_loss = -torch.mean(d_real) + torch.mean(d_fake) + LAMBDA_GP * gp
            d_loss.backward()
            self.optimD.step()
            
            epoch_metrics['d_loss'].append(d_loss.item())
            
            # --- Generator Update ---
            if batch_idx % N_CRITIC == 0:
                self.optimG.zero_grad()
                
                # Generate new fake images
                z = torch.randn(batch_size, LATENT_DIM, device=self.device)
                fake_imgs = self.netG(z, labels)
                
                # Adversarial loss
                g_adv = -torch.mean(self.netD(fake_imgs, labels))
                
                # Pixel-wise L1 loss
                px_loss = F.l1_loss(fake_imgs, real_imgs)
                
                # Pearson correlation loss
                pearson_loss = pearson_correlation_loss(fake_imgs, real_imgs)
                
                # Total generator loss
                g_total = g_adv + LAMBDA_PIXEL*px_loss + LAMBDA_PEARSON*pearson_loss
                g_total.backward()
                self.optimG.step()
                
                # Train classifier and compute additional metrics
                with torch.no_grad():
                    # SSIM metric
                    ssim_val = ssim(fake_imgs, real_imgs).item()
                    
                    # PSNR metric
                    psnr_val = self.compute_psnr(real_imgs, fake_imgs)
                    
                    # Store metrics
                    epoch_metrics['g_loss'].append(g_total.item())
                    epoch_metrics['pearson'].append(1 - pearson_loss.item())
                    epoch_metrics['ssim'].append(ssim_val)
                    epoch_metrics['psnr'].append(psnr_val)
                
                # Train classifier on this batch
                classifier_acc = self.train_classifier(real_imgs, fake_imgs, labels)
                epoch_metrics['classifier_acc'].append(classifier_acc)
                
            # Progress reporting (less frequent)
            if batch_idx % 10 == 0:
    # Handle the conditional formatting properly
               if batch_idx % N_CRITIC == 0:
                g_loss_str = f"{g_total.item():.4f}"
               else:
                g_loss_str = "N/A"
         
               print(f"Epoch [{epoch}/{EPOCHS}] Batch [{batch_idx}/{len(self.loader)}] "
            f"D_loss: {d_loss.item():.4f} G_loss: {g_loss_str}")
        
        # Compute epoch-level metrics
        epoch_time = time() - epoch_start_time
        
        # Compute FID proxy and Inception Score proxy once per epoch on fixed samples
        with torch.no_grad():
            fake_samples = self.netG(self.fixed_z, self.fixed_labels)
            real_samples, real_labels = next(iter(self.loader))
            real_samples = real_samples.to(self.device)
            
            # Extract features for FID
            fake_features = self.extract_features(fake_samples)
            real_features = self.extract_features(real_samples)
            
            # Compute FID proxy
            fid_proxy = compute_fid_proxy(real_features, fake_features).item()
            
            # Compute Inception Score proxy
            is_proxy = self.compute_inception_score_proxy(fake_samples)
        
        # Update overall metrics
        self.metrics['d_loss'].append(np.mean(epoch_metrics['d_loss']))
        self.metrics['g_loss'].append(np.mean(epoch_metrics['g_loss']))
        self.metrics['pearson'].append(np.mean(epoch_metrics['pearson']))
        self.metrics['ssim'].append(np.mean(epoch_metrics['ssim']))
        self.metrics['classifier_acc'].append(np.mean(epoch_metrics['classifier_acc']))
        self.metrics['psnr'].append(np.mean(epoch_metrics['psnr']))
        self.metrics['fid_proxy'].append(fid_proxy)
        self.metrics['inception_score_proxy'].append(is_proxy)
        self.metrics['train_time'].append(epoch_time)
        
        # Update learning rate schedulers
        self.schedulerG.step(self.metrics['g_loss'][-1])
        self.schedulerD.step(self.metrics['d_loss'][-1])
        
        # Print epoch summary
        print(f"\nEpoch {epoch} completed in {epoch_time:.2f}s | "
              f"FID: {fid_proxy:.4f} | IS: {is_proxy:.4f} | "
              f"SSIM: {self.metrics['ssim'][-1]:.4f} | "
              f"PSNR: {self.metrics['psnr'][-1]:.4f} | "
              f"Acc: {self.metrics['classifier_acc'][-1]:.4f}\n")
        
        # Save metrics after each epoch
        with open(f"{self.run_dir}/metrics.json", 'w') as f:
            json.dump(self.metrics, f)
        
        # Plot training curves
        if epoch % 10 == 0:
            self.plot_metrics(epoch)

    def plot_metrics(self, epoch):
        """Plot and save training metrics"""
        fig, axs = plt.subplots(3, 2, figsize=(12, 15))
        
        # Plot losses
        axs[0, 0].plot(self.metrics['d_loss'], label='D Loss')
        axs[0, 0].plot(self.metrics['g_loss'], label='G Loss')
        axs[0, 0].set_title('Losses')
        axs[0, 0].legend()
        
        # Plot image quality metrics
        axs[0, 1].plot(self.metrics['pearson'], label='Pearson')
        axs[0, 1].plot(self.metrics['ssim'], label='SSIM')
        axs[0, 1].set_title('Image Quality')
        axs[0, 1].legend()
        
        # Plot FID and Inception Score
        axs[1, 0].plot(self.metrics['fid_proxy'], label='FID Proxy')
        axs[1, 0].set_title('FID Proxy (lower is better)')
        axs[1, 1].plot(self.metrics['inception_score_proxy'], label='IS Proxy')
        axs[1, 1].set_title('Inception Score Proxy')
        
        # Plot PSNR and classifier accuracy
        axs[2, 0].plot(self.metrics['psnr'], label='PSNR')
        axs[2, 0].set_title('PSNR (higher is better)')
        axs[2, 1].plot(self.metrics['classifier_acc'], label='Classifier Acc')
        axs[2, 1].set_title('Classifier Accuracy')
        
        plt.tight_layout()
        plt.savefig(f"{self.run_dir}/metrics_epoch_{epoch}.png")
        plt.close()

    def save_samples(self, epoch):
        """Saves generated samples for both labels"""
        self.netG.eval()
        
        with torch.no_grad():
            # Generate images using fixed noise
            gen_imgs = self.netG(self.fixed_z, self.fixed_labels)
            
            # Create a grid of images
            fig, axs = plt.subplots(2, 4, figsize=(16, 8))
            for i in range(8):
                row = i // 4
                col = i % 4
                img = gen_imgs[i].cpu().squeeze().numpy()
                img = (img + 1) * 0.5  # Convert from [-1,1] to [0,1]
                axs[row, col].imshow(img, cmap='gray')
                axs[row, col].set_title(f"Label: {int(self.fixed_labels[i].item())}")
                axs[row, col].axis('off')
            
            plt.tight_layout()
            plt.savefig(f"{self.run_dir}/samples/epoch_{epoch}_grid.png")
            plt.close()
            
            # Also save individual images
            for i, (img, label) in enumerate(zip(gen_imgs, self.fixed_labels)):
                img = img.cpu().squeeze().numpy()
                img = (img + 1) * 127.5  # Convert from [-1,1] to [0,255]
                img = img.astype(np.uint8)
                cv2.imwrite(f"{self.run_dir}/samples/epoch_{epoch}_label_{int(label.item())}_sample_{i}.png", img)
        
        self.netG.train()

    def save_checkpoint(self, epoch):
        """Save model checkpoint"""
        torch.save({
            'epoch': epoch,
            'generator': self.netG.state_dict(),
            'discriminator': self.netD.state_dict(),
            'classifier': self.classifier.state_dict(),
            'optimG': self.optimG.state_dict(),
            'optimD': self.optimD.state_dict(),
            'schedulerG': self.schedulerG.state_dict(),
            'schedulerD': self.schedulerD.state_dict(),
            'metrics': self.metrics
        }, f"{self.run_dir}/checkpoints/checkpoint_epoch_{epoch}.pth")
    def train(self):
    
     for epoch in range(1, EPOCHS + 1):
        self.train_epoch(epoch)
        
        # Save checkpoints
        
        
        # Save samples
        if epoch % 200 == 0:
            self.save_samples(epoch)
            print(f"Saved samples for epoch {epoch}")
        
    # Final save
     torch.save({
        'generator': self.netG.state_dict(),
        'discriminator': self.netD.state_dict(),
        'metrics': self.metrics
     }, "gan_final_1.pth")

if __name__ == "__main__":
    gan = StableGAN()
    gan.train()
# Out:
# Using device: cuda
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/1000] Batch [0/25] D_loss: 1036.8507 G_loss: 6.6730
# Epoch [1/1000] Batch [10/25] D_loss: 0.6456 G_loss: N/A
# Epoch [1/1000] Batch [20/25] D_loss: 0.2230 G_loss: N/A
#
# Epoch 1 completed in 35.48s | FID: 0.2469 | IS: 0.5011 | SSIM: 0.0328 | PSNR: 8.7906 | Acc: 0.5319
#
# Epoch [2/1000] Batch [0/25] D_loss: -0.4374 G_loss: 4.7767
# Epoch [2/1000] Batch [10/25] D_loss: 0.3301 G_loss: N/A
# Epoch [2/1000] Batch [20/25] D_loss: -0.4230 G_loss: N/A
#
# Epoch 2 completed in 38.42s | FID: 0.2470 | IS: 0.5012 | SSIM: 0.0518 | PSNR: 11.4593 | Acc: 0.6042
#
# Epoch [3/1000] Batch [0/25] D_loss: -0.1164 G_loss: 5.0328
# Epoch [3/1000] Batch [10/25] D_loss: 0.4800 G_loss: N/A
# Epoch [3/1000] Batch [20/25] D_loss: -0.6459 G_loss: N/A
#
# Epoch 3 completed in 39.87s | FID: 0.6796 | IS: 0.5033 | SSIM: 0.0523 | PSNR: 11.1743 | Acc: 0.6069
#
# Epoch [4/1000] Batch [0/25] D_loss: -0.3743 G_loss: 5.0841
# Epoch [4/1000] Batch [10/25] D_loss: -0.9457 G_loss: N/A
# Epoch [4/1000] Batch [20/25] D_loss: -1.0102 G_loss: N/A
#
# Epoch 4 completed in 36.04s | FID: 0.9034 | IS: 0.5043 | SSIM: 0.0606 | PSNR: 11.8550 | Acc: 0.5986
#
# Epoch [5/1000] Batch [0/25] D_loss: -1.1623 G_loss: 6.2306
# Epoch [5/1000] Batch [10/25] D_loss: 0.2264 G_loss: N/A
# Epoch [5/1000] Batch [20/25] D_loss: -0.7475 G_loss: N/A
#
# Epoch 5 completed in 36.13s | FID: 0.8063 | IS: 0.5019 | SSIM: 0.0539 | PSNR: 12.1885 | Acc: 0.5014
#
# Epoch [6/1000] Batch [0/25] D_loss: -0.9237 G_loss: 5.0344
# Epoch [6/1000] Batch [10/25] D_loss: 1.2621 G_loss: N/A
# Epoch [6/1000] Batch [20/25] D_loss: -0.7680 G_loss: N/A
#
# Epoch 6 completed in 35.53s | FID: 0.5432 | IS: 0.5032 | SSIM: 0.0547 | PSNR: 12.0250 | Acc: 0.6083
#
# Epoch [7/1000] Batch [0/25] D_loss: -0.7603 G_loss: 6.1225
# Epoch [7/1000] Batch [10/25] D_loss: -1.3451 G_loss: N/A
# Epoch [7/1000] Batch [20/25] D_loss: -1.6649 G_loss: N/A
#
# Epoch 7 completed in 35.56s | FID: 1.6895 | IS: 0.5011 | SSIM: 0.0600 | PSNR: 12.6568 | Acc: 0.6069
#
# Epoch [8/1000] Batch [0/25] D_loss: -1.2096 G_loss: 5.0188
# Epoch [8/1000] Batch [10/25] D_loss: -1.5628 G_loss: N/A
# Epoch [8/1000] Batch [20/25] D_loss: -1.6425 G_loss: N/A
#
# Epoch 8 completed in 35.56s | FID: 0.8187 | IS: 0.5018 | SSIM: 0.0564 | PSNR: 12.0901 | Acc: 0.6278
#
# Epoch [9/1000] Batch [0/25] D_loss: -0.9556 G_loss: 6.3726
# Epoch [9/1000] Batch [10/25] D_loss: -1.9179 G_loss: N/A
# Epoch [9/1000] Batch [20/25] D_loss: -1.7588 G_loss: N/A
#
# Epoch 9 completed in 35.56s | FID: 1.0675 | IS: 0.5061 | SSIM: 0.0592 | PSNR: 11.8814 | Acc: 0.5458
#
# Epoch [10/1000] Batch [0/25] D_loss: -1.2690 G_loss: 6.4038
# Epoch [10/1000] Batch [10/25] D_loss: -1.2008 G_loss: N/A
# Epoch [10/1000] Batch [20/25] D_loss: -1.7093 G_loss: N/A
#
# Epoch 10 completed in 35.58s | FID: 0.5701 | IS: 0.5044 | SSIM: 0.0608 | PSNR: 12.0968 | Acc: 0.6097
#
# Epoch [11/1000] Batch [0/25] D_loss: -0.5641 G_loss: 5.6814
# Epoch [11/1000] Batch [10/25] D_loss: -1.5474 G_loss: N/A
# Epoch [11/1000] Batch [20/25] D_loss: -1.2846 G_loss: N/A
#
# Epoch 11 completed in 35.57s | FID: 0.8707 | IS: 0.5018 | SSIM: 0.0571 | PSNR: 11.6791 | Acc: 0.5806
#
# Epoch [12/1000] Batch [0/25] D_loss: -1.6785 G_loss: 5.9229
# Epoch [12/1000] Batch [10/25] D_loss: -1.7115 G_loss: N/A
# Epoch [12/1000] Batch [20/25] D_loss: -1.8802 G_loss: N/A
#
# Epoch 12 completed in 35.62s | FID: 0.8230 | IS: 0.5009 | SSIM: 0.0589 | PSNR: 12.0446 | Acc: 0.5694
#
# Epoch [13/1000] Batch [0/25] D_loss: -1.8416 G_loss: 6.4841
# Epoch [13/1000] Batch [10/25] D_loss: -2.1411 G_loss: N/A
# Epoch [13/1000] Batch [20/25] D_loss: -1.8081 G_loss: N/A
#
# Epoch 13 completed in 35.63s | FID: 0.3635 | IS: 0.5025 | SSIM: 0.0563 | PSNR: 12.2469 | Acc: 0.6403
#
# Epoch [14/1000] Batch [0/25] D_loss: -0.6549 G_loss: 6.2329
# Epoch [14/1000] Batch [10/25] D_loss: -1.3075 G_loss: N/A
# Epoch [14/1000] Batch [20/25] D_loss: -1.8683 G_loss: N/A
#
# Epoch 14 completed in 35.65s | FID: 0.3969 | IS: 0.5020 | SSIM: 0.0542 | PSNR: 11.7883 | Acc: 0.5889
#
# Epoch [15/1000] Batch [0/25] D_loss: -1.9593 G_loss: 5.9808
# Epoch [15/1000] Batch [10/25] D_loss: -2.0811 G_loss: N/A
# Epoch [15/1000] Batch [20/25] D_loss: -1.5596 G_loss: N/A
#
# Epoch 15 completed in 35.70s | FID: 0.8651 | IS: 0.5057 | SSIM: 0.0589 | PSNR: 12.1816 | Acc: 0.6125
#
# Epoch [16/1000] Batch [0/25] D_loss: -1.6757 G_loss: 6.2829
# Epoch [16/1000] Batch [10/25] D_loss: -1.8141 G_loss: N/A
# Epoch [16/1000] Batch [20/25] D_loss: -1.3666 G_loss: N/A
#
# Epoch 16 completed in 35.69s | FID: 0.5624 | IS: 0.5148 | SSIM: 0.0568 | PSNR: 12.0750 | Acc: 0.6611
#
# Epoch [17/1000] Batch [0/25] D_loss: -0.7394 G_loss: 6.5020
# Epoch [17/1000] Batch [10/25] D_loss: -1.3991 G_loss: N/A
# Epoch [17/1000] Batch [20/25] D_loss: -2.0678 G_loss: N/A
#
# Epoch 17 completed in 35.63s | FID: 1.3921 | IS: 0.5054 | SSIM: 0.0542 | PSNR: 11.7928 | Acc: 0.6069
#
# Epoch [18/1000] Batch [0/25] D_loss: -1.4060 G_loss: 6.1872
# Epoch [18/1000] Batch [10/25] D_loss: -1.4087 G_loss: N/A
# Epoch [18/1000] Batch [20/25] D_loss: -1.6962 G_loss: N/A
#
# Epoch 18 completed in 35.60s | FID: 0.6295 | IS: 0.5007 | SSIM: 0.0570 | PSNR: 11.9096 | Acc: 0.5444
#
# Epoch [19/1000] Batch [0/25] D_loss: -1.8014 G_loss: 6.8670
# Epoch [19/1000] Batch [10/25] D_loss: -0.2993 G_loss: N/A
# Epoch [19/1000] Batch [20/25] D_loss: -1.4646 G_loss: N/A
#
# Epoch 19 completed in 35.59s | FID: 0.8272 | IS: 0.5074 | SSIM: 0.0575 | PSNR: 11.6675 | Acc: 0.5972
#
# Epoch [20/1000] Batch [0/25] D_loss: -0.9850 G_loss: 6.3511
# Epoch [20/1000] Batch [10/25] D_loss: -1.1241 G_loss: N/A
# Epoch [20/1000] Batch [20/25] D_loss: -1.3444 G_loss: N/A
#
# Epoch 20 completed in 35.61s | FID: 1.5794 | IS: 0.5070 | SSIM: 0.0529 | PSNR: 11.3895 | Acc: 0.5944
#
# Epoch [21/1000] Batch [0/25] D_loss: -1.6641 G_loss: 6.8216
# Epoch [21/1000] Batch [10/25] D_loss: -1.0528 G_loss: N/A
# Epoch [21/1000] Batch [20/25] D_loss: -1.5733 G_loss: N/A
#
# Epoch 21 completed in 35.64s | FID: 1.0358 | IS: 0.5072 | SSIM: 0.0557 | PSNR: 11.7731 | Acc: 0.7194
#
# Epoch [22/1000] Batch [0/25] D_loss: -0.1352 G_loss: 6.2861
# Epoch [22/1000] Batch [10/25] D_loss: -1.4530 G_loss: N/A
# Epoch [22/1000] Batch [20/25] D_loss: -1.5553 G_loss: N/A
#
# Epoch 22 completed in 35.59s | FID: 1.6532 | IS: 0.5015 | SSIM: 0.0540 | PSNR: 11.5830 | Acc: 0.6569
#
# Epoch [23/1000] Batch [0/25] D_loss: -1.4682 G_loss: 6.2331
# Epoch [23/1000] Batch [10/25] D_loss: -0.9533 G_loss: N/A
# Epoch [23/1000] Batch [20/25] D_loss: -0.5922 G_loss: N/A
#
# Epoch 23 completed in 35.57s | FID: 0.3422 | IS: 0.5149 | SSIM: 0.0560 | PSNR: 11.7618 | Acc: 0.6431
#
# Epoch [24/1000] Batch [0/25] D_loss: -0.2537 G_loss: 5.8496
# Epoch [24/1000] Batch [10/25] D_loss: -1.1176 G_loss: N/A
# Epoch [24/1000] Batch [20/25] D_loss: -1.0533 G_loss: N/A
#
# Epoch 24 completed in 35.60s | FID: 1.1530 | IS: 0.5220 | SSIM: 0.0491 | PSNR: 11.5695 | Acc: 0.6347
#
# Epoch [25/1000] Batch [0/25] D_loss: -1.2477 G_loss: 5.6582
# Epoch [25/1000] Batch [10/25] D_loss: -0.7271 G_loss: N/A
# Epoch [25/1000] Batch [20/25] D_loss: -0.7662 G_loss: N/A
#
# Epoch 25 completed in 35.61s | FID: 1.3574 | IS: 0.5148 | SSIM: 0.0479 | PSNR: 11.1183 | Acc: 0.6292
#
# Epoch [26/1000] Batch [0/25] D_loss: -1.1517 G_loss: 4.3022
# Epoch [26/1000] Batch [10/25] D_loss: -0.7129 G_loss: N/A
# Epoch [26/1000] Batch [20/25] D_loss: -1.2515 G_loss: N/A
#
# Epoch 26 completed in 35.62s | FID: 0.5420 | IS: 0.5112 | SSIM: 0.0556 | PSNR: 11.6243 | Acc: 0.6917
#
# Epoch [27/1000] Batch [0/25] D_loss: -0.8709 G_loss: 5.4864
# Epoch [27/1000] Batch [10/25] D_loss: -1.0701 G_loss: N/A
# Epoch [27/1000] Batch [20/25] D_loss: -0.7769 G_loss: N/A
#
# Epoch 27 completed in 35.65s | FID: 0.3375 | IS: 0.5457 | SSIM: 0.0497 | PSNR: 11.5797 | Acc: 0.6333
#
# Epoch [28/1000] Batch [0/25] D_loss: -0.6251 G_loss: 5.2994
# Epoch [28/1000] Batch [10/25] D_loss: 0.0724 G_loss: N/A
# Epoch [28/1000] Batch [20/25] D_loss: -1.2570 G_loss: N/A
#
# Epoch 28 completed in 35.62s | FID: 0.5056 | IS: 0.5341 | SSIM: 0.0503 | PSNR: 11.3374 | Acc: 0.7000
#
# Epoch [29/1000] Batch [0/25] D_loss: -1.1475 G_loss: 6.1833
# Epoch [29/1000] Batch [10/25] D_loss: -0.6355 G_loss: N/A
# Epoch [29/1000] Batch [20/25] D_loss: -0.6337 G_loss: N/A
#
# Epoch 29 completed in 35.63s | FID: 0.9477 | IS: 0.5160 | SSIM: 0.0467 | PSNR: 10.9182 | Acc: 0.6889
#
# Epoch [30/1000] Batch [0/25] D_loss: -0.7641 G_loss: 4.9777
# Epoch [30/1000] Batch [10/25] D_loss: -0.7739 G_loss: N/A
# Epoch [30/1000] Batch [20/25] D_loss: -0.4785 G_loss: N/A
#
# Epoch 30 completed in 35.63s | FID: 0.5211 | IS: 0.5213 | SSIM: 0.0530 | PSNR: 11.3952 | Acc: 0.5764
#
# Epoch [31/1000] Batch [0/25] D_loss: -0.2311 G_loss: 4.5544
# Epoch [31/1000] Batch [10/25] D_loss: -0.8917 G_loss: N/A
# Epoch [31/1000] Batch [20/25] D_loss: -1.1399 G_loss: N/A
#
# Epoch 31 completed in 35.63s | FID: 1.1023 | IS: 0.5229 | SSIM: 0.0494 | PSNR: 11.5456 | Acc: 0.6542
#
# Epoch [32/1000] Batch [0/25] D_loss: -0.8124 G_loss: 5.0017
# Epoch [32/1000] Batch [10/25] D_loss: -1.0491 G_loss: N/A
# Epoch [32/1000] Batch [20/25] D_loss: -1.1327 G_loss: N/A
#
# Epoch 32 completed in 35.60s | FID: 1.6028 | IS: 0.5247 | SSIM: 0.0573 | PSNR: 11.6731 | Acc: 0.7194
#
# Epoch [33/1000] Batch [0/25] D_loss: -0.5313 G_loss: 5.1080
# Epoch [33/1000] Batch [10/25] D_loss: 0.3119 G_loss: N/A
# Epoch [33/1000] Batch [20/25] D_loss: -0.8666 G_loss: N/A
#
# Epoch 33 completed in 35.59s | FID: 1.0159 | IS: 0.5278 | SSIM: 0.0490 | PSNR: 11.2704 | Acc: 0.7597
#
# Epoch [34/1000] Batch [0/25] D_loss: -0.8951 G_loss: 5.0957
# Epoch [34/1000] Batch [10/25] D_loss: -0.7041 G_loss: N/A
# Epoch [34/1000] Batch [20/25] D_loss: -0.6987 G_loss: N/A
#
# Epoch 34 completed in 35.60s | FID: 0.5176 | IS: 0.5364 | SSIM: 0.0478 | PSNR: 11.1648 | Acc: 0.6736
#
# Epoch [35/1000] Batch [0/25] D_loss: -0.6695 G_loss: 5.7420
# Epoch [35/1000] Batch [10/25] D_loss: -1.0715 G_loss: N/A
# Epoch [35/1000] Batch [20/25] D_loss: -0.7737 G_loss: N/A
#
# Epoch 35 completed in 35.63s | FID: 0.8839 | IS: 0.5260 | SSIM: 0.0528 | PSNR: 11.5823 | Acc: 0.6861
#
# Epoch [36/1000] Batch [0/25] D_loss: -0.6307 G_loss: 5.1975
# Epoch [36/1000] Batch [10/25] D_loss: -0.6032 G_loss: N/A
# Epoch [36/1000] Batch [20/25] D_loss: -0.8049 G_loss: N/A
#
# Epoch 36 completed in 35.67s | FID: 1.0450 | IS: 0.5491 | SSIM: 0.0532 | PSNR: 11.3457 | Acc: 0.7000
#
# Epoch [37/1000] Batch [0/25] D_loss: -0.8652 G_loss: 5.9683
# Epoch [37/1000] Batch [10/25] D_loss: -0.8564 G_loss: N/A
# Epoch [37/1000] Batch [20/25] D_loss: -0.9632 G_loss: N/A
#
# Epoch 37 completed in 35.68s | FID: 0.4843 | IS: 0.5355 | SSIM: 0.0488 | PSNR: 11.3120 | Acc: 0.6319
#
# Epoch [38/1000] Batch [0/25] D_loss: -0.9672 G_loss: 4.6206
# Epoch [38/1000] Batch [10/25] D_loss: -0.7679 G_loss: N/A
# Epoch [38/1000] Batch [20/25] D_loss: -0.4677 G_loss: N/A
#
# Epoch 38 completed in 35.65s | FID: 0.8282 | IS: 0.5282 | SSIM: 0.0530 | PSNR: 11.3948 | Acc: 0.7236
#
# Epoch [39/1000] Batch [0/25] D_loss: -1.1458 G_loss: 4.9939
# Epoch [39/1000] Batch [10/25] D_loss: -1.3901 G_loss: N/A
# Epoch [39/1000] Batch [20/25] D_loss: -0.6165 G_loss: N/A
#
# Epoch 39 completed in 35.66s | FID: 0.7235 | IS: 0.5127 | SSIM: 0.0506 | PSNR: 11.2084 | Acc: 0.7097
#
# Epoch [40/1000] Batch [0/25] D_loss: -1.1715 G_loss: 3.9487
# Epoch [40/1000] Batch [10/25] D_loss: -0.8975 G_loss: N/A
# Epoch [40/1000] Batch [20/25] D_loss: -0.9470 G_loss: N/A
#
# Epoch 40 completed in 35.67s | FID: 0.5760 | IS: 0.5349 | SSIM: 0.0540 | PSNR: 11.6197 | Acc: 0.7333
#
# Epoch [41/1000] Batch [0/25] D_loss: -0.4833 G_loss: 4.8344
# Epoch [41/1000] Batch [10/25] D_loss: -0.9215 G_loss: N/A
# Epoch [41/1000] Batch [20/25] D_loss: -0.9193 G_loss: N/A
#
# Epoch 41 completed in 35.63s | FID: 0.5702 | IS: 0.5795 | SSIM: 0.0517 | PSNR: 11.3559 | Acc: 0.6264
#
# Epoch [42/1000] Batch [0/25] D_loss: -1.3133 G_loss: 5.4889
# Epoch [42/1000] Batch [10/25] D_loss: -0.6803 G_loss: N/A
# Epoch [42/1000] Batch [20/25] D_loss: -1.1313 G_loss: N/A
#
# Epoch 42 completed in 35.61s | FID: 1.0538 | IS: 0.5271 | SSIM: 0.0502 | PSNR: 11.3514 | Acc: 0.5958
#
# Epoch [43/1000] Batch [0/25] D_loss: -1.0903 G_loss: 4.8691
# Epoch [43/1000] Batch [10/25] D_loss: -0.7525 G_loss: N/A
# Epoch [43/1000] Batch [20/25] D_loss: -1.0920 G_loss: N/A
#
# Epoch 43 completed in 35.61s | FID: 0.8827 | IS: 0.5316 | SSIM: 0.0518 | PSNR: 11.3297 | Acc: 0.6542
#
# Epoch [44/1000] Batch [0/25] D_loss: -0.5935 G_loss: 4.5955
# Epoch [44/1000] Batch [10/25] D_loss: -1.5595 G_loss: N/A
# Epoch [44/1000] Batch [20/25] D_loss: -1.0045 G_loss: N/A
#
# Epoch 44 completed in 35.62s | FID: 1.8939 | IS: 0.5176 | SSIM: 0.0546 | PSNR: 11.5159 | Acc: 0.7042
#
# Epoch [45/1000] Batch [0/25] D_loss: -0.6439 G_loss: 4.5987
# Epoch [45/1000] Batch [10/25] D_loss: -0.8172 G_loss: N/A
# Epoch [45/1000] Batch [20/25] D_loss: -0.8427 G_loss: N/A
#
# Epoch 45 completed in 35.66s | FID: 0.6103 | IS: 0.5426 | SSIM: 0.0544 | PSNR: 11.5715 | Acc: 0.6944
#
# Epoch [46/1000] Batch [0/25] D_loss: -1.0256 G_loss: 5.0023
# Epoch [46/1000] Batch [10/25] D_loss: -1.0203 G_loss: N/A
# Epoch [46/1000] Batch [20/25] D_loss: -1.1893 G_loss: N/A
#
# Epoch 46 completed in 35.61s | FID: 1.4701 | IS: 0.5381 | SSIM: 0.0506 | PSNR: 11.2682 | Acc: 0.6000
#
# Epoch [47/1000] Batch [0/25] D_loss: -1.0997 G_loss: 4.2951
# Epoch [47/1000] Batch [10/25] D_loss: -1.1416 G_loss: N/A
# Epoch [47/1000] Batch [20/25] D_loss: -0.9542 G_loss: N/A
#
# Epoch 47 completed in 35.62s | FID: 0.8344 | IS: 0.5674 | SSIM: 0.0528 | PSNR: 11.6119 | Acc: 0.6986
#
# Epoch [48/1000] Batch [0/25] D_loss: -0.8370 G_loss: 4.7184
# Epoch [48/1000] Batch [10/25] D_loss: -0.8543 G_loss: N/A
# Epoch [48/1000] Batch [20/25] D_loss: -1.0822 G_loss: N/A
#
# Epoch 48 completed in 35.64s | FID: 0.9486 | IS: 0.5403 | SSIM: 0.0540 | PSNR: 11.4614 | Acc: 0.7042
#
# Epoch [49/1000] Batch [0/25] D_loss: -0.9020 G_loss: 4.0896
# Epoch [49/1000] Batch [10/25] D_loss: -0.7740 G_loss: N/A
# Epoch [49/1000] Batch [20/25] D_loss: -0.8664 G_loss: N/A
#
# Epoch 49 completed in 35.62s | FID: 1.0751 | IS: 0.5550 | SSIM: 0.0523 | PSNR: 11.4096 | Acc: 0.6639
#
# Epoch [50/1000] Batch [0/25] D_loss: -1.0591 G_loss: 5.3214
# Epoch [50/1000] Batch [10/25] D_loss: -0.5903 G_loss: N/A
# Epoch [50/1000] Batch [20/25] D_loss: -1.1526 G_loss: N/A
#
# Epoch 50 completed in 35.59s | FID: 1.9095 | IS: 0.5250 | SSIM: 0.0486 | PSNR: 11.2194 | Acc: 0.7069
#
# Epoch [51/1000] Batch [0/25] D_loss: -1.0550 G_loss: 4.9904
# Epoch [51/1000] Batch [10/25] D_loss: -0.4930 G_loss: N/A
# Epoch [51/1000] Batch [20/25] D_loss: -0.9732 G_loss: N/A
#
# Epoch 51 completed in 35.68s | FID: 0.8898 | IS: 0.5307 | SSIM: 0.0520 | PSNR: 11.3078 | Acc: 0.6542
#
# Epoch [52/1000] Batch [0/25] D_loss: -1.2693 G_loss: 4.5240
# Epoch [52/1000] Batch [10/25] D_loss: -0.9404 G_loss: N/A
# Epoch [52/1000] Batch [20/25] D_loss: -0.7320 G_loss: N/A
#
# Epoch 52 completed in 35.66s | FID: 1.1146 | IS: 0.5598 | SSIM: 0.0494 | PSNR: 11.3488 | Acc: 0.6472
#
# Epoch [53/1000] Batch [0/25] D_loss: -1.3665 G_loss: 5.4846
# Epoch [53/1000] Batch [10/25] D_loss: -0.7380 G_loss: N/A
# Epoch [53/1000] Batch [20/25] D_loss: -1.0263 G_loss: N/A
#
# Epoch 53 completed in 35.64s | FID: 1.5974 | IS: 0.5375 | SSIM: 0.0462 | PSNR: 11.3511 | Acc: 0.6819
#
# Epoch [54/1000] Batch [0/25] D_loss: -1.2346 G_loss: 4.0786
# Epoch [54/1000] Batch [10/25] D_loss: -0.9192 G_loss: N/A
# Epoch [54/1000] Batch [20/25] D_loss: -0.6494 G_loss: N/A
#
# Epoch 54 completed in 35.64s | FID: 1.6143 | IS: 0.5373 | SSIM: 0.0515 | PSNR: 11.6347 | Acc: 0.7028
#
# Epoch [55/1000] Batch [0/25] D_loss: -1.0790 G_loss: 4.2104
# Epoch [55/1000] Batch [10/25] D_loss: -0.9272 G_loss: N/A
# Epoch [55/1000] Batch [20/25] D_loss: -0.7947 G_loss: N/A
#
# Epoch 55 completed in 35.69s | FID: 2.8032 | IS: 0.5059 | SSIM: 0.0499 | PSNR: 11.1590 | Acc: 0.7444
#
# Epoch [56/1000] Batch [0/25] D_loss: -0.9727 G_loss: 4.4916
# Epoch [56/1000] Batch [10/25] D_loss: -1.1882 G_loss: N/A
# Epoch [56/1000] Batch [20/25] D_loss: -0.9452 G_loss: N/A
#
# Epoch 56 completed in 35.60s | FID: 1.2175 | IS: 0.5546 | SSIM: 0.0475 | PSNR: 11.2985 | Acc: 0.6486
#
# Epoch [57/1000] Batch [0/25] D_loss: -0.3349 G_loss: 4.5713
# Epoch [57/1000] Batch [10/25] D_loss: -1.7866 G_loss: N/A
# Epoch [57/1000] Batch [20/25] D_loss: -0.8129 G_loss: N/A
#
# Epoch 57 completed in 35.64s | FID: 3.2025 | IS: 0.5595 | SSIM: 0.0532 | PSNR: 11.5645 | Acc: 0.6972
#
# Epoch [58/1000] Batch [0/25] D_loss: -0.5345 G_loss: 4.2607
# Epoch [58/1000] Batch [10/25] D_loss: -1.0053 G_loss: N/A
# Epoch [58/1000] Batch [20/25] D_loss: -0.5241 G_loss: N/A
#
# Epoch 58 completed in 35.60s | FID: 2.7949 | IS: 0.5339 | SSIM: 0.0482 | PSNR: 11.2949 | Acc: 0.6889
#
# Epoch [59/1000] Batch [0/25] D_loss: -1.4636 G_loss: 4.5041
# Epoch [59/1000] Batch [10/25] D_loss: -1.2811 G_loss: N/A
# Epoch [59/1000] Batch [20/25] D_loss: -0.9171 G_loss: N/A
#
# Epoch 59 completed in 35.60s | FID: 1.3828 | IS: 0.5432 | SSIM: 0.0545 | PSNR: 11.4379 | Acc: 0.7000
#
# Epoch [60/1000] Batch [0/25] D_loss: -0.6175 G_loss: 5.0375
# Epoch [60/1000] Batch [10/25] D_loss: -1.1084 G_loss: N/A
# Epoch [60/1000] Batch [20/25] D_loss: -0.9542 G_loss: N/A
#
# Epoch 60 completed in 35.62s | FID: 2.4602 | IS: 0.5543 | SSIM: 0.0530 | PSNR: 11.4801 | Acc: 0.7250
#
# Epoch [61/1000] Batch [0/25] D_loss: -1.2210 G_loss: 5.0042
# Epoch [61/1000] Batch [10/25] D_loss: -0.1364 G_loss: N/A
# Epoch [61/1000] Batch [20/25] D_loss: -1.1128 G_loss: N/A
#
# Epoch 61 completed in 35.63s | FID: 2.7164 | IS: 0.5515 | SSIM: 0.0483 | PSNR: 11.3772 | Acc: 0.7139
#
# Epoch [62/1000] Batch [0/25] D_loss: -0.5996 G_loss: 4.3678
# Epoch [62/1000] Batch [10/25] D_loss: -1.1161 G_loss: N/A
# Epoch [62/1000] Batch [20/25] D_loss: -0.8933 G_loss: N/A
#
# Epoch 62 completed in 35.62s | FID: 1.5433 | IS: 0.5563 | SSIM: 0.0537 | PSNR: 11.3729 | Acc: 0.7042
#
# Epoch [63/1000] Batch [0/25] D_loss: -0.9169 G_loss: 5.0681
# Epoch [63/1000] Batch [10/25] D_loss: -1.0906 G_loss: N/A
# Epoch [63/1000] Batch [20/25] D_loss: -0.6099 G_loss: N/A
#
# Epoch 63 completed in 35.63s | FID: 1.2243 | IS: 0.5670 | SSIM: 0.0515 | PSNR: 11.4535 | Acc: 0.7861
#
# Epoch [64/1000] Batch [0/25] D_loss: -0.9125 G_loss: 5.3044
# Epoch [64/1000] Batch [10/25] D_loss: -0.7888 G_loss: N/A
# Epoch [64/1000] Batch [20/25] D_loss: -0.8185 G_loss: N/A
#
# Epoch 64 completed in 35.62s | FID: 0.7216 | IS: 0.5453 | SSIM: 0.0483 | PSNR: 11.2913 | Acc: 0.7097
#
# Epoch [65/1000] Batch [0/25] D_loss: -0.6314 G_loss: 4.1450
# Epoch [65/1000] Batch [10/25] D_loss: -0.9681 G_loss: N/A
# Epoch [65/1000] Batch [20/25] D_loss: -0.5985 G_loss: N/A
#
# Epoch 65 completed in 35.65s | FID: 1.2012 | IS: 0.5796 | SSIM: 0.0536 | PSNR: 11.4173 | Acc: 0.7431
#
# Epoch [66/1000] Batch [0/25] D_loss: -1.1375 G_loss: 5.3880
# Epoch [66/1000] Batch [10/25] D_loss: -1.0027 G_loss: N/A
# Epoch [66/1000] Batch [20/25] D_loss: -1.1493 G_loss: N/A
#
# Epoch 66 completed in 35.66s | FID: 1.5835 | IS: 0.5444 | SSIM: 0.0569 | PSNR: 11.4692 | Acc: 0.6986
#
# Epoch [67/1000] Batch [0/25] D_loss: -0.8362 G_loss: 5.1787
# Epoch [67/1000] Batch [10/25] D_loss: -0.8970 G_loss: N/A
# Epoch [67/1000] Batch [20/25] D_loss: -0.5674 G_loss: N/A
#
# Epoch 67 completed in 35.65s | FID: 0.7562 | IS: 0.5371 | SSIM: 0.0543 | PSNR: 11.3751 | Acc: 0.7278
#
# Epoch [68/1000] Batch [0/25] D_loss: -1.3092 G_loss: 5.2059
# Epoch [68/1000] Batch [10/25] D_loss: -1.0978 G_loss: N/A
# Epoch [68/1000] Batch [20/25] D_loss: -0.7293 G_loss: N/A
#
# Epoch 68 completed in 35.65s | FID: 1.1755 | IS: 0.5347 | SSIM: 0.0503 | PSNR: 11.2231 | Acc: 0.6528
#
# Epoch [69/1000] Batch [0/25] D_loss: -0.8596 G_loss: 5.0322
# Epoch [69/1000] Batch [10/25] D_loss: -1.2972 G_loss: N/A
# Epoch [69/1000] Batch [20/25] D_loss: -0.4606 G_loss: N/A
#
# Epoch 69 completed in 35.62s | FID: 3.4368 | IS: 0.5802 | SSIM: 0.0533 | PSNR: 11.4362 | Acc: 0.7806
#
# Epoch [70/1000] Batch [0/25] D_loss: -0.6340 G_loss: 5.0497
# Epoch [70/1000] Batch [10/25] D_loss: -0.1340 G_loss: N/A
# Epoch [70/1000] Batch [20/25] D_loss: -1.3767 G_loss: N/A
#
# Epoch 70 completed in 35.62s | FID: 0.9419 | IS: 0.5689 | SSIM: 0.0505 | PSNR: 11.1880 | Acc: 0.6611
#
# Epoch [71/1000] Batch [0/25] D_loss: -1.4065 G_loss: 4.9476
# Epoch [71/1000] Batch [10/25] D_loss: -0.9889 G_loss: N/A
# Epoch [71/1000] Batch [20/25] D_loss: -1.0930 G_loss: N/A
#
# Epoch 71 completed in 35.61s | FID: 2.1352 | IS: 0.5762 | SSIM: 0.0556 | PSNR: 11.4639 | Acc: 0.7347
#
# Epoch [72/1000] Batch [0/25] D_loss: -0.8021 G_loss: 4.8630
# Epoch [72/1000] Batch [10/25] D_loss: -0.9054 G_loss: N/A
# Epoch [72/1000] Batch [20/25] D_loss: -0.8674 G_loss: N/A
#
# Epoch 72 completed in 35.60s | FID: 2.0483 | IS: 0.5610 | SSIM: 0.0518 | PSNR: 11.3315 | Acc: 0.6958
#
# Epoch [73/1000] Batch [0/25] D_loss: -0.7449 G_loss: 5.4211
# Epoch [73/1000] Batch [10/25] D_loss: -1.4189 G_loss: N/A
# Epoch [73/1000] Batch [20/25] D_loss: -0.7039 G_loss: N/A
#
# Epoch 73 completed in 35.60s | FID: 0.7261 | IS: 0.5468 | SSIM: 0.0529 | PSNR: 11.4259 | Acc: 0.6889
#
# Epoch [74/1000] Batch [0/25] D_loss: -0.6482 G_loss: 4.2886
# Epoch [74/1000] Batch [10/25] D_loss: -0.9628 G_loss: N/A
# Epoch [74/1000] Batch [20/25] D_loss: -1.3225 G_loss: N/A
#
# Epoch 74 completed in 35.61s | FID: 1.5571 | IS: 0.5513 | SSIM: 0.0521 | PSNR: 11.4293 | Acc: 0.7125
#
# Epoch [75/1000] Batch [0/25] D_loss: -0.4553 G_loss: 4.9053
# Epoch [75/1000] Batch [10/25] D_loss: -0.9821 G_loss: N/A
# Epoch [75/1000] Batch [20/25] D_loss: -1.1694 G_loss: N/A
#
# Epoch 75 completed in 35.69s | FID: 0.8746 | IS: 0.5657 | SSIM: 0.0539 | PSNR: 11.7051 | Acc: 0.7208
#
# Epoch [76/1000] Batch [0/25] D_loss: -0.9494 G_loss: 5.1588
# Epoch [76/1000] Batch [10/25] D_loss: -1.2514 G_loss: N/A
# Epoch [76/1000] Batch [20/25] D_loss: -1.2562 G_loss: N/A
#
# Epoch 76 completed in 35.66s | FID: 0.5856 | IS: 0.5686 | SSIM: 0.0564 | PSNR: 11.6224 | Acc: 0.7611
#
# Epoch [77/1000] Batch [0/25] D_loss: -0.4086 G_loss: 4.1065
# Epoch [77/1000] Batch [10/25] D_loss: -0.9649 G_loss: N/A
# Epoch [77/1000] Batch [20/25] D_loss: -1.4824 G_loss: N/A
#
# Epoch 77 completed in 35.69s | FID: 1.2094 | IS: 0.5636 | SSIM: 0.0485 | PSNR: 11.1800 | Acc: 0.6542
#
# Epoch [78/1000] Batch [0/25] D_loss: -0.8969 G_loss: 4.6715
# Epoch [78/1000] Batch [10/25] D_loss: -1.2570 G_loss: N/A
# Epoch [78/1000] Batch [20/25] D_loss: -0.7803 G_loss: N/A
#
# Epoch 78 completed in 35.67s | FID: 0.5741 | IS: 0.5431 | SSIM: 0.0511 | PSNR: 11.2819 | Acc: 0.7722
#
# Epoch [79/1000] Batch [0/25] D_loss: -0.6310 G_loss: 4.3170
# Epoch [79/1000] Batch [10/25] D_loss: -1.0591 G_loss: N/A
# Epoch [79/1000] Batch [20/25] D_loss: -1.0452 G_loss: N/A
#
# Epoch 79 completed in 35.63s | FID: 2.3972 | IS: 0.5635 | SSIM: 0.0490 | PSNR: 11.4358 | Acc: 0.6903
#
# Epoch [80/1000] Batch [0/25] D_loss: -0.9829 G_loss: 4.6580
# Epoch [80/1000] Batch [10/25] D_loss: -0.8930 G_loss: N/A
# Epoch [80/1000] Batch [20/25] D_loss: -0.2395 G_loss: N/A
#
# Epoch 80 completed in 35.64s | FID: 0.8330 | IS: 0.5783 | SSIM: 0.0515 | PSNR: 11.3621 | Acc: 0.7083
#
# Epoch [81/1000] Batch [0/25] D_loss: -0.9512 G_loss: 4.7434
# Epoch [81/1000] Batch [10/25] D_loss: -1.2792 G_loss: N/A
# Epoch [81/1000] Batch [20/25] D_loss: -1.0916 G_loss: N/A
#
# Epoch 81 completed in 35.60s | FID: 1.2209 | IS: 0.5587 | SSIM: 0.0564 | PSNR: 11.5854 | Acc: 0.7458
#
# Epoch [82/1000] Batch [0/25] D_loss: -0.8627 G_loss: 4.6609
# Epoch [82/1000] Batch [10/25] D_loss: -1.1619 G_loss: N/A
# Epoch [82/1000] Batch [20/25] D_loss: -1.0065 G_loss: N/A
#
# Epoch 82 completed in 35.60s | FID: 2.0298 | IS: 0.5579 | SSIM: 0.0524 | PSNR: 11.2782 | Acc: 0.7597
#
# Epoch [83/1000] Batch [0/25] D_loss: -0.9038 G_loss: 4.3734
# Epoch [83/1000] Batch [10/25] D_loss: -0.8034 G_loss: N/A
# Epoch [83/1000] Batch [20/25] D_loss: -1.0476 G_loss: N/A
#
# Epoch 83 completed in 35.60s | FID: 1.3464 | IS: 0.5349 | SSIM: 0.0485 | PSNR: 11.2638 | Acc: 0.6931
#
# Epoch [84/1000] Batch [0/25] D_loss: -1.0252 G_loss: 4.6224
# Epoch [84/1000] Batch [10/25] D_loss: -1.0329 G_loss: N/A
# Epoch [84/1000] Batch [20/25] D_loss: -1.2771 G_loss: N/A
#
# Epoch 84 completed in 35.61s | FID: 1.9964 | IS: 0.5697 | SSIM: 0.0520 | PSNR: 11.4786 | Acc: 0.7028
#
# Epoch [85/1000] Batch [0/25] D_loss: -1.0074 G_loss: 4.9898
# Epoch [85/1000] Batch [10/25] D_loss: -1.2611 G_loss: N/A
# Epoch [85/1000] Batch [20/25] D_loss: -1.0237 G_loss: N/A
#
# Epoch 85 completed in 35.67s | FID: 1.2296 | IS: 0.5414 | SSIM: 0.0522 | PSNR: 11.4894 | Acc: 0.7069
#
# Epoch [86/1000] Batch [0/25] D_loss: -0.9178 G_loss: 4.3960
# Epoch [86/1000] Batch [10/25] D_loss: -1.2065 G_loss: N/A
# Epoch [86/1000] Batch [20/25] D_loss: -0.9422 G_loss: N/A
#
# Epoch 86 completed in 35.67s | FID: 1.1550 | IS: 0.5445 | SSIM: 0.0548 | PSNR: 11.5318 | Acc: 0.7222
#
# Epoch [87/1000] Batch [0/25] D_loss: -0.7070 G_loss: 4.3102
# Epoch [87/1000] Batch [10/25] D_loss: -0.6370 G_loss: N/A
# Epoch [87/1000] Batch [20/25] D_loss: -0.9953 G_loss: N/A
#
# Epoch 87 completed in 35.67s | FID: 0.8479 | IS: 0.5547 | SSIM: 0.0517 | PSNR: 11.2869 | Acc: 0.7139
#
# Epoch [88/1000] Batch [0/25] D_loss: -0.9534 G_loss: 4.9103
# Epoch [88/1000] Batch [10/25] D_loss: -1.2445 G_loss: N/A
# Epoch [88/1000] Batch [20/25] D_loss: -0.6045 G_loss: N/A
#
# Epoch 88 completed in 35.66s | FID: 1.2216 | IS: 0.5448 | SSIM: 0.0515 | PSNR: 11.2109 | Acc: 0.6361
#
# Epoch [89/1000] Batch [0/25] D_loss: -0.9545 G_loss: 4.8853
# Epoch [89/1000] Batch [10/25] D_loss: -1.5349 G_loss: N/A
# Epoch [89/1000] Batch [20/25] D_loss: -1.0160 G_loss: N/A
#
# Epoch 89 completed in 35.63s | FID: 1.8664 | IS: 0.5694 | SSIM: 0.0524 | PSNR: 11.3217 | Acc: 0.6764
#
# Epoch [90/1000] Batch [0/25] D_loss: -0.8321 G_loss: 4.5468
# Epoch [90/1000] Batch [10/25] D_loss: -1.0727 G_loss: N/A
# Epoch [90/1000] Batch [20/25] D_loss: -0.6284 G_loss: N/A
#
# Epoch 90 completed in 35.59s | FID: 1.0828 | IS: 0.5469 | SSIM: 0.0513 | PSNR: 11.1742 | Acc: 0.6847
#
# Epoch [91/1000] Batch [0/25] D_loss: -0.8284 G_loss: 4.9282
# Epoch [91/1000] Batch [10/25] D_loss: -1.0035 G_loss: N/A
# Epoch [91/1000] Batch [20/25] D_loss: -1.1295 G_loss: N/A
#
# Epoch 91 completed in 35.61s | FID: 2.1689 | IS: 0.5491 | SSIM: 0.0561 | PSNR: 11.4311 | Acc: 0.7264
#
# Epoch [92/1000] Batch [0/25] D_loss: -0.9691 G_loss: 4.7575
# Epoch [92/1000] Batch [10/25] D_loss: -0.7530 G_loss: N/A
# Epoch [92/1000] Batch [20/25] D_loss: -0.8314 G_loss: N/A
#
# Epoch 92 completed in 35.63s | FID: 1.4476 | IS: 0.5829 | SSIM: 0.0509 | PSNR: 11.2239 | Acc: 0.7056
#
# Epoch [93/1000] Batch [0/25] D_loss: -0.8260 G_loss: 4.5010
# Epoch [93/1000] Batch [10/25] D_loss: -0.8728 G_loss: N/A
# Epoch [93/1000] Batch [20/25] D_loss: -0.8929 G_loss: N/A
#
# Epoch 93 completed in 35.64s | FID: 1.0384 | IS: 0.5744 | SSIM: 0.0509 | PSNR: 11.2847 | Acc: 0.7000
#
# Epoch [94/1000] Batch [0/25] D_loss: -1.2484 G_loss: 4.7811
# Epoch [94/1000] Batch [10/25] D_loss: -1.0665 G_loss: N/A
# Epoch [94/1000] Batch [20/25] D_loss: -1.1769 G_loss: N/A
#
# Epoch 94 completed in 35.60s | FID: 0.9233 | IS: 0.5509 | SSIM: 0.0565 | PSNR: 11.6249 | Acc: 0.6778
#
# Epoch [95/1000] Batch [0/25] D_loss: -0.9344 G_loss: 5.1749
# Epoch [95/1000] Batch [10/25] D_loss: -0.8884 G_loss: N/A
# Epoch [95/1000] Batch [20/25] D_loss: -0.7949 G_loss: N/A
#
# Epoch 95 completed in 35.62s | FID: 1.1699 | IS: 0.5560 | SSIM: 0.0557 | PSNR: 11.3672 | Acc: 0.7208
#
# Epoch [96/1000] Batch [0/25] D_loss: -1.1572 G_loss: 4.8861
# Epoch [96/1000] Batch [10/25] D_loss: -0.7965 G_loss: N/A
# Epoch [96/1000] Batch [20/25] D_loss: -1.1256 G_loss: N/A
#
# Epoch 96 completed in 35.62s | FID: 1.1029 | IS: 0.5817 | SSIM: 0.0517 | PSNR: 11.0571 | Acc: 0.7194
#
# Epoch [97/1000] Batch [0/25] D_loss: -1.1950 G_loss: 5.0633
# Epoch [97/1000] Batch [10/25] D_loss: -0.7347 G_loss: N/A
# Epoch [97/1000] Batch [20/25] D_loss: -0.8201 G_loss: N/A
#
# Epoch 97 completed in 35.63s | FID: 0.8721 | IS: 0.5585 | SSIM: 0.0523 | PSNR: 11.2136 | Acc: 0.7153
#
# Epoch [98/1000] Batch [0/25] D_loss: -0.9014 G_loss: 4.9450
# Epoch [98/1000] Batch [10/25] D_loss: -1.5945 G_loss: N/A
# Epoch [98/1000] Batch [20/25] D_loss: -1.3759 G_loss: N/A
#
# Epoch 98 completed in 35.62s | FID: 1.3456 | IS: 0.5720 | SSIM: 0.0524 | PSNR: 11.4217 | Acc: 0.7181
#
# Epoch [99/1000] Batch [0/25] D_loss: -1.0168 G_loss: 4.9351
# Epoch [99/1000] Batch [10/25] D_loss: -0.6958 G_loss: N/A
# Epoch [99/1000] Batch [20/25] D_loss: -1.0433 G_loss: N/A
#
# Epoch 99 completed in 35.65s | FID: 0.9959 | IS: 0.5513 | SSIM: 0.0478 | PSNR: 11.1269 | Acc: 0.6889
#
# Epoch [100/1000] Batch [0/25] D_loss: -1.4251 G_loss: 4.9136
# Epoch [100/1000] Batch [10/25] D_loss: -0.8106 G_loss: N/A
# Epoch [100/1000] Batch [20/25] D_loss: -1.0845 G_loss: N/A
#
# Epoch 100 completed in 35.64s | FID: 0.7525 | IS: 0.5546 | SSIM: 0.0524 | PSNR: 11.4130 | Acc: 0.7347
#
# Epoch [101/1000] Batch [0/25] D_loss: -1.0577 G_loss: 4.6054
# Epoch [101/1000] Batch [10/25] D_loss: -0.8481 G_loss: N/A
# Epoch [101/1000] Batch [20/25] D_loss: -0.8640 G_loss: N/A
#
# Epoch 101 completed in 35.61s | FID: 1.8528 | IS: 0.5747 | SSIM: 0.0520 | PSNR: 11.4423 | Acc: 0.7306
#
# Epoch [102/1000] Batch [0/25] D_loss: -1.3103 G_loss: 4.7312
# Epoch [102/1000] Batch [10/25] D_loss: -0.7921 G_loss: N/A
# Epoch [102/1000] Batch [20/25] D_loss: -0.7726 G_loss: N/A
#
# Epoch 102 completed in 35.63s | FID: 0.6587 | IS: 0.5630 | SSIM: 0.0498 | PSNR: 11.1941 | Acc: 0.7167
#
# Epoch [103/1000] Batch [0/25] D_loss: -0.8712 G_loss: 4.8123
# Epoch [103/1000] Batch [10/25] D_loss: -1.1180 G_loss: N/A
# Epoch [103/1000] Batch [20/25] D_loss: -1.0026 G_loss: N/A
#
# Epoch 103 completed in 35.65s | FID: 0.6147 | IS: 0.5504 | SSIM: 0.0514 | PSNR: 11.4216 | Acc: 0.6250
#
# Epoch [104/1000] Batch [0/25] D_loss: -1.2402 G_loss: 4.7408
# Epoch [104/1000] Batch [10/25] D_loss: -1.0105 G_loss: N/A
# Epoch [104/1000] Batch [20/25] D_loss: -0.9124 G_loss: N/A
#
# Epoch 104 completed in 35.62s | FID: 0.5267 | IS: 0.5371 | SSIM: 0.0531 | PSNR: 11.3379 | Acc: 0.7028
#
# Epoch [105/1000] Batch [0/25] D_loss: -0.6779 G_loss: 4.3586
# Epoch [105/1000] Batch [10/25] D_loss: -1.1833 G_loss: N/A
# Epoch [105/1000] Batch [20/25] D_loss: -1.4288 G_loss: N/A
#
# Epoch 105 completed in 35.59s | FID: 1.5839 | IS: 0.5493 | SSIM: 0.0514 | PSNR: 11.3468 | Acc: 0.7014
#
# Epoch [106/1000] Batch [0/25] D_loss: -0.6963 G_loss: 4.1323
# Epoch [106/1000] Batch [10/25] D_loss: -1.3906 G_loss: N/A
# Epoch [106/1000] Batch [20/25] D_loss: -1.1772 G_loss: N/A
#
# Epoch 106 completed in 35.59s | FID: 0.6748 | IS: 0.6102 | SSIM: 0.0589 | PSNR: 11.7926 | Acc: 0.7417
#
# Epoch [107/1000] Batch [0/25] D_loss: -1.1297 G_loss: 4.6443
# Epoch [107/1000] Batch [10/25] D_loss: -0.7555 G_loss: N/A
# Epoch [107/1000] Batch [20/25] D_loss: -0.8562 G_loss: N/A
#
# Epoch 107 completed in 35.59s | FID: 0.7703 | IS: 0.6015 | SSIM: 0.0452 | PSNR: 11.3176 | Acc: 0.7444
#
# Epoch [108/1000] Batch [0/25] D_loss: -0.7374 G_loss: 4.4427
# Epoch [108/1000] Batch [10/25] D_loss: -1.4182 G_loss: N/A
# Epoch [108/1000] Batch [20/25] D_loss: -1.1059 G_loss: N/A
#
# Epoch 108 completed in 35.61s | FID: 1.4648 | IS: 0.5937 | SSIM: 0.0496 | PSNR: 11.4212 | Acc: 0.7014
#
# Epoch [109/1000] Batch [0/25] D_loss: -0.3148 G_loss: 4.4411
# Epoch [109/1000] Batch [10/25] D_loss: -1.1624 G_loss: N/A
# Epoch [109/1000] Batch [20/25] D_loss: -0.9096 G_loss: N/A
#
# Epoch 109 completed in 35.65s | FID: 1.2734 | IS: 0.5386 | SSIM: 0.0515 | PSNR: 11.2765 | Acc: 0.7514
#
# Epoch [110/1000] Batch [0/25] D_loss: -1.4105 G_loss: 5.4811
# Epoch [110/1000] Batch [10/25] D_loss: -0.9181 G_loss: N/A
# Epoch [110/1000] Batch [20/25] D_loss: -0.9238 G_loss: N/A
#
# Epoch 110 completed in 35.64s | FID: 1.3132 | IS: 0.5366 | SSIM: 0.0459 | PSNR: 11.1303 | Acc: 0.7125
#
# Epoch [111/1000] Batch [0/25] D_loss: -0.9470 G_loss: 4.5801
# Epoch [111/1000] Batch [10/25] D_loss: -0.8445 G_loss: N/A
# Epoch [111/1000] Batch [20/25] D_loss: -1.1034 G_loss: N/A
#
# Epoch 111 completed in 35.63s | FID: 0.5339 | IS: 0.5432 | SSIM: 0.0536 | PSNR: 11.1406 | Acc: 0.7347
#
# Epoch [112/1000] Batch [0/25] D_loss: -0.8674 G_loss: 4.6600
# Epoch [112/1000] Batch [10/25] D_loss: -0.9015 G_loss: N/A
# Epoch [112/1000] Batch [20/25] D_loss: -0.6637 G_loss: N/A
#
# Epoch 112 completed in 35.63s | FID: 1.4724 | IS: 0.5863 | SSIM: 0.0564 | PSNR: 11.4546 | Acc: 0.7375
#
# Epoch [113/1000] Batch [0/25] D_loss: -0.7809 G_loss: 4.7839
# Epoch [113/1000] Batch [10/25] D_loss: -1.5567 G_loss: N/A
# Epoch [113/1000] Batch [20/25] D_loss: -0.7411 G_loss: N/A
#
# Epoch 113 completed in 35.63s | FID: 0.7813 | IS: 0.5934 | SSIM: 0.0596 | PSNR: 11.5041 | Acc: 0.6500
#
# Epoch [114/1000] Batch [0/25] D_loss: -1.0088 G_loss: 4.5860
# Epoch [114/1000] Batch [10/25] D_loss: -0.8569 G_loss: N/A
# Epoch [114/1000] Batch [20/25] D_loss: -1.1751 G_loss: N/A
#
# Epoch 114 completed in 35.64s | FID: 0.9083 | IS: 0.5866 | SSIM: 0.0570 | PSNR: 11.5432 | Acc: 0.7694
#
# Epoch [115/1000] Batch [0/25] D_loss: -0.7623 G_loss: 4.3451
# Epoch [115/1000] Batch [10/25] D_loss: -1.1629 G_loss: N/A
# Epoch [115/1000] Batch [20/25] D_loss: -1.0080 G_loss: N/A
#
# Epoch 115 completed in 35.65s | FID: 0.5244 | IS: 0.5668 | SSIM: 0.0534 | PSNR: 11.2328 | Acc: 0.7708
#
# Epoch [116/1000] Batch [0/25] D_loss: -1.0994 G_loss: 4.9256
# Epoch [116/1000] Batch [10/25] D_loss: -0.9308 G_loss: N/A
# Epoch [116/1000] Batch [20/25] D_loss: -1.2058 G_loss: N/A
#
# Epoch 116 completed in 35.64s | FID: 0.5812 | IS: 0.5693 | SSIM: 0.0529 | PSNR: 11.3320 | Acc: 0.6750
#
# Epoch [117/1000] Batch [0/25] D_loss: -0.9011 G_loss: 4.6343
# Epoch [117/1000] Batch [10/25] D_loss: -1.0651 G_loss: N/A
# Epoch [117/1000] Batch [20/25] D_loss: -0.8641 G_loss: N/A
#
# Epoch 117 completed in 35.66s | FID: 0.5746 | IS: 0.5534 | SSIM: 0.0568 | PSNR: 11.2985 | Acc: 0.6917
#
# Epoch [118/1000] Batch [0/25] D_loss: -0.9178 G_loss: 4.3746
# Epoch [118/1000] Batch [10/25] D_loss: -0.6453 G_loss: N/A
# Epoch [118/1000] Batch [20/25] D_loss: -1.1014 G_loss: N/A
#
# Epoch 118 completed in 35.63s | FID: 1.3079 | IS: 0.5366 | SSIM: 0.0554 | PSNR: 11.4132 | Acc: 0.7222
#
# Epoch [119/1000] Batch [0/25] D_loss: -1.0131 G_loss: 4.6932
# Epoch [119/1000] Batch [10/25] D_loss: -0.9132 G_loss: N/A
# Epoch [119/1000] Batch [20/25] D_loss: -1.1364 G_loss: N/A
#
# Epoch 119 completed in 35.60s | FID: 0.5238 | IS: 0.5604 | SSIM: 0.0552 | PSNR: 11.5816 | Acc: 0.7458
#
# Epoch [120/1000] Batch [0/25] D_loss: -1.1633 G_loss: 4.6840
# Epoch [120/1000] Batch [10/25] D_loss: -1.0455 G_loss: N/A
# Epoch [120/1000] Batch [20/25] D_loss: -0.8918 G_loss: N/A
#
# Epoch 120 completed in 35.58s | FID: 1.1993 | IS: 0.5640 | SSIM: 0.0528 | PSNR: 11.3641 | Acc: 0.6722
#
# Epoch [121/1000] Batch [0/25] D_loss: -0.9615 G_loss: 3.9956
# Epoch [121/1000] Batch [10/25] D_loss: -1.1423 G_loss: N/A
# Epoch [121/1000] Batch [20/25] D_loss: -1.5652 G_loss: N/A
#
# Epoch 121 completed in 35.60s | FID: 0.4754 | IS: 0.5405 | SSIM: 0.0558 | PSNR: 11.4499 | Acc: 0.6986
#
# Epoch [122/1000] Batch [0/25] D_loss: -0.7894 G_loss: 4.6845
# Epoch [122/1000] Batch [10/25] D_loss: -1.0594 G_loss: N/A
# Epoch [122/1000] Batch [20/25] D_loss: -1.1831 G_loss: N/A
#
# Epoch 122 completed in 35.57s | FID: 1.2116 | IS: 0.5554 | SSIM: 0.0540 | PSNR: 11.5047 | Acc: 0.6722
#
# Epoch [123/1000] Batch [0/25] D_loss: -0.7802 G_loss: 4.3954
# Epoch [123/1000] Batch [10/25] D_loss: -0.7212 G_loss: N/A
# Epoch [123/1000] Batch [20/25] D_loss: -0.8372 G_loss: N/A
#
# Epoch 123 completed in 35.63s | FID: 0.9450 | IS: 0.5856 | SSIM: 0.0540 | PSNR: 11.4713 | Acc: 0.7417
#
# Epoch [124/1000] Batch [0/25] D_loss: -0.8687 G_loss: 4.9486
# Epoch [124/1000] Batch [10/25] D_loss: -1.5702 G_loss: N/A
# Epoch [124/1000] Batch [20/25] D_loss: -0.8920 G_loss: N/A
#
# Epoch 124 completed in 35.65s | FID: 0.9624 | IS: 0.5596 | SSIM: 0.0575 | PSNR: 11.4340 | Acc: 0.7097
#
# Epoch [125/1000] Batch [0/25] D_loss: -0.7954 G_loss: 4.7950
# Epoch [125/1000] Batch [10/25] D_loss: -1.0229 G_loss: N/A
# Epoch [125/1000] Batch [20/25] D_loss: -1.0274 G_loss: N/A
#
# Epoch 125 completed in 35.67s | FID: 0.8134 | IS: 0.5711 | SSIM: 0.0520 | PSNR: 11.2586 | Acc: 0.7306
#
# Epoch [126/1000] Batch [0/25] D_loss: -1.7411 G_loss: 5.4476
# Epoch [126/1000] Batch [10/25] D_loss: -0.9298 G_loss: N/A
# Epoch [126/1000] Batch [20/25] D_loss: -1.0237 G_loss: N/A
#
# Epoch 126 completed in 35.66s | FID: 0.5769 | IS: 0.5576 | SSIM: 0.0514 | PSNR: 11.2420 | Acc: 0.7333
#
# Epoch [127/1000] Batch [0/25] D_loss: -0.8950 G_loss: 5.0117
# Epoch [127/1000] Batch [10/25] D_loss: -1.3155 G_loss: N/A
# Epoch [127/1000] Batch [20/25] D_loss: -0.9730 G_loss: N/A
#
# Epoch 127 completed in 35.66s | FID: 0.9687 | IS: 0.5694 | SSIM: 0.0553 | PSNR: 11.5986 | Acc: 0.7250
#
# Epoch [128/1000] Batch [0/25] D_loss: -1.3408 G_loss: 5.0324
# Epoch [128/1000] Batch [10/25] D_loss: -1.1718 G_loss: N/A
# Epoch [128/1000] Batch [20/25] D_loss: -1.2610 G_loss: N/A
#
# Epoch 128 completed in 35.64s | FID: 0.8994 | IS: 0.5402 | SSIM: 0.0520 | PSNR: 11.2477 | Acc: 0.7000
#
# Epoch [129/1000] Batch [0/25] D_loss: -0.9736 G_loss: 5.2965
# Epoch [129/1000] Batch [10/25] D_loss: -1.0074 G_loss: N/A
# Epoch [129/1000] Batch [20/25] D_loss: -1.1300 G_loss: N/A
#
# Epoch 129 completed in 35.59s | FID: 0.6388 | IS: 0.5980 | SSIM: 0.0561 | PSNR: 11.3359 | Acc: 0.7597
#
# Epoch [130/1000] Batch [0/25] D_loss: -1.2237 G_loss: 4.8848
# Epoch [130/1000] Batch [10/25] D_loss: -0.8788 G_loss: N/A
# Epoch [130/1000] Batch [20/25] D_loss: -0.6093 G_loss: N/A
#
# Epoch 130 completed in 35.60s | FID: 0.9015 | IS: 0.6239 | SSIM: 0.0526 | PSNR: 11.4721 | Acc: 0.7389
#
# Epoch [131/1000] Batch [0/25] D_loss: -1.4779 G_loss: 5.1125
# Epoch [131/1000] Batch [10/25] D_loss: -0.9661 G_loss: N/A
# Epoch [131/1000] Batch [20/25] D_loss: -0.9141 G_loss: N/A
#
# Epoch 131 completed in 35.60s | FID: 0.8728 | IS: 0.5744 | SSIM: 0.0536 | PSNR: 11.2902 | Acc: 0.6819
#
# Epoch [132/1000] Batch [0/25] D_loss: -1.0272 G_loss: 4.6627
# Epoch [132/1000] Batch [10/25] D_loss: -1.1883 G_loss: N/A
# Epoch [132/1000] Batch [20/25] D_loss: -0.6677 G_loss: N/A
#
# Epoch 132 completed in 35.60s | FID: 1.0822 | IS: 0.5431 | SSIM: 0.0565 | PSNR: 11.4270 | Acc: 0.6681
#
# Epoch [133/1000] Batch [0/25] D_loss: -0.9983 G_loss: 4.8700
# Epoch [133/1000] Batch [10/25] D_loss: -0.7071 G_loss: N/A
# Epoch [133/1000] Batch [20/25] D_loss: -1.2215 G_loss: N/A
#
# Epoch 133 completed in 35.61s | FID: 0.5333 | IS: 0.5228 | SSIM: 0.0518 | PSNR: 11.3597 | Acc: 0.7028
#
# Epoch [134/1000] Batch [0/25] D_loss: -1.4498 G_loss: 5.2734
# Epoch [134/1000] Batch [10/25] D_loss: -1.1537 G_loss: N/A
# Epoch [134/1000] Batch [20/25] D_loss: -1.0685 G_loss: N/A
#
# Epoch 134 completed in 35.63s | FID: 0.6195 | IS: 0.5699 | SSIM: 0.0502 | PSNR: 11.3694 | Acc: 0.7347
#
# Epoch [135/1000] Batch [0/25] D_loss: -1.0643 G_loss: 4.6615
# Epoch [135/1000] Batch [10/25] D_loss: -1.0215 G_loss: N/A
# Epoch [135/1000] Batch [20/25] D_loss: -1.1806 G_loss: N/A
#
# Epoch 135 completed in 35.63s | FID: 1.3795 | IS: 0.5734 | SSIM: 0.0561 | PSNR: 11.7834 | Acc: 0.6736
#
# Epoch [136/1000] Batch [0/25] D_loss: -1.1114 G_loss: 5.2604
# Epoch [136/1000] Batch [10/25] D_loss: -0.9319 G_loss: N/A
# Epoch [136/1000] Batch [20/25] D_loss: -0.8821 G_loss: N/A
#
# Epoch 136 completed in 35.67s | FID: 0.5390 | IS: 0.5513 | SSIM: 0.0554 | PSNR: 11.4677 | Acc: 0.6972
#
# Epoch [137/1000] Batch [0/25] D_loss: -0.9400 G_loss: 4.6338
# Epoch [137/1000] Batch [10/25] D_loss: -0.8506 G_loss: N/A
# Epoch [137/1000] Batch [20/25] D_loss: -0.9681 G_loss: N/A
#
# Epoch 137 completed in 35.66s | FID: 0.6351 | IS: 0.5440 | SSIM: 0.0557 | PSNR: 11.4666 | Acc: 0.7514
#
# Epoch [138/1000] Batch [0/25] D_loss: -0.5527 G_loss: 4.1267
# Epoch [138/1000] Batch [10/25] D_loss: -0.8524 G_loss: N/A
# Epoch [138/1000] Batch [20/25] D_loss: -1.1340 G_loss: N/A
#
# Epoch 138 completed in 35.62s | FID: 0.9316 | IS: 0.5733 | SSIM: 0.0544 | PSNR: 11.2792 | Acc: 0.7764
#
# Epoch [139/1000] Batch [0/25] D_loss: -1.2805 G_loss: 5.0932
# Epoch [139/1000] Batch [10/25] D_loss: -0.7824 G_loss: N/A
# Epoch [139/1000] Batch [20/25] D_loss: -0.6500 G_loss: N/A
#
# Epoch 139 completed in 35.60s | FID: 1.0308 | IS: 0.6003 | SSIM: 0.0553 | PSNR: 11.7480 | Acc: 0.7514
#
# Epoch [140/1000] Batch [0/25] D_loss: -1.6214 G_loss: 4.5271
# Epoch [140/1000] Batch [10/25] D_loss: -1.3215 G_loss: N/A
# Epoch [140/1000] Batch [20/25] D_loss: -1.1316 G_loss: N/A
#
# Epoch 140 completed in 35.60s | FID: 1.2474 | IS: 0.5972 | SSIM: 0.0579 | PSNR: 11.5063 | Acc: 0.7764
#
# Epoch [141/1000] Batch [0/25] D_loss: -1.2166 G_loss: 5.1135
# Epoch [141/1000] Batch [10/25] D_loss: -1.1820 G_loss: N/A
# Epoch [141/1000] Batch [20/25] D_loss: -0.6766 G_loss: N/A
#
# Epoch 141 completed in 35.62s | FID: 1.5326 | IS: 0.5564 | SSIM: 0.0531 | PSNR: 11.3929 | Acc: 0.7111
#
# Epoch [142/1000] Batch [0/25] D_loss: -0.5718 G_loss: 4.5866
# Epoch [142/1000] Batch [10/25] D_loss: -1.2901 G_loss: N/A
# Epoch [142/1000] Batch [20/25] D_loss: -0.8627 G_loss: N/A
#
# Epoch 142 completed in 35.61s | FID: 0.9314 | IS: 0.5586 | SSIM: 0.0570 | PSNR: 11.3680 | Acc: 0.7347
#
# Epoch [143/1000] Batch [0/25] D_loss: -1.1857 G_loss: 4.7359
# Epoch [143/1000] Batch [10/25] D_loss: -1.0013 G_loss: N/A
# Epoch [143/1000] Batch [20/25] D_loss: -0.9022 G_loss: N/A
#
# Epoch 143 completed in 35.58s | FID: 0.6095 | IS: 0.5813 | SSIM: 0.0555 | PSNR: 11.3944 | Acc: 0.7278
#
# Epoch [144/1000] Batch [0/25] D_loss: -1.2822 G_loss: 5.1078
# Epoch [144/1000] Batch [10/25] D_loss: -0.8664 G_loss: N/A
# Epoch [144/1000] Batch [20/25] D_loss: -0.9717 G_loss: N/A
#
# Epoch 144 completed in 35.58s | FID: 1.2488 | IS: 0.5775 | SSIM: 0.0527 | PSNR: 11.2503 | Acc: 0.7903
#
# Epoch [145/1000] Batch [0/25] D_loss: -1.2095 G_loss: 5.1252
# Epoch [145/1000] Batch [10/25] D_loss: -0.9125 G_loss: N/A
# Epoch [145/1000] Batch [20/25] D_loss: -0.8185 G_loss: N/A
#
# Epoch 145 completed in 35.63s | FID: 0.8905 | IS: 0.5678 | SSIM: 0.0537 | PSNR: 11.3121 | Acc: 0.7583
#
# Epoch [146/1000] Batch [0/25] D_loss: -1.0654 G_loss: 4.6341
# Epoch [146/1000] Batch [10/25] D_loss: -0.8820 G_loss: N/A
# Epoch [146/1000] Batch [20/25] D_loss: -0.8978 G_loss: N/A
#
# Epoch 146 completed in 35.60s | FID: 0.6310 | IS: 0.5724 | SSIM: 0.0538 | PSNR: 11.4172 | Acc: 0.7681
#
# Epoch [147/1000] Batch [0/25] D_loss: -1.0634 G_loss: 4.6949
# Epoch [147/1000] Batch [10/25] D_loss: -1.1189 G_loss: N/A
# Epoch [147/1000] Batch [20/25] D_loss: -0.7983 G_loss: N/A
#
# Epoch 147 completed in 35.63s | FID: 0.6965 | IS: 0.5689 | SSIM: 0.0525 | PSNR: 11.3022 | Acc: 0.6917
#
# Epoch [148/1000] Batch [0/25] D_loss: -1.2015 G_loss: 5.1888
# Epoch [148/1000] Batch [10/25] D_loss: -1.2485 G_loss: N/A
# Epoch [148/1000] Batch [20/25] D_loss: -1.0562 G_loss: N/A
#
# Epoch 148 completed in 35.66s | FID: 0.8686 | IS: 0.5521 | SSIM: 0.0513 | PSNR: 11.3917 | Acc: 0.7514
#
# Epoch [149/1000] Batch [0/25] D_loss: -0.7598 G_loss: 4.9309
# Epoch [149/1000] Batch [10/25] D_loss: -1.1995 G_loss: N/A
# Epoch [149/1000] Batch [20/25] D_loss: -1.2347 G_loss: N/A
#
# Epoch 149 completed in 35.65s | FID: 1.0464 | IS: 0.5571 | SSIM: 0.0532 | PSNR: 11.4805 | Acc: 0.6569
#
# Epoch [150/1000] Batch [0/25] D_loss: -1.0990 G_loss: 4.5222
# Epoch [150/1000] Batch [10/25] D_loss: -1.2910 G_loss: N/A
# Epoch [150/1000] Batch [20/25] D_loss: -1.1934 G_loss: N/A
#
# Epoch 150 completed in 35.66s | FID: 1.5680 | IS: 0.5662 | SSIM: 0.0517 | PSNR: 11.3881 | Acc: 0.7083
#
# Epoch [151/1000] Batch [0/25] D_loss: -1.1187 G_loss: 5.2794
# Epoch [151/1000] Batch [10/25] D_loss: -0.8610 G_loss: N/A
# Epoch [151/1000] Batch [20/25] D_loss: -0.6587 G_loss: N/A
#
# Epoch 151 completed in 35.62s | FID: 1.0820 | IS: 0.5767 | SSIM: 0.0541 | PSNR: 11.4263 | Acc: 0.8083
#
# Epoch [152/1000] Batch [0/25] D_loss: -1.0444 G_loss: 5.0397
# Epoch [152/1000] Batch [10/25] D_loss: -1.0822 G_loss: N/A
# Epoch [152/1000] Batch [20/25] D_loss: -0.9990 G_loss: N/A
#
# Epoch 152 completed in 35.59s | FID: 0.4925 | IS: 0.5502 | SSIM: 0.0478 | PSNR: 11.1168 | Acc: 0.6958
#
# Epoch [153/1000] Batch [0/25] D_loss: -0.6846 G_loss: 4.7202
# Epoch [153/1000] Batch [10/25] D_loss: -0.8102 G_loss: N/A
# Epoch [153/1000] Batch [20/25] D_loss: -1.1613 G_loss: N/A
#
# Epoch 153 completed in 35.59s | FID: 1.3223 | IS: 0.5536 | SSIM: 0.0518 | PSNR: 11.3733 | Acc: 0.7111
#
# Epoch [154/1000] Batch [0/25] D_loss: -0.8554 G_loss: 4.8394
# Epoch [154/1000] Batch [10/25] D_loss: -1.1990 G_loss: N/A
# Epoch [154/1000] Batch [20/25] D_loss: -1.4466 G_loss: N/A
#
# Epoch 154 completed in 35.59s | FID: 1.0230 | IS: 0.5758 | SSIM: 0.0504 | PSNR: 11.2709 | Acc: 0.6806
#
# Epoch [155/1000] Batch [0/25] D_loss: -1.1059 G_loss: 5.5938
# Epoch [155/1000] Batch [10/25] D_loss: -0.9768 G_loss: N/A
# Epoch [155/1000] Batch [20/25] D_loss: -0.8549 G_loss: N/A
#
# Epoch 155 completed in 35.57s | FID: 0.7106 | IS: 0.5510 | SSIM: 0.0524 | PSNR: 11.2691 | Acc: 0.7458
#
# Epoch [156/1000] Batch [0/25] D_loss: -0.9450 G_loss: 4.7110
# Epoch [156/1000] Batch [10/25] D_loss: -1.2966 G_loss: N/A
# Epoch [156/1000] Batch [20/25] D_loss: -1.2606 G_loss: N/A
#
# Epoch 156 completed in 35.61s | FID: 0.8044 | IS: 0.5685 | SSIM: 0.0522 | PSNR: 11.3306 | Acc: 0.6986
#
# Epoch [157/1000] Batch [0/25] D_loss: -1.2433 G_loss: 5.0882
# Epoch [157/1000] Batch [10/25] D_loss: -1.2596 G_loss: N/A
# Epoch [157/1000] Batch [20/25] D_loss: -1.2043 G_loss: N/A
#
# Epoch 157 completed in 35.63s | FID: 0.5744 | IS: 0.5846 | SSIM: 0.0541 | PSNR: 11.3203 | Acc: 0.7250
#
# Epoch [158/1000] Batch [0/25] D_loss: -1.4579 G_loss: 5.0203
# Epoch [158/1000] Batch [10/25] D_loss: -1.2805 G_loss: N/A
# Epoch [158/1000] Batch [20/25] D_loss: -1.0158 G_loss: N/A
#
# Epoch 158 completed in 35.62s | FID: 0.5466 | IS: 0.5659 | SSIM: 0.0518 | PSNR: 11.4695 | Acc: 0.7250
#
# Epoch [159/1000] Batch [0/25] D_loss: -1.5069 G_loss: 5.3040
# Epoch [159/1000] Batch [10/25] D_loss: -1.3282 G_loss: N/A
# Epoch [159/1000] Batch [20/25] D_loss: -0.7098 G_loss: N/A
#
# Epoch 159 completed in 35.61s | FID: 0.8411 | IS: 0.5717 | SSIM: 0.0561 | PSNR: 11.3535 | Acc: 0.7250
#
# Epoch [160/1000] Batch [0/25] D_loss: -0.9189 G_loss: 5.5761
# Epoch [160/1000] Batch [10/25] D_loss: -1.0445 G_loss: N/A
# Epoch [160/1000] Batch [20/25] D_loss: -1.2633 G_loss: N/A
#
# Epoch 160 completed in 35.60s | FID: 1.0733 | IS: 0.5584 | SSIM: 0.0523 | PSNR: 11.2681 | Acc: 0.6778
#
# Epoch [161/1000] Batch [0/25] D_loss: -0.7305 G_loss: 4.9116
# Epoch [161/1000] Batch [10/25] D_loss: -1.6302 G_loss: N/A
# Epoch [161/1000] Batch [20/25] D_loss: -1.4509 G_loss: N/A
#
# Epoch 161 completed in 35.60s | FID: 1.0800 | IS: 0.5688 | SSIM: 0.0551 | PSNR: 11.5668 | Acc: 0.7486
#
# Epoch [162/1000] Batch [0/25] D_loss: -0.9034 G_loss: 5.3527
# Epoch [162/1000] Batch [10/25] D_loss: -1.5820 G_loss: N/A
# Epoch [162/1000] Batch [20/25] D_loss: -1.0341 G_loss: N/A
#
# Epoch 162 completed in 35.63s | FID: 0.9103 | IS: 0.5990 | SSIM: 0.0527 | PSNR: 11.6205 | Acc: 0.8028
#
# Epoch [163/1000] Batch [0/25] D_loss: -1.5468 G_loss: 5.4979
# Epoch [163/1000] Batch [10/25] D_loss: -0.9602 G_loss: N/A
# Epoch [163/1000] Batch [20/25] D_loss: -1.0490 G_loss: N/A
#
# Epoch 163 completed in 35.59s | FID: 0.9457 | IS: 0.5620 | SSIM: 0.0540 | PSNR: 11.3616 | Acc: 0.7556
#
# Epoch [164/1000] Batch [0/25] D_loss: -0.9909 G_loss: 4.8716
# Epoch [164/1000] Batch [10/25] D_loss: -0.9197 G_loss: N/A
# Epoch [164/1000] Batch [20/25] D_loss: -1.6851 G_loss: N/A
#
# Epoch 164 completed in 35.62s | FID: 0.8688 | IS: 0.5515 | SSIM: 0.0540 | PSNR: 11.6599 | Acc: 0.7639
#
# Epoch [165/1000] Batch [0/25] D_loss: -0.8543 G_loss: 4.9265
# Epoch [165/1000] Batch [10/25] D_loss: -0.9740 G_loss: N/A
# Epoch [165/1000] Batch [20/25] D_loss: -1.1359 G_loss: N/A
#
# Epoch 165 completed in 35.62s | FID: 2.2797 | IS: 0.5962 | SSIM: 0.0575 | PSNR: 11.5644 | Acc: 0.7403
#
# Epoch [166/1000] Batch [0/25] D_loss: -0.9883 G_loss: 4.7706
# Epoch [166/1000] Batch [10/25] D_loss: -0.9738 G_loss: N/A
# Epoch [166/1000] Batch [20/25] D_loss: -1.2212 G_loss: N/A
#
# Epoch 166 completed in 35.64s | FID: 0.4909 | IS: 0.5684 | SSIM: 0.0592 | PSNR: 11.4583 | Acc: 0.7194
#
# Epoch [167/1000] Batch [0/25] D_loss: -0.9612 G_loss: 4.7355
# Epoch [167/1000] Batch [10/25] D_loss: -1.0107 G_loss: N/A
# Epoch [167/1000] Batch [20/25] D_loss: -0.8188 G_loss: N/A
#
# Epoch 167 completed in 35.60s | FID: 0.6643 | IS: 0.5532 | SSIM: 0.0517 | PSNR: 11.3135 | Acc: 0.7722
#
# Epoch [168/1000] Batch [0/25] D_loss: -0.9925 G_loss: 4.6571
# Epoch [168/1000] Batch [10/25] D_loss: -1.2292 G_loss: N/A
# Epoch [168/1000] Batch [20/25] D_loss: -1.1802 G_loss: N/A
#
# Epoch 168 completed in 35.58s | FID: 0.7791 | IS: 0.5546 | SSIM: 0.0558 | PSNR: 11.4625 | Acc: 0.6986
#
# Epoch [169/1000] Batch [0/25] D_loss: -1.0409 G_loss: 5.0352
# Epoch [169/1000] Batch [10/25] D_loss: -1.0173 G_loss: N/A
# Epoch [169/1000] Batch [20/25] D_loss: -1.3207 G_loss: N/A
#
# Epoch 169 completed in 35.57s | FID: 0.7999 | IS: 0.5690 | SSIM: 0.0554 | PSNR: 11.6732 | Acc: 0.7875
#
# Epoch [170/1000] Batch [0/25] D_loss: -1.1669 G_loss: 4.8826
# Epoch [170/1000] Batch [10/25] D_loss: -1.0415 G_loss: N/A
# Epoch [170/1000] Batch [20/25] D_loss: -1.0281 G_loss: N/A
#
# Epoch 170 completed in 35.58s | FID: 0.9764 | IS: 0.5778 | SSIM: 0.0556 | PSNR: 11.6141 | Acc: 0.7569
#
# Epoch [171/1000] Batch [0/25] D_loss: -1.6458 G_loss: 5.2913
# ...
#
# Epoch 944 completed in 35.60s | FID: 1.9712 | IS: 0.6700 | SSIM: 0.0509 | PSNR: 11.2130 | Acc: 0.8583
#
# Epoch [945/1000] Batch [0/25] D_loss: -1.5763 G_loss: 5.6135
# Epoch [945/1000] Batch [10/25] D_loss: -0.8794 G_loss: N/A
# Epoch [945/1000] Batch [20/25] D_loss: -1.5228 G_loss: N/A
#
# Epoch 945 completed in 35.57s | FID: 0.7969 | IS: 0.6670 | SSIM: 0.0543 | PSNR: 11.3153 | Acc: 0.8708
#
# Epoch [946/1000] Batch [0/25] D_loss: -1.1568 G_loss: 4.7880
# Epoch [946/1000] Batch [10/25] D_loss: -1.1948 G_loss: N/A
# Epoch [946/1000] Batch [20/25] D_loss: -0.9849 G_loss: N/A
#
# Epoch 946 completed in 35.53s | FID: 0.8765 | IS: 0.6683 | SSIM: 0.0553 | PSNR: 11.5840 | Acc: 0.8778
#
# Epoch [947/1000] Batch [0/25] D_loss: -1.5267 G_loss: 5.2618
# Epoch [947/1000] Batch [10/25] D_loss: -0.6632 G_loss: N/A
# Epoch [947/1000] Batch [20/25] D_loss: -1.4160 G_loss: N/A
#
# Epoch 947 completed in 35.54s | FID: 0.9375 | IS: 0.6675 | SSIM: 0.0561 | PSNR: 11.5798 | Acc: 0.9014
#
# Epoch [948/1000] Batch [0/25] D_loss: -0.9979 G_loss: 4.8589
# Epoch [948/1000] Batch [10/25] D_loss: -1.1232 G_loss: N/A
# Epoch [948/1000] Batch [20/25] D_loss: -1.2420 G_loss: N/A
#
# Epoch 948 completed in 35.50s | FID: 1.4699 | IS: 0.6524 | SSIM: 0.0593 | PSNR: 11.4512 | Acc: 0.8986
#
# Epoch [949/1000] Batch [0/25] D_loss: -1.0998 G_loss: 5.2742
# Epoch [949/1000] Batch [10/25] D_loss: -1.3004 G_loss: N/A
# Epoch [949/1000] Batch [20/25] D_loss: -1.4048 G_loss: N/A
#
# Epoch 949 completed in 35.57s | FID: 1.1061 | IS: 0.7047 | SSIM: 0.0564 | PSNR: 11.6495 | Acc: 0.9125
#
# Epoch [950/1000] Batch [0/25] D_loss: -0.9078 G_loss: 4.9035
# Epoch [950/1000] Batch [10/25] D_loss: -1.0743 G_loss: N/A
# Epoch [950/1000] Batch [20/25] D_loss: -1.0162 G_loss: N/A
#
# Epoch 950 completed in 35.60s | FID: 0.8499 | IS: 0.6564 | SSIM: 0.0578 | PSNR: 11.4105 | Acc: 0.8889
#
# Epoch [951/1000] Batch [0/25] D_loss: -0.8267 G_loss: 5.2144
# Epoch [951/1000] Batch [10/25] D_loss: -1.1835 G_loss: N/A
# Epoch [951/1000] Batch [20/25] D_loss: -1.5969 G_loss: N/A
#
# Epoch 951 completed in 35.59s | FID: 0.4664 | IS: 0.7073 | SSIM: 0.0544 | PSNR: 11.4382 | Acc: 0.8847
#
# Epoch [952/1000] Batch [0/25] D_loss: -1.1420 G_loss: 5.0153
# Epoch [952/1000] Batch [10/25] D_loss: -0.8985 G_loss: N/A
# Epoch [952/1000] Batch [20/25] D_loss: -1.1893 G_loss: N/A
#
# Epoch 952 completed in 35.54s | FID: 0.5893 | IS: 0.6765 | SSIM: 0.0552 | PSNR: 11.5383 | Acc: 0.8681
#
# Epoch [953/1000] Batch [0/25] D_loss: -0.9940 G_loss: 5.1599
# Epoch [953/1000] Batch [10/25] D_loss: -1.5552 G_loss: N/A
# Epoch [953/1000] Batch [20/25] D_loss: -1.2723 G_loss: N/A
#
# Epoch 953 completed in 35.55s | FID: 1.0173 | IS: 0.6083 | SSIM: 0.0526 | PSNR: 11.3807 | Acc: 0.8458
#
# Epoch [954/1000] Batch [0/25] D_loss: -1.5415 G_loss: 5.4350
# Epoch [954/1000] Batch [10/25] D_loss: -1.0740 G_loss: N/A
# Epoch [954/1000] Batch [20/25] D_loss: -1.1356 G_loss: N/A
#
# Epoch 954 completed in 35.58s | FID: 3.5151 | IS: 0.7533 | SSIM: 0.0500 | PSNR: 11.2522 | Acc: 0.8403
#
# Epoch [955/1000] Batch [0/25] D_loss: -1.0121 G_loss: 5.0342
# Epoch [955/1000] Batch [10/25] D_loss: -1.0529 G_loss: N/A
# Epoch [955/1000] Batch [20/25] D_loss: -1.3129 G_loss: N/A
#
# Epoch 955 completed in 35.58s | FID: 1.3891 | IS: 0.6684 | SSIM: 0.0564 | PSNR: 11.4627 | Acc: 0.8569
#
# Epoch [956/1000] Batch [0/25] D_loss: -0.8940 G_loss: 4.8537
# Epoch [956/1000] Batch [10/25] D_loss: -1.1361 G_loss: N/A
# Epoch [956/1000] Batch [20/25] D_loss: -0.8506 G_loss: N/A
#
# Epoch 956 completed in 35.60s | FID: 1.1990 | IS: 0.6596 | SSIM: 0.0587 | PSNR: 11.5469 | Acc: 0.8736
#
# Epoch [957/1000] Batch [0/25] D_loss: -1.0538 G_loss: 5.2888
# Epoch [957/1000] Batch [10/25] D_loss: -1.2782 G_loss: N/A
# Epoch [957/1000] Batch [20/25] D_loss: -1.0437 G_loss: N/A
#
# Epoch 957 completed in 35.55s | FID: 2.2355 | IS: 0.7122 | SSIM: 0.0548 | PSNR: 11.6224 | Acc: 0.8917
#
# Epoch [958/1000] Batch [0/25] D_loss: -1.0702 G_loss: 5.0428
# Epoch [958/1000] Batch [10/25] D_loss: -0.9213 G_loss: N/A
# Epoch [958/1000] Batch [20/25] D_loss: -1.1445 G_loss: N/A
#
# Epoch 958 completed in 35.58s | FID: 2.9712 | IS: 0.7508 | SSIM: 0.0582 | PSNR: 11.5666 | Acc: 0.9125
#
# Epoch [959/1000] Batch [0/25] D_loss: -0.8897 G_loss: 5.2618
# Epoch [959/1000] Batch [10/25] D_loss: -0.7718 G_loss: N/A
# Epoch [959/1000] Batch [20/25] D_loss: -1.3822 G_loss: N/A
#
# Epoch 959 completed in 35.59s | FID: 1.7137 | IS: 0.6426 | SSIM: 0.0523 | PSNR: 11.3612 | Acc: 0.8764
#
# Epoch [960/1000] Batch [0/25] D_loss: -1.8299 G_loss: 5.8668
# Epoch [960/1000] Batch [10/25] D_loss: -0.7577 G_loss: N/A
# Epoch [960/1000] Batch [20/25] D_loss: -1.4852 G_loss: N/A
#
# Epoch 960 completed in 35.54s | FID: 1.5201 | IS: 0.6899 | SSIM: 0.0550 | PSNR: 11.5501 | Acc: 0.8750
#
# Epoch [961/1000] Batch [0/25] D_loss: -1.1451 G_loss: 5.3386
# Epoch [961/1000] Batch [10/25] D_loss: -0.9399 G_loss: N/A
# Epoch [961/1000] Batch [20/25] D_loss: -1.4129 G_loss: N/A
#
# Epoch 961 completed in 35.55s | FID: 1.7277 | IS: 0.6422 | SSIM: 0.0540 | PSNR: 11.3185 | Acc: 0.8292
#
# Epoch [962/1000] Batch [0/25] D_loss: -0.9062 G_loss: 5.1771
# Epoch [962/1000] Batch [10/25] D_loss: -1.4981 G_loss: N/A
# Epoch [962/1000] Batch [20/25] D_loss: -1.1912 G_loss: N/A
#
# Epoch 962 completed in 35.51s | FID: 1.9777 | IS: 0.6873 | SSIM: 0.0541 | PSNR: 11.4526 | Acc: 0.8569
#
# Epoch [963/1000] Batch [0/25] D_loss: -1.0677 G_loss: 4.9794
# Epoch [963/1000] Batch [10/25] D_loss: -1.4955 G_loss: N/A
# Epoch [963/1000] Batch [20/25] D_loss: -1.1080 G_loss: N/A
#
# Epoch 963 completed in 35.54s | FID: 1.4013 | IS: 0.6551 | SSIM: 0.0567 | PSNR: 11.3631 | Acc: 0.8639
#
# Epoch [964/1000] Batch [0/25] D_loss: -1.4035 G_loss: 5.4594
# Epoch [964/1000] Batch [10/25] D_loss: -0.9480 G_loss: N/A
# Epoch [964/1000] Batch [20/25] D_loss: -1.0626 G_loss: N/A
#
# Epoch 964 completed in 35.52s | FID: 0.6343 | IS: 0.6884 | SSIM: 0.0527 | PSNR: 11.3627 | Acc: 0.8708
#
# Epoch [965/1000] Batch [0/25] D_loss: -1.0476 G_loss: 5.1914
# Epoch [965/1000] Batch [10/25] D_loss: -0.9472 G_loss: N/A
# Epoch [965/1000] Batch [20/25] D_loss: -0.8898 G_loss: N/A
#
# Epoch 965 completed in 35.57s | FID: 0.9837 | IS: 0.6837 | SSIM: 0.0561 | PSNR: 11.5296 | Acc: 0.8889
#
# Epoch [966/1000] Batch [0/25] D_loss: -1.3973 G_loss: 5.5932
# Epoch [966/1000] Batch [10/25] D_loss: -1.0155 G_loss: N/A
# Epoch [966/1000] Batch [20/25] D_loss: -0.9226 G_loss: N/A
#
# Epoch 966 completed in 35.58s | FID: 2.3689 | IS: 0.6283 | SSIM: 0.0528 | PSNR: 11.3214 | Acc: 0.8125
#
# Epoch [967/1000] Batch [0/25] D_loss: -1.1950 G_loss: 5.3270
# Epoch [967/1000] Batch [10/25] D_loss: -0.9950 G_loss: N/A
# Epoch [967/1000] Batch [20/25] D_loss: -0.9617 G_loss: N/A
#
# Epoch 967 completed in 35.58s | FID: 1.9206 | IS: 0.7141 | SSIM: 0.0594 | PSNR: 11.6159 | Acc: 0.8361
#
# Epoch [968/1000] Batch [0/25] D_loss: -1.1854 G_loss: 5.0962
# Epoch [968/1000] Batch [10/25] D_loss: -1.0561 G_loss: N/A
# Epoch [968/1000] Batch [20/25] D_loss: -1.4076 G_loss: N/A
#
# Epoch 968 completed in 35.60s | FID: 1.2704 | IS: 0.6705 | SSIM: 0.0574 | PSNR: 11.4838 | Acc: 0.8778
#
# Epoch [969/1000] Batch [0/25] D_loss: -1.1257 G_loss: 5.2632
# Epoch [969/1000] Batch [10/25] D_loss: -1.2421 G_loss: N/A
# Epoch [969/1000] Batch [20/25] D_loss: -1.1390 G_loss: N/A
#
# Epoch 969 completed in 35.58s | FID: 0.8094 | IS: 0.6520 | SSIM: 0.0570 | PSNR: 11.5550 | Acc: 0.8681
#
# Epoch [970/1000] Batch [0/25] D_loss: -1.4993 G_loss: 5.3613
# Epoch [970/1000] Batch [10/25] D_loss: -1.0504 G_loss: N/A
# Epoch [970/1000] Batch [20/25] D_loss: -1.0975 G_loss: N/A
#
# Epoch 970 completed in 35.55s | FID: 0.6468 | IS: 0.6693 | SSIM: 0.0546 | PSNR: 11.4233 | Acc: 0.8708
#
# Epoch [971/1000] Batch [0/25] D_loss: -1.0352 G_loss: 4.9831
# Epoch [971/1000] Batch [10/25] D_loss: -1.5352 G_loss: N/A
# Epoch [971/1000] Batch [20/25] D_loss: -1.1310 G_loss: N/A
#
# Epoch 971 completed in 35.56s | FID: 0.8362 | IS: 0.6776 | SSIM: 0.0539 | PSNR: 11.3465 | Acc: 0.8847
#
# Epoch [972/1000] Batch [0/25] D_loss: -1.3165 G_loss: 5.3882
# Epoch [972/1000] Batch [10/25] D_loss: -1.7129 G_loss: N/A
# Epoch [972/1000] Batch [20/25] D_loss: -0.9560 G_loss: N/A
#
# Epoch 972 completed in 35.53s | FID: 1.2744 | IS: 0.6663 | SSIM: 0.0545 | PSNR: 11.3007 | Acc: 0.8694
#
# Epoch [973/1000] Batch [0/25] D_loss: -1.0071 G_loss: 5.1575
# Epoch [973/1000] Batch [10/25] D_loss: -1.1096 G_loss: N/A
# Epoch [973/1000] Batch [20/25] D_loss: -1.1720 G_loss: N/A
#
# Epoch 973 completed in 35.53s | FID: 0.9343 | IS: 0.6985 | SSIM: 0.0552 | PSNR: 11.5002 | Acc: 0.8708
#
# Epoch [974/1000] Batch [0/25] D_loss: -1.1336 G_loss: 4.8916
# Epoch [974/1000] Batch [10/25] D_loss: -1.0643 G_loss: N/A
# Epoch [974/1000] Batch [20/25] D_loss: -1.2970 G_loss: N/A
#
# Epoch 974 completed in 35.54s | FID: 0.9196 | IS: 0.6500 | SSIM: 0.0569 | PSNR: 11.5905 | Acc: 0.8819
#
# Epoch [975/1000] Batch [0/25] D_loss: -1.1399 G_loss: 5.4274
# Epoch [975/1000] Batch [10/25] D_loss: -1.4951 G_loss: N/A
# Epoch [975/1000] Batch [20/25] D_loss: -0.7059 G_loss: N/A
#
# Epoch 975 completed in 35.54s | FID: 0.9710 | IS: 0.6601 | SSIM: 0.0518 | PSNR: 11.4678 | Acc: 0.8347
#
# Epoch [976/1000] Batch [0/25] D_loss: -1.1115 G_loss: 5.2278
# Epoch [976/1000] Batch [10/25] D_loss: -0.6634 G_loss: N/A
# Epoch [976/1000] Batch [20/25] D_loss: -1.3420 G_loss: N/A
#
# Epoch 976 completed in 35.57s | FID: 0.5751 | IS: 0.6885 | SSIM: 0.0561 | PSNR: 11.5395 | Acc: 0.8736
#
# Epoch [977/1000] Batch [0/25] D_loss: -0.9933 G_loss: 4.9778
# Epoch [977/1000] Batch [10/25] D_loss: -0.9730 G_loss: N/A
# Epoch [977/1000] Batch [20/25] D_loss: -0.9668 G_loss: N/A
#
# Epoch 977 completed in 35.56s | FID: 1.1973 | IS: 0.6907 | SSIM: 0.0546 | PSNR: 11.5038 | Acc: 0.8944
#
# Epoch [978/1000] Batch [0/25] D_loss: -0.8474 G_loss: 5.1050
# Epoch [978/1000] Batch [10/25] D_loss: -1.1984 G_loss: N/A
# Epoch [978/1000] Batch [20/25] D_loss: -0.7312 G_loss: N/A
#
# Epoch 978 completed in 35.59s | FID: 0.9472 | IS: 0.6656 | SSIM: 0.0562 | PSNR: 11.5363 | Acc: 0.8889
#
# Epoch [979/1000] Batch [0/25] D_loss: -0.8402 G_loss: 5.0668
# Epoch [979/1000] Batch [10/25] D_loss: -1.9066 G_loss: N/A
# Epoch [979/1000] Batch [20/25] D_loss: -0.9283 G_loss: N/A
#
# Epoch 979 completed in 35.59s | FID: 1.5478 | IS: 0.6691 | SSIM: 0.0555 | PSNR: 11.3705 | Acc: 0.9083
#
# Epoch [980/1000] Batch [0/25] D_loss: -1.1164 G_loss: 5.1003
# Epoch [980/1000] Batch [10/25] D_loss: -1.1874 G_loss: N/A
# Epoch [980/1000] Batch [20/25] D_loss: -0.7432 G_loss: N/A
#
# Epoch 980 completed in 35.65s | FID: 0.5906 | IS: 0.6463 | SSIM: 0.0538 | PSNR: 11.5440 | Acc: 0.8903
#
# Epoch [981/1000] Batch [0/25] D_loss: -1.0123 G_loss: 4.9702
# Epoch [981/1000] Batch [10/25] D_loss: -1.2800 G_loss: N/A
# Epoch [981/1000] Batch [20/25] D_loss: -1.3357 G_loss: N/A
#
# Epoch 981 completed in 35.55s | FID: 1.3747 | IS: 0.6838 | SSIM: 0.0573 | PSNR: 11.5081 | Acc: 0.8458
#
# Epoch [982/1000] Batch [0/25] D_loss: -1.2755 G_loss: 5.2100
# Epoch [982/1000] Batch [10/25] D_loss: -1.0763 G_loss: N/A
# Epoch [982/1000] Batch [20/25] D_loss: -1.3418 G_loss: N/A
#
# Epoch 982 completed in 35.58s | FID: 1.0332 | IS: 0.6577 | SSIM: 0.0525 | PSNR: 11.3836 | Acc: 0.8986
#
# Epoch [983/1000] Batch [0/25] D_loss: -0.7959 G_loss: 4.9976
# Epoch [983/1000] Batch [10/25] D_loss: -0.9178 G_loss: N/A
# Epoch [983/1000] Batch [20/25] D_loss: -0.9034 G_loss: N/A
#
# Epoch 983 completed in 35.60s | FID: 0.7483 | IS: 0.6888 | SSIM: 0.0540 | PSNR: 11.4195 | Acc: 0.9042
#
# Epoch [984/1000] Batch [0/25] D_loss: -1.1029 G_loss: 5.0507
# Epoch [984/1000] Batch [10/25] D_loss: -1.1179 G_loss: N/A
# Epoch [984/1000] Batch [20/25] D_loss: -1.3150 G_loss: N/A
#
# Epoch 984 completed in 35.54s | FID: 2.7763 | IS: 0.6845 | SSIM: 0.0573 | PSNR: 11.5184 | Acc: 0.8500
#
# Epoch [985/1000] Batch [0/25] D_loss: -1.1200 G_loss: 5.2086
# Epoch [985/1000] Batch [10/25] D_loss: -1.1583 G_loss: N/A
# Epoch [985/1000] Batch [20/25] D_loss: -1.0286 G_loss: N/A
#
# Epoch 985 completed in 35.54s | FID: 0.9111 | IS: 0.6902 | SSIM: 0.0527 | PSNR: 11.4691 | Acc: 0.9375
#
# Epoch [986/1000] Batch [0/25] D_loss: -1.3301 G_loss: 5.2908
# Epoch [986/1000] Batch [10/25] D_loss: -1.4626 G_loss: N/A
# Epoch [986/1000] Batch [20/25] D_loss: -1.1129 G_loss: N/A
#
# Epoch 986 completed in 35.52s | FID: 1.8923 | IS: 0.6953 | SSIM: 0.0549 | PSNR: 11.5359 | Acc: 0.8375
#
# Epoch [987/1000] Batch [0/25] D_loss: -1.2578 G_loss: 5.3315
# Epoch [987/1000] Batch [10/25] D_loss: -1.3873 G_loss: N/A
# Epoch [987/1000] Batch [20/25] D_loss: -0.9571 G_loss: N/A
#
# Epoch 987 completed in 35.52s | FID: 1.4335 | IS: 0.6456 | SSIM: 0.0509 | PSNR: 11.2953 | Acc: 0.8472
#
# Epoch [988/1000] Batch [0/25] D_loss: -0.8998 G_loss: 4.9652
# Epoch [988/1000] Batch [10/25] D_loss: -1.3871 G_loss: N/A
# Epoch [988/1000] Batch [20/25] D_loss: -1.0512 G_loss: N/A
#
# Epoch 988 completed in 35.53s | FID: 0.6179 | IS: 0.7512 | SSIM: 0.0570 | PSNR: 11.6389 | Acc: 0.8556
#
# Epoch [989/1000] Batch [0/25] D_loss: -1.1946 G_loss: 4.8913
# Epoch [989/1000] Batch [10/25] D_loss: -1.2843 G_loss: N/A
# Epoch [989/1000] Batch [20/25] D_loss: -1.1304 G_loss: N/A
#
# Epoch 989 completed in 35.66s | FID: 0.6909 | IS: 0.6524 | SSIM: 0.0569 | PSNR: 11.5209 | Acc: 0.8750
#
# Epoch [990/1000] Batch [0/25] D_loss: -1.0997 G_loss: 5.3380
# Epoch [990/1000] Batch [10/25] D_loss: -1.0567 G_loss: N/A
# Epoch [990/1000] Batch [20/25] D_loss: -1.3649 G_loss: N/A
#
# Epoch 990 completed in 35.62s | FID: 0.6791 | IS: 0.6692 | SSIM: 0.0542 | PSNR: 11.6267 | Acc: 0.8306
#
# Epoch [991/1000] Batch [0/25] D_loss: -1.2799 G_loss: 5.1750
# Epoch [991/1000] Batch [10/25] D_loss: -0.9604 G_loss: N/A
# Epoch [991/1000] Batch [20/25] D_loss: -1.7156 G_loss: N/A
#
# Epoch 991 completed in 35.56s | FID: 1.5775 | IS: 0.7197 | SSIM: 0.0575 | PSNR: 11.4982 | Acc: 0.8708
#
# Epoch [992/1000] Batch [0/25] D_loss: -1.2310 G_loss: 5.4229
# Epoch [992/1000] Batch [10/25] D_loss: -1.1723 G_loss: N/A
# Epoch [992/1000] Batch [20/25] D_loss: -1.0620 G_loss: N/A
#
# Epoch 992 completed in 35.57s | FID: 0.8550 | IS: 0.6232 | SSIM: 0.0574 | PSNR: 11.3362 | Acc: 0.8361
#
# Epoch [993/1000] Batch [0/25] D_loss: -1.0328 G_loss: 4.8758
# Epoch [993/1000] Batch [10/25] D_loss: -0.8335 G_loss: N/A
# Epoch [993/1000] Batch [20/25] D_loss: -1.4519 G_loss: N/A
#
# Epoch 993 completed in 35.57s | FID: 0.8922 | IS: 0.7437 | SSIM: 0.0563 | PSNR: 11.4093 | Acc: 0.8597
#
# Epoch [994/1000] Batch [0/25] D_loss: -1.2886 G_loss: 5.3113
# Epoch [994/1000] Batch [10/25] D_loss: -1.1422 G_loss: N/A
# Epoch [994/1000] Batch [20/25] D_loss: -1.3894 G_loss: N/A
#
# Epoch 994 completed in 35.54s | FID: 1.6520 | IS: 0.6518 | SSIM: 0.0548 | PSNR: 11.4428 | Acc: 0.8431
#
# Epoch [995/1000] Batch [0/25] D_loss: -1.2054 G_loss: 5.3054
# Epoch [995/1000] Batch [10/25] D_loss: -0.8840 G_loss: N/A
# Epoch [995/1000] Batch [20/25] D_loss: -1.2835 G_loss: N/A
#
# Epoch 995 completed in 35.52s | FID: 0.4968 | IS: 0.6875 | SSIM: 0.0533 | PSNR: 11.4565 | Acc: 0.8444
#
# Epoch [996/1000] Batch [0/25] D_loss: -1.3195 G_loss: 5.0731
# Epoch [996/1000] Batch [10/25] D_loss: -1.6934 G_loss: N/A
# Epoch [996/1000] Batch [20/25] D_loss: -1.6175 G_loss: N/A
#
# Epoch 996 completed in 35.54s | FID: 1.7169 | IS: 0.6957 | SSIM: 0.0562 | PSNR: 11.6739 | Acc: 0.8819
#
# Epoch [997/1000] Batch [0/25] D_loss: -1.5563 G_loss: 5.3405
# Epoch [997/1000] Batch [10/25] D_loss: -1.1245 G_loss: N/A
# Epoch [997/1000] Batch [20/25] D_loss: -1.0425 G_loss: N/A
#
# Epoch 997 completed in 35.53s | FID: 1.7126 | IS: 0.6942 | SSIM: 0.0566 | PSNR: 11.5757 | Acc: 0.8597
#
# Epoch [998/1000] Batch [0/25] D_loss: -1.3142 G_loss: 5.1787
# Epoch [998/1000] Batch [10/25] D_loss: -1.1833 G_loss: N/A
# Epoch [998/1000] Batch [20/25] D_loss: -1.2821 G_loss: N/A
#
# Epoch 998 completed in 36.06s | FID: 1.8018 | IS: 0.6768 | SSIM: 0.0550 | PSNR: 11.4390 | Acc: 0.8681
#
# Epoch [999/1000] Batch [0/25] D_loss: -1.3485 G_loss: 5.0786
# Epoch [999/1000] Batch [10/25] D_loss: -1.2201 G_loss: N/A
# Epoch [999/1000] Batch [20/25] D_loss: -1.4248 G_loss: N/A
#
# Epoch 999 completed in 36.48s | FID: 0.9766 | IS: 0.6368 | SSIM: 0.0557 | PSNR: 11.6357 | Acc: 0.8944
#
# Epoch [1000/1000] Batch [0/25] D_loss: -1.2842 G_loss: 4.9751
# Epoch [1000/1000] Batch [10/25] D_loss: -1.0335 G_loss: N/A
# Epoch [1000/1000] Batch [20/25] D_loss: -1.0534 G_loss: N/A
#
# Epoch 1000 completed in 35.62s | FID: 0.7163 | IS: 0.6612 | SSIM: 0.0540 | PSNR: 11.4242 | Acc: 0.9125
#
# Saved samples for epoch 1000

# %%
gan.plot_metrics(epoch=1000)
